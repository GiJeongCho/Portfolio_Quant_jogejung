# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import time
import csv
import datetime

def word_preprocess(word):
    symbols = [" ", '\n', "\t"]  # make your own list
    for symbol in symbols:
        word = word.replace(symbol, '')
    return word

def Data_Processing(text_data):
    start_point = 0
    data_2 = []
    data_2_append = data_2.append
    for i, v in enumerate(text_data):
    #     print(v)
        try:
            float(v)
        except:
            end_point = i

            a = text_data[start_point:end_point] # 이 부분 어찌 깔끔하게..?
            try:
                int(a[0][:4])
            except:
                if len(a) >= 4:
                    print(a)
                    data_2_append(a)

            start_point = end_point
            pass
    return data_2

def data_to_csv(data_2):
    dic_data = {}

    dic_data["time"] = now.strftime('%Y-%m-%d %H:%M:%S')
    for v in data_2:
        dic_data[v[0]] = v[1]

    try:
        save_state = []
        save_state_append = save_state.append

        key_list = list(data_2.keys())
        for i in key_list:
            save_state_append(dic_data[i])

        # save_state = list(dic_data.values())
        # ======================================== 데이터 쓰는 부분
        # csv파일로 적기 # newline 설정을 안하면 한줄마다 공백있는 줄이 생긴다.
        with open('currency_exchange_data.csv', 'a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(save_state)
    except:
        key_list = list(dic_data.keys())
        columns_name = key_list
        # csv파일로 적기 # newline 설정을 안하면 한줄마다 공백있는 줄이 생긴다.
        with open('currency_exchange_data.csv', 'w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(columns_name)

            save_state = []
        save_state_append = save_state.append
        for i in key_list:
            save_state_append(dic_data[i])
        # ======================================== 데이터 쓰는 부분
        # save_state = list(dic_data.values())

        # csv파일로 적기 # newline 설정을 안하면 한줄마다 공백있는 줄이 생긴다.
        with open('currency_exchange_data.csv', 'a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(save_state)

while True:
    now = datetime.datetime.now()
    html = urlopen("https://www.mibank.me/exchange/saving/index.php?currency=USD")
    bsObject = BeautifulSoup(html, "html.parser")
    # =============== 크롤링 부분
    td_data = []
    td_data_append = td_data.append
    for data in bsObject.body.find_all('td'):
        td_data_append(data.text)

    text_data = []
    for line in td_data:
        # print(line)
        word = word_preprocess(line)
        if len(word) > 2:  # ("]" in line) == False and
            text_data.append(word)
    # =============== 크롤링 부분

    del text_data[0]

    data_2 = Data_Processing(text_data) # 데이터 저장하기 쉽게 가공. @ 이 부분 속도 빠르게 개선 가능해 보임
    data_to_csv(data_2) # 데이터 csv에 저장

    time.sleep(1)
# Out:
# ['[이태원]월드환전소', '1318', '26.06', '1.94']
# ['명동스카이환전', '1319', '25.06', '1.86']
# ['명동로사환전소', '1319', '25.06', '1.86']
# ['명동제일환전센터', '1319', '25.06', '1.86']
# ['[을지로6가]포인트환전소', '1319', '25.06', '1.86']
# ['[종로]종로오케이환전', '1319', '25.06', '1.86']
# ['[이태원]국제환전소', '1319', '25.06', '1.86']
# ['베스트환전', '1319', '25.06', '1.86']
# ['한미환전', '1320', '24.06', '1.79']
# ['중앙환전', '1320', '24.06', '1.79']
# ['에프엑스코리아', '1320', '24.06', '1.79']
# ['고래환전소', '1320', '24.06', '1.79']
# ['나이스환전금융', '1320', '24.06', '1.79']
# ['[종로]종로환전소', '1320', '24.06', '1.79']
# ['신세계환전소', '1320', '24.06', '1.79']
# ['플러스환전', '1321', '23.06', '1.72']
# ['고고환전소', '1321', '23.06', '1.72']
# ['[코엑스]투어시티환전센터', '1321', '23.06', '1.72']
# ['한양환전소', '1323', '21.06', '1.57']
# ['대박나라넷', '1324', '20.06', '1.49']
# ['[신사역]로얄외국환환전소', '1325', '19.06', '1.42']
# ['[이태원]월드환전소', '1318', '26.06', '1.94']
# ['명동스카이환전', '1319', '25.06', '1.86']
# ['명동로사환전소', '1319', '25.06', '1.86']
# ['명동제일환전센터', '1319', '25.06', '1.86']
# ['[을지로6가]포인트환전소', '1319', '25.06', '1.86']
# ['[종로]종로오케이환전', '1319', '25.06', '1.86']
# ['[이태원]국제환전소', '1319', '25.06', '1.86']
# ['베스트환전', '1319', '25.06', '1.86']
# ['한미환전', '1320', '24.06', '1.79']
# ['중앙환전', '1320', '24.06', '1.79']
# ['에프엑스코리아', '1320', '24.06', '1.79']
# ['고래환전소', '1320', '24.06', '1.79']
# ['나이스환전금융', '1320', '24.06', '1.79']
# ['[종로]종로환전소', '1320', '24.06', '1.79']
# ['신세계환전소', '1320', '24.06', '1.79']
# ['플러스환전', '1321', '23.06', '1.72']
# ['고고환전소', '1321', '23.06', '1.72']
# ['[코엑스]투어시티환전센터', '1321', '23.06', '1.72']
# ['한양환전소', '1323', '21.06', '1.57']
# ['대박나라넷', '1324', '20.06', '1.49']
# ['[신사역]로얄외국환환전소', '1325', '19.06', '1.42']
# ['[이태원]월드환전소', '1318', '26.06', '1.94']
# ['명동스카이환전', '1319', '25.06', '1.86']
# ['명동로사환전소', '1319', '25.06', '1.86']
# ['명동제일환전센터', '1319', '25.06', '1.86']
# ['[을지로6가]포인트환전소', '1319', '25.06', '1.86']
# ['[종로]종로오케이환전', '1319', '25.06', '1.86']
# ['[이태원]국제환전소', '1319', '25.06', '1.86']
# ['베스트환전', '1319', '25.06', '1.86']
# ['한미환전', '1320', '24.06', '1.79']
# ['중앙환전', '1320', '24.06', '1.79']
# ['에프엑스코리아', '1320', '24.06', '1.79']
# ['고래환전소', '1320', '24.06', '1.79']
# ['나이스환전금융', '1320', '24.06', '1.79']
# ['[종로]종로환전소', '1320', '24.06', '1.79']
# ['신세계환전소', '1320', '24.06', '1.79']
# ['플러스환전', '1321', '23.06', '1.72']
# ['고고환전소', '1321', '23.06', '1.72']
# ['[코엑스]투어시티환전센터', '1321', '23.06', '1.72']
# ['한양환전소', '1323', '21.06', '1.57']
# ['대박나라넷', '1324', '20.06', '1.49']
# ['[신사역]로얄외국환환전소', '1325', '19.06', '1.42']
# ['[이태원]월드환전소', '1318', '26.06', '1.94']
# ['명동스카이환전', '1319', '25.06', '1.86']
# ['명동로사환전소', '1319', '25.06', '1.86']
# ['명동제일환전센터', '1319', '25.06', '1.86']
# ['[을지로6가]포인트환전소', '1319', '25.06', '1.86']
# ['[종로]종로오케이환전', '1319', '25.06', '1.86']
# ['[이태원]국제환전소', '1319', '25.06', '1.86']
# ['베스트환전', '1319', '25.06', '1.86']
# ['한미환전', '1320', '24.06', '1.79']
# ['중앙환전', '1320', '24.06', '1.79']
# ['에프엑스코리아', '1320', '24.06', '1.79']
# ['고래환전소', '1320', '24.06', '1.79']
# ['나이스환전금융', '1320', '24.06', '1.79']
# ['[종로]종로환전소', '1320', '24.06', '1.79']
# ['신세계환전소', '1320', '24.06', '1.79']
# ['플러스환전', '1321', '23.06', '1.72']
# ['고고환전소', '1321', '23.06', '1.72']
# ['[코엑스]투어시티환전센터', '1321', '23.06', '1.72']
# ['한양환전소', '1323', '21.06', '1.57']
# ['대박나라넷', '1324', '20.06', '1.49']
# ['[신사역]로얄외국환환전소', '1325', '19.06', '1.42']
# ['[이태원]월드환전소', '1318', '26.06', '1.94']
# ['명동스카이환전', '1319', '25.06', '1.86']
# ['명동로사환전소', '1319', '25.06', '1.86']
# ['명동제일환전센터', '1319', '25.06', '1.86']
# ['[을지로6가]포인트환전소', '1319', '25.06', '1.86']
# ['[종로]종로오케이환전', '1319', '25.06', '1.86']
# ['[이태원]국제환전소', '1319', '25.06', '1.86']
# ['베스트환전', '1319', '25.06', '1.86']
# ['한미환전', '1320', '24.06', '1.79']
# ['중앙환전', '1320', '24.06', '1.79']
# ['에프엑스코리아', '1320', '24.06', '1.79']
# ['고래환전소', '1320', '24.06', '1.79']
# ['나이스환전금융', '1320', '24.06', '1.79']
# ['[종로]종로환전소', '1320', '24.06', '1.79']
# ['신세계환전소', '1320', '24.06', '1.79']
# ['플러스환전', '1321', '23.06', '1.72']
# ['고고환전소', '1321', '23.06', '1.72']
# ['[코엑스]투어시티환전센터', '1321', '23.06', '1.72']
# ['한양환전소', '1323', '21.06', '1.57']
# ['대박나라넷', '1324', '20.06', '1.49']
# ['[신사역]로얄외국환환전소', '1325', '19.06', '1.42']
# ['[이태원]월드환전소', '1318', '26.06', '1.94']
# ['명동스카이환전', '1319', '25.06', '1.86']
# ['명동로사환전소', '1319', '25.06', '1.86']
# ['명동제일환전센터', '1319', '25.06', '1.86']
# ['[을지로6가]포인트환전소', '1319', '25.06', '1.86']
# ['[종로]종로오케이환전', '1319', '25.06', '1.86']
# ['[이태원]국제환전소', '1319', '25.06', '1.86']
# ['베스트환전', '1319', '25.06', '1.86']
# ['한미환전', '1320', '24.06', '1.79']
# ['중앙환전', '1320', '24.06', '1.79']
# ['에프엑스코리아', '1320', '24.06', '1.79']
# ['고래환전소', '1320', '24.06', '1.79']
# ['나이스환전금융', '1320', '24.06', '1.79']
# ['[종로]종로환전소', '1320', '24.06', '1.79']
# ['신세계환전소', '1320', '24.06', '1.79']
# ['플러스환전', '1321', '23.06', '1.72']
# ['고고환전소', '1321', '23.06', '1.72']
# ['[코엑스]투어시티환전센터', '1321', '23.06', '1.72']
# ['한양환전소', '1323', '21.06', '1.57']
# ['대박나라넷', '1324', '20.06', '1.49']
# ['[신사역]로얄외국환환전소', '1325', '19.06', '1.42']
# ['[이태원]월드환전소', '1318', '26.06', '1.94']
# ['명동스카이환전', '1319', '25.06', '1.86']
# ['명동로사환전소', '1319', '25.06', '1.86']
# ['명동제일환전센터', '1319', '25.06', '1.86']
# ['[을지로6가]포인트환전소', '1319', '25.06', '1.86']
# ['[종로]종로오케이환전', '1319', '25.06', '1.86']
# ['[이태원]국제환전소', '1319', '25.06', '1.86']
# ['베스트환전', '1319', '25.06', '1.86']
# ['한미환전', '1320', '24.06', '1.79']
# ['중앙환전', '1320', '24.06', '1.79']
# ['에프엑스코리아', '1320', '24.06', '1.79']
# ['고래환전소', '1320', '24.06', '1.79']
# ['나이스환전금융', '1320', '24.06', '1.79']
# ['[종로]종로환전소', '1320', '24.06', '1.79']
# ['신세계환전소', '1320', '24.06', '1.79']
# ['플러스환전', '1321', '23.06', '1.72']
# ['고고환전소', '1321', '23.06', '1.72']
# ['[코엑스]투어시티환전센터', '1321', '23.06', '1.72']
# ['한양환전소', '1323', '21.06', '1.57']
# ['대박나라넷', '1324', '20.06', '1.49']
# ['[신사역]로얄외국환환전소', '1325', '19.06', '1.42']
# ['[이태원]월드환전소', '1318', '26.06', '1.94']
# ['명동스카이환전', '1319', '25.06', '1.86']
# ['명동로사환전소', '1319', '25.06', '1.86']
# ['명동제일환전센터', '1319', '25.06', '1.86']
# ['[을지로6가]포인트환전소', '1319', '25.06', '1.86']
# ['[종로]종로오케이환전', '1319', '25.06', '1.86']
# ['[이태원]국제환전소', '1319', '25.06', '1.86']
# ['베스트환전', '1319', '25.06', '1.86']
# ['한미환전', '1320', '24.06', '1.79']
# ['중앙환전', '1320', '24.06', '1.79']
# ['에프엑스코리아', '1320', '24.06', '1.79']
# ['고래환전소', '1320', '24.06', '1.79']
# ['나이스환전금융', '1320', '24.06', '1.79']
# ['[종로]종로환전소', '1320', '24.06', '1.79']
# ['신세계환전소', '1320', '24.06', '1.79']
# ['플러스환전', '1321', '23.06', '1.72']
# ['고고환전소', '1321', '23.06', '1.72']
# ['[코엑스]투어시티환전센터', '1321', '23.06', '1.72']
# ['한양환전소', '1323', '21.06', '1.57']
# ['대박나라넷', '1324', '20.06', '1.49']
# ['[신사역]로얄외국환환전소', '1325', '19.06', '1.42']
# ['[이태원]월드환전소', '1318', '26.06', '1.94']
# ['명동스카이환전', '1319', '25.06', '1.86']
# ['명동로사환전소', '1319', '25.06', '1.86']
# ['명동제일환전센터', '1319', '25.06', '1.86']
# ['[을지로6가]포인트환전소', '1319', '25.06', '1.86']
# ['[종로]종로오케이환전', '1319', '25.06', '1.86']
# ['[이태원]국제환전소', '1319', '25.06', '1.86']
# ['베스트환전', '1319', '25.06', '1.86']
# ['한미환전', '1320', '24.06', '1.79']
# ['중앙환전', '1320', '24.06', '1.79']
# ['에프엑스코리아', '1320', '24.06', '1.79']
# ['고래환전소', '1320', '24.06', '1.79']
# ['나이스환전금융', '1320', '24.06', '1.79']
# ['[종로]종로환전소', '1320', '24.06', '1.79']
# ['신세계환전소', '1320', '24.06', '1.79']
# ['플러스환전', '1321', '23.06', '1.72']
# ['고고환전소', '1321', '23.06', '1.72']
# ['[코엑스]투어시티환전센터', '1321', '23.06', '1.72']
# ['한양환전소', '1323', '21.06', '1.57']
# ['대박나라넷', '1324', '20.06', '1.49']
# ['[신사역]로얄외국환환전소', '1325', '19.06', '1.42']
# ['[이태원]월드환전소', '1318', '26.06', '1.94']
# ['명동스카이환전', '1319', '25.06', '1.86']
# ['명동로사환전소', '1319', '25.06', '1.86']
# ['명동제일환전센터', '1319', '25.06', '1.86']
# ['[을지로6가]포인트환전소', '1319', '25.06', '1.86']
# ['[종로]종로오케이환전', '1319', '25.06', '1.86']
# ['[이태원]국제환전소', '1319', '25.06', '1.86']
# ['베스트환전', '1319', '25.06', '1.86']
# ['한미환전', '1320', '24.06', '1.79']
# ['중앙환전', '1320', '24.06', '1.79']
# ['에프엑스코리아', '1320', '24.06', '1.79']
# ['고래환전소', '1320', '24.06', '1.79']
# ['나이스환전금융', '1320', '24.06', '1.79']
# ['[종로]종로환전소', '1320', '24.06', '1.79']
# ['신세계환전소', '1320', '24.06', '1.79']
# ['플러스환전', '1321', '23.06', '1.72']
# ['고고환전소', '1321', '23.06', '1.72']
# ['[코엑스]투어시티환전센터', '1321', '23.06', '1.72']
# ['한양환전소', '1323', '21.06', '1.57']
# ['대박나라넷', '1324', '20.06', '1.49']
# ['[신사역]로얄외국환환전소', '1325', '19.06', '1.42']
# ['[이태원]월드환전소', '1318', '26.06', '1.94']
# ['명동스카이환전', '1319', '25.06', '1.86']
# ['명동로사환전소', '1319', '25.06', '1.86']
# ['명동제일환전센터', '1319', '25.06', '1.86']
# ['[을지로6가]포인트환전소', '1319', '25.06', '1.86']
# ['[종로]종로오케이환전', '1319', '25.06', '1.86']
# ['[이태원]국제환전소', '1319', '25.06', '1.86']
# ['베스트환전', '1319', '25.06', '1.86']
# ['한미환전', '1320', '24.06', '1.79']
# ['중앙환전', '1320', '24.06', '1.79']
# ['에프엑스코리아', '1320', '24.06', '1.79']
# ['고래환전소', '1320', '24.06', '1.79']
# ['나이스환전금융', '1320', '24.06', '1.79']
# ['[종로]종로환전소', '1320', '24.06', '1.79']
# ['신세계환전소', '1320', '24.06', '1.79']
# ['플러스환전', '1321', '23.06', '1.72']
# ['고고환전소', '1321', '23.06', '1.72']
# ['[코엑스]투어시티환전센터', '1321', '23.06', '1.72']
# ['한양환전소', '1323', '21.06', '1.57']
# ['대박나라넷', '1324', '20.06', '1.49']
# ['[신사역]로얄외국환환전소', '1325', '19.06', '1.42']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13228\1621239773.py in <module>
#      98     data_to_csv(data_2) # 데이터 csv에 저장
#      99
# --> 100     time.sleep(1)
#
# KeyboardInterrupt:

# %%
while True:
    now = datetime.datetime.now()
    html = urlopen("https://www.mibank.me/exchange/saving/index.php?currency=USD")
    bsObject = BeautifulSoup(html, "html.parser")

    td_data = []
    td_data_append = td_data.append
    for data in bsObject.find_all('td'):
        td_data_append(data.text)

    text_data= [] 
    for line in td_data:
        # print(line)
        word = word_preprocess(line)
        if len(word)>2 : # ("]" in line) == False and
            text_data.append(word)
            
#     del text_data[0]
    
    statuses = (text_data
                )
    if (len(statuses) != 0):
        clear_output(wait=True)
        display(statuses)
    
    time.sleep(1)
# Out:
# ['\r지점별상세정보를보시려면지도의핀아이콘을클릭하세요.',
#  '[이태원]월드환전소',
#  '1318',
#  '26.06',
#  '1.94',
#  '2023.05.22',
#  '명동스카이환전',
#  '1319',
#  '25.06',
#  '1.86',
#  '2023.05.22',
#  '명동로사환전소',
#  '1319',
#  '25.06',
#  '1.86',
#  '2023.05.22',
#  '하나환전',
#  '1319',
#  '25.06',
#  '1.86',
#  '2023.05.22',
#  '명동제일환전센터',
#  '1319',
#  '25.06',
#  '1.86',
#  '2023.05.22',
#  '[을지로6가]포인트환전소',
#  '1319',
#  '25.06',
#  '1.86',
#  '2023.05.22',
#  '[종로]종로오케이환전',
#  '1319',
#  '25.06',
#  '1.86',
#  '2023.05.22',
#  '[이태원]국제환전소',
#  '1319',
#  '25.06',
#  '1.86',
#  '2023.05.22',
#  '베스트환전',
#  '1319',
#  '25.06',
#  '1.86',
#  '2023.05.22',
#  '한미환전',
#  '1320',
#  '24.06',
#  '1.79',
#  '2023.05.22',
#  '중앙환전',
#  '1320',
#  '24.06',
#  '1.79',
#  '2023.05.22',
#  '에프엑스코리아',
#  '1320',
#  '24.06',
#  '1.79',
#  '2023.05.22',
#  '고래환전소',
#  '1320',
#  '24.06',
#  '1.79',
#  '2023.05.22',
#  '나이스환전금융',
#  '1320',
#  '24.06',
#  '1.79',
#  '2023.05.22',
#  '신세계환전소',
#  '1320',
#  '24.06',
#  '1.79',
#  '2023.05.22',
#  '[종로]종로환전소',
#  '1320',
#  '24.06',
#  '1.79',
#  '2023.05.22',
#  '플러스환전',
#  '1321',
#  '23.06',
#  '1.72',
#  '2023.05.22',
#  '고고환전소',
#  '1321',
#  '23.06',
#  '1.72',
#  '2023.05.22',
#  '[코엑스]투어시티환전센터',
#  '1322',
#  '22.06',
#  '1.64',
#  '2023.05.22',
#  '한양환전소',
#  '1323',
#  '21.06',
#  '1.57',
#  '2023.05.22',
#  '대박나라넷',
#  '1324',
#  '20.06',
#  '1.49',
#  '2023.05.21',
#  '[신사역]로얄외국환환전소',
#  '1325',
#  '19.06',
#  '1.42',
#  '2023.05.22',
#  '1341.06',
#  '0.22',
#  '2023.05.22',
#  '1341.21',
#  '2.85',
#  '0.21',
#  '2023.05.22',
#  '1341.47',
#  '2.59',
#  '0.19',
#  '2023.05.22',
#  '1341.57',
#  '2.49',
#  '0.19',
#  '2023.05.22',
#  '1341.57',
#  '2.49',
#  '0.19',
#  '2023.05.22',
#  '1341.57',
#  '2.49',
#  '0.19',
#  '2023.05.22',
#  '1341.57',
#  '2.49',
#  '0.19',
#  '2023.05.22',
#  '1341.57',
#  '2.49',
#  '0.19',
#  '2023.05.22',
#  '1341.57',
#  '2.49',
#  '0.19',
#  '2023.05.22',
#  '1342.08',
#  '1.98',
#  '0.15',
#  '2023.05.22',
#  '1342.08',
#  '1.98',
#  '0.15',
#  '2023.05.22',
#  '1342.24',
#  '1.82',
#  '0.14',
#  '2023.05.22',
#  '1342.59',
#  '1.47',
#  '0.11',
#  '2023.05.22',
#  '1344.06',
#  '0.00',
#  '2023.05.22']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [165], in <cell line: 2>()
#       1 while True:
#       2     now = datetime.datetime.now()
# ----> 3     html = urlopen("https://www.mibank.me/exchange/saving/index.php?currency=USD")
#       4     bsObject = BeautifulSoup(html, "html.parser")
#       6     td_data = []
#
# File ~\anaconda3\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File ~\anaconda3\lib\urllib\request.py:517, in OpenerDirector.open(self, fullurl, data, timeout)
#     514     req = meth(req)
#     516 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517 response = self._open(req, data)
#     519 # post-process response
#     520 meth_name = protocol+"_response"
#
# File ~\anaconda3\lib\urllib\request.py:534, in OpenerDirector._open(self, req, data)
#     531     return result
#     533 protocol = req.type
# --> 534 result = self._call_chain(self.handle_open, protocol, protocol +
#     535                           '_open', req)
#     536 if result:
#     537     return result
#
# File ~\anaconda3\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File ~\anaconda3\lib\urllib\request.py:1389, in HTTPSHandler.https_open(self, req)
#    1388 def https_open(self, req):
# -> 1389     return self.do_open(http.client.HTTPSConnection, req,
#    1390         context=self._context, check_hostname=self._check_hostname)
#
# File ~\anaconda3\lib\urllib\request.py:1350, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348     except OSError as err: # timeout error
#    1349         raise URLError(err)
# -> 1350     r = h.getresponse()
#    1351 except:
#    1352     h.close()
#
# File ~\anaconda3\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~\anaconda3\lib\http\client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~\anaconda3\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~\anaconda3\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~\anaconda3\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
def Data_Processing(data_2):
    start_point = 0
    data_2 = []
    data_2_append = data_2.append
    for i, v in enumerate(text_data):
    #     print(v)
        try:
            float(v)
        except:
            end_point = i

            a = text_data[start_point:end_point] # 이 부분 어찌 깔끔하게..?
            try:
                int(a[0][:4])
            except:
                if len(a) >= 4:
                    print(a)
                    data_2_append(a)

            start_point = end_point
            pass
# Out:
# ['[이태원]월드환전소', '1318', '26.06', '1.94']
# ['명동스카이환전', '1319', '25.06', '1.86']
# ['명동로사환전소', '1319', '25.06', '1.86']
# ['하나환전', '1319', '25.06', '1.86']
# ['명동제일환전센터', '1319', '25.06', '1.86']
# ['[을지로6가]포인트환전소', '1319', '25.06', '1.86']
# ['[종로]종로오케이환전', '1319', '25.06', '1.86']
# ['[이태원]국제환전소', '1319', '25.06', '1.86']
# ['베스트환전', '1319', '25.06', '1.86']
# ['한미환전', '1320', '24.06', '1.79']
# ['중앙환전', '1320', '24.06', '1.79']
# ['에프엑스코리아', '1320', '24.06', '1.79']
# ['고래환전소', '1320', '24.06', '1.79']
# ['나이스환전금융', '1320', '24.06', '1.79']
# ['신세계환전소', '1320', '24.06', '1.79']
# ['[종로]종로환전소', '1320', '24.06', '1.79']
# ['플러스환전', '1321', '23.06', '1.72']
# ['고고환전소', '1321', '23.06', '1.72']
# ['[코엑스]투어시티환전센터', '1322', '22.06', '1.64']
# ['한양환전소', '1323', '21.06', '1.57']
# ['대박나라넷', '1324', '20.06', '1.49']
# ['[신사역]로얄외국환환전소', '1325', '19.06', '1.42']

# %%
def data_to_csv(data_2):
    dic_data = {}

    dic_data["time"] = now.strftime('%Y-%m-%d %H:%M:%S')
    for v in data_2:
        dic_data[v[0]] = v[1]

    try:
        save_state = []
        save_state_append = save_state.append

        key_list = list(data_2.keys())
        for i in key_list:
            save_state_append(dic_data[i])

        # save_state = list(dic_data.values())
        # ======================================== 데이터 쓰는 부분
        # csv파일로 적기 # newline 설정을 안하면 한줄마다 공백있는 줄이 생긴다.
        with open('currency_exchange_data.csv', 'a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(save_state)
    except:
        key_list = list(dic_data.keys())
        columns_name = key_list
        # csv파일로 적기 # newline 설정을 안하면 한줄마다 공백있는 줄이 생긴다.
        with open('currency_exchange_data.csv', 'w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(columns_name)

            save_state = []
        save_state_append = save_state.append
        for i in key_list:
            save_state_append(dic_data[i])
        # ======================================== 데이터 쓰는 부분
        # save_state = list(dic_data.values())

        # csv파일로 적기 # newline 설정을 안하면 한줄마다 공백있는 줄이 생긴다.
        with open('currency_exchange_data.csv', 'a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(save_state)
# Out:
# 22

# %%
# Out:
# ['time',
#  '[이태원]월드환전소',
#  '명동스카이환전',
#  '명동로사환전소',
#  '하나환전',
#  '명동제일환전센터',
#  '[을지로6가]포인트환전소',
#  '[종로]종로오케이환전',
#  '[이태원]국제환전소',
#  '베스트환전',
#  '한미환전',
#  '중앙환전',
#  '에프엑스코리아',
#  '고래환전소',
#  '나이스환전금융',
#  '신세계환전소',
#  '[종로]종로환전소',
#  '플러스환전',
#  '고고환전소',
#  '[코엑스]투어시티환전센터',
#  '한양환전소',
#  '대박나라넷',
#  '[신사역]로얄외국환환전소']

# %%
# Out:
# 23

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import time
html = urlopen("https://www.mibank.me/exchange/saving/index.php?currency=USD")
bsObject = BeautifulSoup(html, "html.parser")

td_data = []
td_data_append = td_data.append
for data in bsObject.find_all('td'):
    td_data_append(data.text)

def word_preprocess(word):
    symbols = [" ", '\n', "\t"]  # make your own list
    for symbol in symbols:
        word = word.replace(symbol, '')
    return word

text_data= [] 
for line in td_data:
    # print(line)
    word = word_preprocess(line)
    if len(word)>2 : # ("]" in line) == False and
        text_data.append(word)

# del text_data[0]

print(text_data) # 여기서 데이터 저장해서 쓰면 될거 같아요
# Out:
# ['\r지점별상세정보를보시려면지도의핀아이콘을클릭하세요.', '[을지로6가]포인트환전소', '1318', '23.71', '1.77', '2023.05.22', '동대문환전', '1318', '23.71', '1.77', '2023.05.22', '고래환전소', '1318', '23.71', '1.77', '2023.05.22', '동대문OK환전', '1319', '22.71', '1.69', '2023.05.22', '명동스카이환전', '1319', '22.71', '1.69', '2023.05.22', '베스트환전', '1319', '22.71', '1.69', '2023.05.22', '명동로사환전소', '1319', '22.71', '1.69', '2023.05.22', '[종로]종로환전소', '1319', '22.71', '1.69', '2023.05.22', '환전카페', '1319', '22.71', '1.69', '2023.05.22', '하나환전', '1319', '22.71', '1.69', '2023.05.22', '한미환전', '1320', '21.71', '1.62', '2023.05.22', '[이태원]월드환전소', '1320', '21.71', '1.62', '2023.05.22', '명동제일환전센터', '1320', '21.71', '1.62', '2023.05.22', '중앙환전', '1320', '21.71', '1.62', '2023.05.22', '서울상역환전', '1320', '21.71', '1.62', '2023.05.22', '[종로]종로오케이환전', '1320', '21.71', '1.62', '2023.05.22', '에프엑스코리아', '1320', '21.71', '1.62', '2023.05.22', '나이스환전금융', '1320', '21.71', '1.62', '2023.05.22', '고고환전소', '1320', '21.71', '1.62', '2023.05.22', '플러스환전', '1321', '20.71', '1.54', '2023.05.22', '[코엑스]투어시티환전센터', '1321', '20.71', '1.54', '2023.05.22', '한양환전소', '1323', '18.71', '1.39', '2023.05.22', '대박나라넷', '1324', '17.71', '1.32', '2023.05.21', '[신사역]로얄외국환환전소', '1325', '16.71', '1.25', '2023.05.22', '신세계환전소', '1325', '16.71', '1.25', '2023.05.22', '1339.43', '2.28', '0.17', '2023.05.22', '1339.43', '2.28', '0.17', '2023.05.22', '1339.43', '2.28', '0.17', '2023.05.22', '1339.48', '2.23', '0.17', '2023.05.22', '1339.49', '2.22', '0.17', '2023.05.22', '1339.52', '2.19', '0.16', '2023.05.22', '1339.53', '2.18', '0.16', '2023.05.22', '1339.53', '2.18', '0.16', '2023.05.22', '1339.64', '2.07', '0.15', '2023.05.22', '1339.64', '2.07', '0.15', '2023.05.22', '1339.74', '1.97', '0.15', '2023.05.22', '1339.84', '1.87', '0.14', '2023.05.22', '1339.99', '1.72', '0.13', '2023.05.22', '1341.71', '0.00', '2023.05.22']

# %%
# Out:
# ['1318',
#  '24.02',
#  '1.79',
#  '2023.05.22',
#  '고래환전소',
#  '1318',
#  '24.02',
#  '1.79',
#  '2023.05.22',
#  '동대문환전',
#  '1318',
#  '24.02',
#  '1.79',
#  '2023.05.22',
#  '동대문OK환전',
#  '1319',
#  '23.02',
#  '1.72',
#  '2023.05.22',
#  '명동스카이환전',
#  '1319',
#  '23.02',
#  '1.72',
#  '2023.05.22',
#  '베스트환전',
#  '1319',
#  '23.02',
#  '1.72',
#  '2023.05.22',
#  '명동로사환전소',
#  '1319',
#  '23.02',
#  '1.72',
#  '2023.05.22',
#  '1319',
#  '23.02',
#  '1.72',
#  '2023.05.22',
#  '환전카페',
#  '1319',
#  '23.02',
#  '1.72',
#  '2023.05.22',
#  '하나환전',
#  '1319',
#  '23.02',
#  '1.72',
#  '2023.05.22',
#  '한미환전',
#  '1320',
#  '22.02',
#  '1.64',
#  '2023.05.22',
#  '1320',
#  '22.02',
#  '1.64',
#  '2023.05.22',
#  '명동제일환전센터',
#  '1320',
#  '22.02',
#  '1.64',
#  '2023.05.22',
#  '중앙환전',
#  '1320',
#  '22.02',
#  '1.64',
#  '2023.05.22',
#  '서울상역환전',
#  '1320',
#  '22.02',
#  '1.64',
#  '2023.05.22',
#  '1320',
#  '22.02',
#  '1.64',
#  '2023.05.22',
#  '에프엑스코리아',
#  '1320',
#  '22.02',
#  '1.64',
#  '2023.05.22',
#  '나이스환전금융',
#  '1320',
#  '22.02',
#  '1.64',
#  '2023.05.22',
#  '플러스환전',
#  '1321',
#  '21.02',
#  '1.57',
#  '2023.05.22',
#  '1321',
#  '21.02',
#  '1.57',
#  '2023.05.22',
#  '한양환전소',
#  '1323',
#  '19.02',
#  '1.42',
#  '2023.05.22',
#  '대박나라넷',
#  '1324',
#  '18.02',
#  '1.34',
#  '2023.05.21',
#  '1325',
#  '17.02',
#  '1.27',
#  '2023.05.22',
#  '신세계환전소',
#  '1325',
#  '17.02',
#  '1.27',
#  '2023.05.22',
#  '1339.52',
#  '2.5',
#  '0.19',
#  '2023.05.22',
#  '1339.74',
#  '2.28',
#  '0.17',
#  '2023.05.22',
#  '1339.74',
#  '2.28',
#  '0.17',
#  '2023.05.22',
#  '1339.74',
#  '2.28',
#  '0.17',
#  '2023.05.22',
#  '1339.74',
#  '2.28',
#  '0.17',
#  '2023.05.22',
#  '1339.84',
#  '2.18',
#  '0.16',
#  '2023.05.22',
#  '1339.84',
#  '2.18',
#  '0.16',
#  '2023.05.22',
#  '1339.84',
#  '2.18',
#  '0.16',
#  '2023.05.22',
#  '1339.89',
#  '2.13',
#  '0.16',
#  '2023.05.22',
#  '1339.94',
#  '2.08',
#  '0.15',
#  '2023.05.22',
#  '1339.99',
#  '2.03',
#  '0.15',
#  '2023.05.22',
#  '1340.04',
#  '1.98',
#  '0.15',
#  '2023.05.22',
#  '1340.35',
#  '1.67',
#  '0.12',
#  '2023.05.22',
#  '1342.02',
#  '0.00',
#  '2023.05.22']

# %%
print(dir(bsObject))
# Out:
# ['ASCII_SPACES', 'DEFAULT_BUILDER_FEATURES', 'DEFAULT_INTERESTING_STRING_TYPES', 'NO_PARSER_SPECIFIED_WARNING', 'ROOT_TAG_NAME', '__bool__', '__call__', '__class__', '__contains__', '__copy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', '__unicode__', '__weakref__', '_all_strings', '_decode_markup', '_feed', '_find_all', '_find_one', '_is_xml', '_lastRecursiveChild', '_last_descendant', '_linkage_fixer', '_markup_is_url', '_markup_resembles_filename', '_most_recent_element', '_namespaces', '_popToTag', '_should_pretty_print', 'append', 'attrs', 'builder', 'can_be_empty_element', 'cdata_list_attributes', 'childGenerator', 'children', 'clear', 'contains_replacement_characters', 'contents', 'currentTag', 'current_data', 'declared_html_encoding', 'decode', 'decode_contents', 'decompose', 'decomposed', 'default', 'descendants', 'element_classes', 'encode', 'encode_contents', 'endData', 'extend', 'extract', 'fetchNextSiblings', 'fetchParents', 'fetchPrevious', 'fetchPreviousSiblings', 'find', 'findAll', 'findAllNext', 'findAllPrevious', 'findChild', 'findChildren', 'findNext', 'findNextSibling', 'findNextSiblings', 'findParent', 'findParents', 'findPrevious', 'findPreviousSibling', 'findPreviousSiblings', 'find_all', 'find_all_next', 'find_all_previous', 'find_next', 'find_next_sibling', 'find_next_siblings', 'find_parent', 'find_parents', 'find_previous', 'find_previous_sibling', 'find_previous_siblings', 'format_string', 'formatter_for_name', 'get', 'getText', 'get_attribute_list', 'get_text', 'handle_data', 'handle_endtag', 'handle_starttag', 'has_attr', 'has_key', 'hidden', 'index', 'insert', 'insert_after', 'insert_before', 'interesting_string_types', 'isSelfClosing', 'is_empty_element', 'is_xml', 'known_xml', 'markup', 'name', 'namespace', 'new_string', 'new_tag', 'next', 'nextGenerator', 'nextSibling', 'nextSiblingGenerator', 'next_element', 'next_elements', 'next_sibling', 'next_siblings', 'object_was_parsed', 'open_tag_counter', 'original_encoding', 'parent', 'parentGenerator', 'parents', 'parse_only', 'parserClass', 'parser_class', 'popTag', 'prefix', 'preserve_whitespace_tag_stack', 'preserve_whitespace_tags', 'prettify', 'previous', 'previousGenerator', 'previousSibling', 'previousSiblingGenerator', 'previous_element', 'previous_elements', 'previous_sibling', 'previous_siblings', 'pushTag', 'recursiveChildGenerator', 'renderContents', 'replaceWith', 'replaceWithChildren', 'replace_with', 'replace_with_children', 'reset', 'select', 'select_one', 'setup', 'smooth', 'string', 'string_container', 'string_container_stack', 'strings', 'stripped_strings', 'tagStack', 'text', 'unwrap', 'wrap']

# %%
bsObject.body
# Out:
# <body>
# <!-- header -->
# <div class="sub_header header-dev" id="JS_bank_header">
# <div id="header-dev-top"></div>
# <div class="sub_menu JS_popup_scroll_fix">
# <div class="s_menu">
# <div class="s_menu_l">
# <ul>
# <li><a class="on" href="/exchange/saving/index.php">절약하기</a></li>
# <li><a class="first" href="/exchange/bank/index.php">은행별 환율</a></li>
# <li><a class="" href="/exchange/map/index.php">가까운 환전소</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <script src="/dev-js/header.js?d=1684730059" type="text/javascript"></script>
# <!--// header --><div class="saving_map_pop" id="map_popup" style="display: none;">
# <table>
# <caption>saving 지도레이어</caption>
# <colgroup>
# <col width="674px"/>
# <col width="249px"/>
# </colgroup>
# <tbody>
# <tr>
# <td><div id="map_view" style="width: 674px; height:509px;"></div></td>
# <td class="map_result">
# <!-- 본점 지점 리스트 정보 //-->
# <div id="JS_bank_info" style="display: none;">
# <div class="map_head">
# <div class="bank_logo">
# <!-- img src="/images/mibank/ico_wrbank.png" alt="우리은행" -->
# </div>
# <div class="bank_num">
# <!-- <span>서울 중구</span>의 '<span>우리은행</span>' 총 <span class="num">10</span>건 -->
# </div>
# </div>
# <div class="map_info">
# <ul>
# <li class="map_info_sign">
# <p>
# 										지점별 상세정보를 보시려면<br/>지도의 핀 아이콘을 클릭하세요.									</p>
# </li>
# </ul>
# </div>
# </div>
# <!-- 지점정보 //-->
# <div id="JS_branch_info" style="display: none;"></div>
# </td>
# </tr>
# </tbody>
# </table>
# <p class="pop_close">
# <a class="close" href="#none"><img alt="창닫기" src="/images/mibank/ic_close_but.gif"/></a>
# </p>
# </div>
# <!--<script type="text/javascript" src="//apis.daum.net/maps/maps3.js?apikey=2a439b072176fd863f0f96ddfcf60405f340118b" charset="utf-8"></script>-->
# <script src="//dapi.kakao.com/v2/maps/sdk.js?appkey=a3876d95ecb22374950c424abde4e1c4" type="text/javascript"></script>
# <script type="text/javascript">
# //전역변수
# var search = { //검색조건
# 	"cu_code": "",
# 	"data_type": "",
# 	"bank_code": ""
# };
# var obj = { //object
# 	"map": null,
# 	"points": [],
# 	"bounds": null,
# 	"marker": [],
# 	"infowindow": []
# };
# var data = { //데이터
# 	"list": []
# };
#
# //팝업
# var daum_map_popup = MKpopup({"selector": "map_popup", "header": "N"});
#
# //주소값 -> 좌표 변환
# var getLngLat = function(options) {
# 	if(typeof options.address == 'undefined') return;
# 	var address = options.address;
# 	var lng = '';
# 	var lat = '';
# 	$.ajax({
# 		url : '//apis.daum.net/local/geo/addr2coord',
# 		async: false, //비동기 여부
# 		type : 'get',
# 		data : {"apikey": "0a141d8dd522330f6d33f95bcde476c4677ef750", "q": address, "output": "json"},
# 		beforeSend: function() {
# 			//요청전
# 		},
# 		complete: function() {
# 			//요청완료
# 		},
# 		error: function() {
# 			//요청실패
# 		},
# 		dataType: "jsonp",
# 		jsonp : "callback",
# 		success: function(json) {
# 			//console.log(json);
# 			if(json.channel && json.channel.result > 0) {
# 				lng = json.channel.item[0].lng; //경도
# 				lat = json.channel.item[0].lat; //위도
# 			}
# 		}
# 	});
#
# 	return {"lng": lng, "lat": lat};
# };
#
# //지도로딩
# var setMap = function(options) {
# 	if(typeof options.lng == 'undefined' || typeof options.lat == 'undefined') return;
# 	var lng = options.lng; //경도
# 	var lat = options.lat; //위도
#
# 	//지도 출력 div
# 	var map_view = $('#map_view')[0];
#
# 	//기본 지도 설정
# 	obj.map = new daum.maps.Map(map_view, {
# 		center: new daum.maps.LatLng(lat, lng), //중심 좌표
# 		level: 4, //확대 수준
# 		draggable: true //마우스로 드래그하여 시점을 변경 가능한지의 여부
# 	});
#
# 	//컨트롤
# 	var zoomControl = new daum.maps.ZoomControl();
# 	obj.map.addControl(zoomControl, daum.maps.ControlPosition.RIGHT);
# 	var mapTypeControl = new daum.maps.MapTypeControl();
# 	obj.map.addControl(mapTypeControl, daum.maps.ControlPosition.TOPRIGHT);
# };
#
# //지점 정보 보기
# var setBranchView = function(index) {
# 	var JS_bank_info = $('#JS_bank_info');
# 	var JS_branch_info = $('#JS_branch_info');
# 	var div = JS_branch_info.find('> div');
#
# 	JS_bank_info.hide();
# 	JS_branch_info.show();
# 	div.hide();
# 	div.filter('#JS_branch_' + index).fadeIn('fast');
# };
#
# //지점 리스트 생성
# var setCreateBranchList = function() {
# 	var index = 0;
# 	var max = data.list.length;
# 	var JS_bank_info = $('#JS_bank_info'); //지점정보
# 	var JS_branch_info = $('#JS_branch_info'); //지점리스트
#
# 	//초기화
# 	//console.log('obj.marker.length: ' + obj.marker.length);
# 	if(obj.marker.length > 0) {
# 		//지도 부분
# 		for(var loop in obj.marker) {
# 			if(typeof obj.marker[loop] != 'undefined') obj.marker[loop].setMap(null);
# 		}
# 		obj.points = [];
# 		obj.bounds = [];
# 		obj.marker = [];
# 	}
#
# 	//리스트 표시
# 	if(max <= 0) {
# 		//기존 초기화
# 		JS_bank_info.hide();
# 		JS_branch_info.hide();
# 		alert('해당 지역에는 선택하신 은행의 지점이 없습니다.');
# 		daum_map_popup.close();
# 		return;
# 	}else {
# 		//지도생성
# 		if(obj.map == null || typeof obj.map != 'object') {
# 			setMap({"lng": data.list[0].longitude, "lat": data.list[0].latitude});
# 		}
# 		//지도를 재설정할 범위정보를 가지고 있을 LatLngBounds 객체를 생성
# 		obj.bounds = new daum.maps.LatLngBounds();
# 		//지점표시
# 		var html = '';
# 		for( ; index<max; index++) {
#
# 			// ---------- Map ---------- //
#
# 			//좌표설정
# 			obj.points[index] = new daum.maps.LatLng(data.list[index].latitude, data.list[index].longitude);
#
# 			//LatLngBounds 객체에 좌표를 추가
# 			obj.bounds.extend(obj.points[index]);
#
# 			//마커설정
# 			obj.marker[index] = new daum.maps.Marker({
# 				position: obj.points[index]
# 			});
# 			obj.marker[index].setMap(obj.map);
#
# 			//인포윈도우 설정
# 			obj.infowindow[index] = new daum.maps.InfoWindow({
# 				position : obj.points[index],
# 				content : data.list[index].branch_name
# 			});
#
# 			//이벤트
# 			(function(num) {
# 				//var points = obj.points[num];
# 				var marker = obj.marker[num];
# 				//var custom_overlay = obj.custom_overlay[num];
# 				var infowindow = obj.infowindow[num];
# 				daum.maps.event.addListener(marker, 'click', function() { //클릭
# 					setBranchView(num);
# 				});
#
# 				daum.maps.event.addListener(marker, 'mouseover', function() { //마커에 마우스오버 이벤트
# 					infowindow.open(obj.map, marker);
# 				});
# 				daum.maps.event.addListener(marker, 'mouseout', function() { //마커에 마우스아웃 이벤트
# 					infowindow.close();
# 				});
#
# 			})(index);
#
# 			// ---------- ul ---------- //
#
# 			//지점
# 			html += decodeURIComponent(data.list[index].html);
# 		}
# 		obj.map.setBounds(obj.bounds);
# 		JS_branch_info.html(html);
#
# 		//지점이 하나의 경우
# 		if(max == 1) {
# 			setBranchView(0);
# 		}else {
# 			var bank_logo = JS_bank_info.find('.bank_logo');
# 			bank_logo.empty();
# 			if(data.list[0].branch_image) {
# 				bank_logo.html('<img src="' + data.list[0].branch_image + '" alt="">');
# 			}
# 			var bank_name = data.list[0].bank_name || data.list[0].branch_name || '';
# 			var bank_num = JS_bank_info.find('.bank_num');
# 			var sido = $('#sido_code').find('option').filter(':selected').text();
# 			var gugun = $('#gugun_code').find('option').filter(':selected').text();
# 			var tmp = [];
# 			var address = '';
# 			if(sido != '') tmp.push(sido);
# 			if(gugun != '') tmp.push(gugun);
#
# 			if(tmp.length > 0) address = '<span>' + tmp.join(' ') + '</span>의 ';
# 			bank_num.empty();
# 			bank_num.html(address + '\'<span>' + bank_name + '</span>\' 총 <span class="num">' + max + '</span>건');
#
# 			JS_branch_info.hide();
# 			JS_bank_info.fadeIn('fast');
# 		}
# 	}
# };
#
# //환전소 정보
# var getExchangeBranch = function(options) {
# 	var options = options || {};
#
# 	daum_map_popup.open({"callback": function() {
# 		$.ajax({
# 			url : '/ajax/select_branch_list_exchange.php',
# 			//async: false, //비동기 여부
# 			type : 'post',
# 			data : options,
# 			beforeSend: function() {
# 				//요청전
# 			},
# 			complete: function() {
# 				//요청완료
# 			},
# 			error: function() {
# 				//요청실패
# 			},
# 			//dataType: "jsonp",
# 			//jsonp : "callback",
# 			success: function(json) {
# 				//console.dir(json);
# 				if(json.msg == 'success') {
# 					//지도에 좌표표시
# 					data.list = json.data;
# 					setCreateBranchList(); //지점 리스트
# 				}
# 			}
# 		});
# 	}});
# };
#
# //지점 정보
# var getBranchMap = function(options, type) {
# 	var options = options || {};
# 	var type = type || '';
#
# 	if(type == 'loan') {
# 		daum_map_popup.open({"callback": function() {
# 			$.ajax({
# 				url : '/ajax/select_branch_list_loan.php',
# 				//async: false, //비동기 여부
# 				type : 'post',
# 				data : options,
# 				beforeSend: function() {
# 					//요청전
# 				},
# 				complete: function() {
# 					//요청완료
# 				},
# 				error: function() {
# 					//요청실패
# 				},
# 				//dataType: "jsonp",
# 				//jsonp : "callback",
# 				success: function(json) {
# 					//console.dir(json);
# 					if(json.msg == 'success') {
# 						//지도에 좌표표시
# 						data.list = json.data;
# 						setCreateBranchList(); //지점 리스트
# 					}
# 				}
# 			});
# 		}});
# 	}else if(type == 'deposit') {
# 		daum_map_popup.open({"callback": function() {
# 			$.ajax({
# 				url : '/ajax/select_branch_list_deposit.php',
# 				//async: false, //비동기 여부
# 				type : 'post',
# 				data : options,
# 				beforeSend: function() {
# 					//요청전
# 				},
# 				complete: function() {
# 					//요청완료
# 				},
# 				error: function() {
# 					//요청실패
# 				},
# 				//dataType: "jsonp",
# 				//jsonp : "callback",
# 				success: function(json) {
# 					//console.dir(json);
# 					if(json.msg == 'success') {
# 						//지도에 좌표표시
# 						data.list = json.data;
# 						setCreateBranchList(); //지점 리스트
# 					}
# 				}
# 			});
# 		}});
# 	}
# };
# </script> <script type="text/javascript">
#         //구글
#         ga('send', 'event', 'ko.Saving', 'currency', 'USD'); //통화별 클릭수
#
#         var setSearch = function(){
#             $('#search_form')[0].submit();
#         };
#         var setDiscountView = function() {
#             var popup_discount_all = $('#JS_discount_all');
#             var popup_discount_list = $('.JS_discount_list');
#             var search_form = $('#search_form');
#             var form_discount_all = search_form.find('[name="discount_all"]');
#             var form_discount_list = search_form.find('[name="discount_list"]');
#
#             //초기화
#             form_discount_all.val('');
#             form_discount_list.val('');
#             //값 검사
#             var arr = [];
#             if(MKvalidate.isNumber(popup_discount_all)) {
#                 var value = popup_discount_all.val();
#                 form_discount_all.val(value);
#             }else {
#                 popup_discount_list.each(function() {
#                     var that = $(this);
#                     var value = that.val();
#                     var code = that.data('code').replace('CODE', ''); //자바스크립트의 자동 Number 타입 변환을 방지하기 위해 CODE라는 문자열 값을 넣어주었음.
#                     if(MKvalidate.isNumber(that) && value > 0) {
#                         arr.push(code + '|' + value);
#                     }
#                 });
#                 form_discount_list.val(arr.join(','));
#             }
#             setSearch();
#         };
#
#         $(document).ready(function() {
#             //주소
#             var sido_code = $('#sido_code');
#             var gugun_code = $('#gugun_code');
#             var getGugun = function(code) {
#                 if(!code) return;
#                 $.ajax({
#                     url : '/ajax/select_gugun.php',
#                     type : 'post',
#                     data : {"code": code},
#                     beforeSend: function() {
#                         //요청전
#                     },
#                     complete: function() {
#                         //요청완료
#                     },
#                     error: function() {
#                         //요청실패
#                     },
#                     success: function(json) {
#                         if(!json) return;
#                         if(json['msg'] == 'success') {
#                             var select = '';
#                             var arr = [];
#                             for(var i=0, max=json.data.length; i<max; i++) {
#                                 arr.push('<option value="' + json.data[i]['gugun_code'] + '" ' + (select == json.data[i]['gugun_code'] ? 'selected="selected"' : '') + '>' + decodeURIComponent(json.data[i]['name_ko']) + '</option>');
#                             }
#                             gugun_code.append(arr.join(''));
#                         }else {
#                             alert('데이터 전송 중 오류가 발생했습니다.');
#                         }
#                     }
#                 });
#             };
#             sido_code.on('change', function() {
#                 var val = $(this).find('option:selected').val();
#                 //select 초기화
#                 gugun_code.find('option:not(:eq(0))').remove();
#                 if(val) {
#                     getGugun(val);
#                 }
#             });
#             getGugun(9);
#             //지도
#             $('.JS_map_view').on('click', function() {
#                 var that = $(this);
#                 var option = {
#                     "bank_code": that.attr('data-bank_code'), //은행 고유값은 숫자로 시작
#                     "branch_code": that.data('branch_code'),
#                     "cu_code": that.data('cu_code'),
#                     "data_type": that.data('data_type'),
#                     "sido_code": that.data('sido_code'),
#                     "gugun_code": that.data('gugun_code')
#                 };
#
#                 getExchangeBranch(option);
#
#                 //구글
#                 ga('send', 'event', 'ko.Saving', 'map_view', option.cu_code);
#                 ga('send', 'event', 'ko.ExchangeStation', option.cu_code, option.branch_code);
#             });
#
#             //할인율 팝업
#             var discount_popup = MKpopup({'selector': 'discount_popup', 'header': 'N', 'mask': 'Y'});
#             $('.JS_discount_open_btn').on('click', function() {
#                 discount_popup.open();
#             });
#
#             //할인율 입력
#             var JS_discount_all = $('#JS_discount_all');
#             var JS_discount_list = $('.JS_discount_list');
#             $(JS_discount_all).on('keyup', function() {
#                 var val = $(this).val();
#                 if(val != '' && !MKvalidate.isNumber(val)) {
#                     alert('숫자만 입력 가능합니다.');
#                     return;
#                 }else if(Number(val) > 100) {
#                     val = val.slice(0, -1);
#                     JS_discount_all.val(val);
#                 }
#                 JS_discount_list.val(val);
#             });
#             JS_discount_list.on('keyup', function() {
#                 var val = $.trim($(this).val());
#                 if(val != '' && !MKvalidate.isNumber(val)) {
#                     alert('숫자만 입력 가능합니다.');
#                     return;
#                 }else if(Number(val) > 100) {
#                     val = val.slice(0, -1);
#                     $(this).val(val);
#                 }
#                 if(val !== '') {
#                     JS_discount_all.val('');
#                     //JS_discount_list.not(this).val('');
#                 }
#             });
#
#             //enter event
#             setEnterEvent(JS_discount_all, setDiscountView);
#             setEnterEvent(JS_discount_list, setDiscountView);
#
#             //우대쿠폰 팝업
#             var coupon_popup = MKpopup({'selector': 'coupon_popup', 'header': 'N', 'mask': 'Y'});
#             $('.JS_coupon_open_btn').on('click', function() {
#                 coupon_popup.open();
#             });
#
#             //서브메뉴 보이기/숨기기
#             var JS_toggleList = $('.JS_toggleList');
#             $('.JS_toggle_btn').on('click', function() {
#                 var index = $(this).data('index');
#                 JS_toggleList.filter('[data-index="' + index + '"]').slideToggle();
#             });
#
#             //입력값 초기화
#             $('#money_input').on('focus', function() {
#                 $(this).val('');
#             });
#
#             //입력값 콤마
#             var setMoneyInputFormat = function() {
#                 var regNumber = /^[0-9]*$/;
#                 if(!regNumber.test($("#money_input_check").val())) {
#                     alert('숫자를 입력해주세요.');
#                     $("#money_input").val('');
#                     $("#money_input_check").val('');
#                     return;
#                 }
#                 var money_input = $('#money_input');
#                 var val1 = remove_comma($.trim(money_input.val()));
#                 //var val2 = number_format(val1);
#                 var val2 = float_format(val1);
#                 $('input[name="money"]').val(val1);
#                 money_input.val(val2);
#             };
#             $('#money_input').on('keyup', function() {
#                 $("#money_input_check").val(remove_comma($("#money_input").val()));
#                 setMoneyInputFormat();
#             });
#             setMoneyInputFormat(); //초기화
#         });
#     </script>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <!-- 할인율 입력 //-->
# <div class="popup_layer" id="discount_popup" style="display: none;background-color: #FFF;">
# <div class="pop1">
# <form>
# <table border="0" cellspacing="0" class="table_style02" summary="할인율 입력을 위한 은행 리스트입니다.">
# <caption class="pop_title02">
# <img alt="할인율 입력" src="/images/mibank/ko/t_input_discount.png">
# </img></caption>
# <tr>
# <th class="left" scope="row" style="width: 53.5%"><label for="all"><img alt="일괄적용" src="/images/mibank/ko/all_apply.png"/> </label></th>
# <td>
# <input class="input_style3" id="JS_discount_all" name="discount[]" title="일괄적용" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank0"><img alt="KEB하나은행" src="/images/mibank/ko/ico_kbbank_2015.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE005" id="bank0" name="discount[]" title="KEB하나은행 우대쿠폰 할인율 입력" type="text" value="">
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </input></td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank1"><img alt="우리은행" src="/images/mibank/ko/ico_wrbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE020" id="bank1" name="discount[]" title="우리은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank2"><img alt="KB국민은행" src="/images/mibank/ko/ico_kbbbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE004" id="bank2" name="discount[]" title="KB국민은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank3"><img alt="신한은행" src="/images/mibank/ko/ico_shbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE088" id="bank3" name="discount[]" title="신한은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank4"><img alt="NH농협은행" src="/images/mibank/ko/ico_nhbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE011" id="bank4" name="discount[]" title="NH농협은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank5"><img alt="기업은행" src="/images/mibank/ko/ico_ibkbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE003" id="bank5" name="discount[]" title="기업은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank6"><img alt="한국스탠다드차타드은행" src="/images/mibank/ko/ico_scbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE023" id="bank6" name="discount[]" title="한국스탠다드차타드은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank7"><img alt="한국씨티은행" src="/images/mibank/ko/ico_ctbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE027" id="bank7" name="discount[]" title="한국씨티은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank8"><img alt="수협은행" src="/images/mibank/ko/ico_shkbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE007" id="bank8" name="discount[]" title="수협은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank9"><img alt="부산은행" src="/images/mibank/ko/ico_bsbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE032" id="bank9" name="discount[]" title="부산은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank10"><img alt="대구은행" src="/images/mibank/ko/ico_dgbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE031" id="bank10" name="discount[]" title="대구은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank11"><img alt="전북은행" src="/images/mibank/ko/ico_jbbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE037" id="bank11" name="discount[]" title="전북은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank12"><img alt="경남은행" src="/images/mibank/ko/ico_knbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE039" id="bank12" name="discount[]" title="경남은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank13"><img alt="제주은행" src="/images/mibank/ko/ico_jjbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE035" id="bank13" name="discount[]" title="제주은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# </table>
# </form>
# <div class="pop_close_saving">
# <a class="close" href="#none"><img alt="닫기" src="/images/mibank/ko/bt_layer_close.png"/></a>
# </div>
# <!-- 2014.11.03-->
# <p class="bt_center_pop">
# <a class="close" href="#none"><img alt="취소" src="/images/mibank/ko/canceled.png"/></a>
# <a href="#none" onclick="setDiscountView()"><img alt="확인" src="/images/mibank/ko/finished.png"/></a>
# </p>
# <!--// 2014.11.03-->
# <br/>
# </div>
# </div>
# <!-- 우대쿠폰 //-->
# <div class="popup_layer" id="coupon_popup" style="display: none; background-color: #FFF;">
# <div class="pop2">
# <ul>
# <li class="pop_title02"><span class="pop_title02"><img alt="우대쿠폰" src="/images/mibank/ko/t_good_coupon.png"/></span></li>
# <li class="good_coupon">
# <a href="http://www.keb.co.kr/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '005');" target="_blank"><img alt="KEB하나은행" src="/images/mibank/ko/ico_kbbank_2015.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="https://www.wooribank.com/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '020');" target="_blank"><img alt="우리은행" src="/images/mibank/ko/ico_wrbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="https://www.kbstar.com/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '004');" target="_blank"><img alt="KB국민은행" src="/images/mibank/ko/ico_kbbbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="http://www.shinhan.com/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '088');" target="_blank"><img alt="신한은행" src="/images/mibank/ko/ico_shbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="https://banking.nonghyup.com/nhbank.html" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '011');" target="_blank"><img alt="NH농협은행" src="/images/mibank/ko/ico_nhbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="http://www.ibk.co.kr/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '003');" target="_blank"><img alt="기업은행" src="/images/mibank/ko/ico_ibkbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="http://www.standardchartered.co.kr/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '023');" target="_blank"><img alt="한국스탠다드차타드은행" src="/images/mibank/ko/ico_scbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="http://www.citibank.co.kr/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '027');" target="_blank"><img alt="한국씨티은행" src="/images/mibank/ko/ico_ctbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="https://www.suhyup-bank.com/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '007');" target="_blank"><img alt="수협은행" src="/images/mibank/ko/ico_shkbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="http://www.busanbank.co.kr/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '032');" target="_blank"><img alt="부산은행" src="/images/mibank/ko/ico_bsbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="https://www.dgb.co.kr/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '031');" target="_blank"><img alt="대구은행" src="/images/mibank/ko/ico_dgbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="https://www.jbbank.co.kr/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '037');" target="_blank"><img alt="전북은행" src="/images/mibank/ko/ico_jbbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="http://www.knbank.co.kr/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '039');" target="_blank"><img alt="경남은행" src="/images/mibank/ko/ico_knbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="https://www.e-jejubank.com/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '035');" target="_blank"><img alt="제주은행" src="/images/mibank/ko/ico_jjbank.png"/></a>
# </li>
# </ul>
# <div class="pop_close_saving">
# <a class="close" href="#none"><img alt="닫기" src="/images/mibank/ko/bt_layer_close.png"/></a>
# </div>
# </div>
# </div>
# <!-- container -->
# <div class="container_sub_banks_saving">
# <!-- left -->
# <div class="left_menu">
# <div class="world_first JS_toggle_btn" data-index="1" style="display:none;">
# 			주요국<a href="#none"><img alt="카테고리 접기" class="saving_cat_arrow" src="/images/mibank/ko/bt_close.png"/></a>
# </div>
# <ul class="menulist1 JS_toggleList" data-index="1">
# <li class=""><a href="/exchange/saving/index.php?currency=CNY"><img alt="중국" src="/images/mibank/ko/CNY.png"/>중국</a></li><li class=""><a href="/exchange/saving/index.php?currency=JPY"><img alt="일본" src="/images/mibank/ko/JPY.png"/>일본</a></li><li class="on"><a href="/exchange/saving/index.php?currency=USD"><img alt="미국" src="/images/mibank/ko/USD.png"/>미국</a></li><li class=""><a href="/exchange/saving/index.php?currency=EUR"><img alt="유럽연합" src="/images/mibank/ko/EUR.png"/>유럽연합</a></li><li class=""><a href="/exchange/saving/index.php?currency=HKD"><img alt="홍콩" src="/images/mibank/ko/HKD.png"/>홍콩</a></li><li class=""><a href="/exchange/saving/index.php?currency=TWD"><img alt="대만" src="/images/mibank/ko/TWD.png"/>대만</a></li><li class=""><a href="/exchange/saving/index.php?currency=SGD"><img alt="싱가폴" src="/images/mibank/ko/SGD.png"/>싱가폴</a></li><li class=""><a href="/exchange/saving/index.php?currency=THB"><img alt="태국" src="/images/mibank/ko/THB.png"/>태국</a></li><li class=""><a href="/exchange/saving/index.php?currency=PHP"><img alt="필리핀" src="/images/mibank/ko/PHP.png"/>필리핀</a></li><li class=""><a href="/exchange/saving/index.php?currency=VND"><img alt="베트남" src="/images/mibank/ko/VND.png"/>베트남</a></li><li class=""><a href="/exchange/saving/index.php?currency=GBP"><img alt="영국" src="/images/mibank/ko/GBP.png"/>영국</a></li><li class=""><a href="/exchange/saving/index.php?currency=AUD"><img alt="호주" src="/images/mibank/ko/AUD.png"/>호주</a></li>
# </ul>
# <div class="world JS_toggle_btn" data-index="2" style="display:none;">
# 			미주<a href="#none"><img alt="카테고리 접기" class="saving_cat_arrow" src="/images/mibank/ko/bt_close.png"/></a>
# </div>
# <ul class="menulist1 JS_toggleList" data-index="2">
# <li class=""><a href="/exchange/saving/index.php?currency=CAD"><img alt="캐나다" src="/images/mibank/ko/CAD.png"/>캐나다</a></li><li class=""><a href="/exchange/saving/index.php?currency=BRL"><img alt="브라질" src="/images/mibank/ko/BRL.png"/>브라질</a></li><li class=""><a href="/exchange/saving/index.php?currency=CLP"><img alt="칠레" src="/images/mibank/ko/CLP.png"/>칠레</a></li><li class=""><a href="/exchange/saving/index.php?currency=MXN"><img alt="멕시코" src="/images/mibank/ko/MXN.png"/>멕시코</a></li>
# </ul>
# <div class="world JS_toggle_btn" data-index="3" style="display:none;">
# 			오세아니아<a href="#none"><img alt="카테고리 접기" class="saving_cat_arrow" src="/images/mibank/ko/bt_close.png"/></a>
# </div>
# <ul class="menulist1 JS_toggleList" data-index="3">
# <li class=""><a href="/exchange/saving/index.php?currency=NZD"><img alt="뉴질랜드" src="/images/mibank/ko/NZD.png"/>뉴질랜드</a></li>
# </ul>
# <div class="world JS_toggle_btn" data-index="4" style="display:none;">
# 			아시아<a href="#none"><img alt="카테고리 접기" class="saving_cat_arrow" src="/images/mibank/ko/bt_close.png"/></a>
# </div>
# <ul class="menulist1 JS_toggleList" data-index="4">
# <li class=""><a href="/exchange/saving/index.php?currency=IDR"><img alt="인도네시아" src="/images/mibank/ko/IDR.png"/>인도네시아</a></li><li class=""><a href="/exchange/saving/index.php?currency=MYR"><img alt="말레이시아" src="/images/mibank/ko/MYR.png"/>말레이시아</a></li><li class=""><a href="/exchange/saving/index.php?currency=TRY"><img alt="터키" src="/images/mibank/ko/TRY.png"/>터키</a></li><li class=""><a href="/exchange/saving/index.php?currency=INR"><img alt="인도" src="/images/mibank/ko/INR.png"/>인도</a></li><li class=""><a href="/exchange/saving/index.php?currency=MNT"><img alt="몽골" src="/images/mibank/ko/MNT.png"/>몽골</a></li><li class=""><a href="/exchange/saving/index.php?currency=ILS"><img alt="이스라엘" src="/images/mibank/ko/ILS.png"/>이스라엘</a></li><li class=""><a href="/exchange/saving/index.php?currency=SAR"><img alt="사우디" src="/images/mibank/ko/SAR.png"/>사우디</a></li><li class=""><a href="/exchange/saving/index.php?currency=KWD"><img alt="쿠웨이트" src="/images/mibank/ko/KWD.png"/>쿠웨이트</a></li><li class=""><a href="/exchange/saving/index.php?currency=BHD"><img alt="바레인" src="/images/mibank/ko/BHD.png"/>바레인</a></li><li class=""><a href="/exchange/saving/index.php?currency=AED"><img alt="U.A.E" src="/images/mibank/ko/AED.png"/>U.A.E</a></li><li class=""><a href="/exchange/saving/index.php?currency=KZT"><img alt="카자흐스탄" src="/images/mibank/ko/KZT.png"/>카자흐스탄</a></li><li class=""><a href="/exchange/saving/index.php?currency=QAR"><img alt="카타르" src="/images/mibank/ko/QAR.png"/>카타르</a></li><li class=""><a href="/exchange/saving/index.php?currency=PKR"><img alt="파키스탄" src="/images/mibank/ko/PKR.png"/>파키스탄</a></li><li class=""><a href="/exchange/saving/index.php?currency=BDT"><img alt="방글라데시" src="/images/mibank/ko/BDT.png"/>방글라데시</a></li><li class=""><a href="/exchange/saving/index.php?currency=BND"><img alt="브루나이" src="/images/mibank/ko/BND.png"/>브루나이</a></li><li class=""><a href="/exchange/saving/index.php?currency=OMR"><img alt="오만" src="/images/mibank/ko/OMR.png"/>오만</a></li><li class=""><a href="/exchange/saving/index.php?currency=JOD"><img alt="요르단" src="/images/mibank/ko/JOD.png"/>요르단</a></li>
# </ul>
# <div class="world JS_toggle_btn" data-index="5" style="display:none;">
# 			유럽<a href="#none"><img alt="카테고리 접기" class="saving_cat_arrow" src="/images/mibank/ko/bt_close.png"/></a>
# </div>
# <ul class="menulist1 JS_toggleList" data-index="5">
# <li class=""><a href="/exchange/saving/index.php?currency=CHF"><img alt="스위스" src="/images/mibank/ko/CHF.png"/>스위스</a></li><li class=""><a href="/exchange/saving/index.php?currency=RUB"><img alt="러시아" src="/images/mibank/ko/RUB.png"/>러시아</a></li><li class=""><a href="/exchange/saving/index.php?currency=SEK"><img alt="스웨덴" src="/images/mibank/ko/SEK.png"/>스웨덴</a></li><li class=""><a href="/exchange/saving/index.php?currency=DKK"><img alt="덴마크" src="/images/mibank/ko/DKK.png"/>덴마크</a></li><li class=""><a href="/exchange/saving/index.php?currency=NOK"><img alt="노르웨이" src="/images/mibank/ko/NOK.png"/>노르웨이</a></li><li class=""><a href="/exchange/saving/index.php?currency=HUF"><img alt="헝가리" src="/images/mibank/ko/HUF.png"/>헝가리</a></li><li class=""><a href="/exchange/saving/index.php?currency=CZK"><img alt="체코" src="/images/mibank/ko/CZK.png"/>체코</a></li><li class=""><a href="/exchange/saving/index.php?currency=PLN"><img alt="폴란드" src="/images/mibank/ko/PLN.png"/>폴란드</a></li>
# </ul>
# <div class="world JS_toggle_btn" data-index="6" style="display:none;">
# 			아프리카<a href="#none"><img alt="카테고리 접기" class="saving_cat_arrow" src="/images/mibank/ko/bt_close.png"/></a>
# </div>
# <ul class="menulist1 JS_toggleList" data-index="6">
# <li class=""><a href="/exchange/saving/index.php?currency=ZAR"><img alt="남아공" src="/images/mibank/ko/ZAR.png"/>남아공</a></li><li class=""><a href="/exchange/saving/index.php?currency=EGP"><img alt="이집트" src="/images/mibank/ko/EGP.png"/>이집트</a></li>
# </ul>
# </div>
# <!--// left -->
# <!-- right -->
# <div class="right_contents">
# <h3 class="title_saving">
# <img alt="미국" src="/images/mibank/ko/USD_03.png"/>
# </h3>
# <div class="box_table01_saving">
# <form action="/exchange/saving/index.php?currency=USD" id="search_form" method="post">
# <!-- 할인율 //-->
# <input name="discount_all" type="hidden" value=""/>
# <input name="discount_list" type="hidden" value=""/>
# <input name="money" type="hidden" value="1"/>
# <div class="box_dummy2">
# <div class="right_box_1st">
# <select class="selectBox02" id="rate_standard" name="standard" title="옵션 선택">
# <option selected="selected" value="cash_buy">현찰 살 때</option>
# <option value="cash_sell">현찰 팔 때</option>
# <option value="t_m_send">송금 보낼 때</option>
# <!-- option value="t_m_receive">송금 받을때</option -->
# <!-- option value="b_exchn_rate">매매기준율</option -->
# </select>
# </div>
# <select class="selectBox" id="sido_code" name="sido" title="지역 선택">
# <!-- option value="">전국</option -->
# <option selected="selected" value="9">서울</option>
# <option value="8">부산</option>
# <option value="6">대구</option>
# <option value="12">인천</option>
# <option value="5">광주</option>
# <option value="7">대전</option>
# <option value="11">울산</option>
# <option value="2">경기도</option>
# <option value="1">강원도</option>
# <option value="17">충청북도</option>
# <option value="16">충청남도</option>
# <option value="14">전라북도</option>
# <option value="13">전라남도</option>
# <option value="4">경상북도</option>
# <option value="3">경상남도</option>
# <option value="15">제주도</option>
# <option value="10">세종시</option>
# </select>
# <select class="selectBox" id="gugun_code" name="gugun" title="지역 세부 선택">
# <option value="">전체</option>
# </select>
# <label class="blind" for="money_input">대한민국원</label>
# <div class="input_wrap2">
# <input id="money_input_check" type="hidden"/>
# <input class="input_style2_on" id="money_input" name="money_input" style="vertical-align: middle;" title="금액 입력" type="text" value="1"/>
# <span class="monetary_05">$</span>
# </div>
# <a class="btn_confirm" href="#none" onclick="setSearch()">확인</a>
# </div>
# </form>
# <p class="bt_center_saving">
# <a class="JS_discount_open_btn" href="#none">우대쿠폰으로 다시 계산</a>
# </p>
# </div>
# <div class="box_contents1">
# <!-- h5 class="update">
# 			<img src="/images/mibank/ko/txt_update.png" alt="UPDATE" width="53" height="13" />2014. 09. 21 14:25
# 		</h5 -->
# <!-- 수정 14.10.13 -->
# <table border="1" cellspacing="0" class="table_style01 exchange_saving tb_action" summary="나라별 통화 환산리스트">
# <caption>나라별 통화 환산리스트</caption>
# <colgroup>
# <col width="6%"/>
# <col width="24%"/>
# <col width="17%"/>
# <col width="16%"/>
# <col width="16%"/>
# <col width="21%"/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col"></th>
# <th class="left" scope="col">환전소</th>
# <th class="txt_em" scope="col">환율</th>
# <th class="txt_em" scope="col">
#                                 절약금액                                <div class="layer_help_position"><a class="JS_layer_toggle" data-layer-target="JS_layer_loan_common" href="#none"><img alt="도움말" class="table_tit_help" src="/images/mibank/ko/ico_click_help_on.png"/></a>
# <p class="JS_layer_loan_common layer_help5" style="display: none; width:159px;">
#                                         가장 불리한 환전소와 비교시 절약되는 금액임                                    </p>
# </div>
# </th>
# <th class="txt_em" scope="col">절약율</th>
# <!-- <th scope="col">환전하기</th> -->
# <!-- 2017.06.08 - 이세이 - 개발요청 : 환전하기(+) 기능 삭제 및 UPDATE 기능 추가 -->
# <th scope="col">UPDATE</th>
# </tr>
# <tr>
# </tr></thead>
# <tbody>
# <!-- 2017.06.26. J. update
#                     <tr>
#                         <td class="text_none left_none"></td>
#                         <td class="text_none"></td>
#                         <td class="text_none"></td>
#                         <td class="text_none"></td>
#                         <td class="text_none"></td>
#                         <td class="text_none right_none"></td>
#                     </tr>
#                      -->
# <tr>
# <td class="first box box_left"><img alt="Best" src="/images/mibank/ko/ico_best.png"/></td>
# <td class="second box">
# <span class="bank_name"><a class="JS_map_view" data-bank_code="000" data-branch_code="7883" data-cu_code="USD" data-data_type="cash_buy" data-gugun_code="240" data-sido_code="9" href="#none">나이스환전금융</a></span> </td>
# <td class="right counter txt_em box">1318</td>
# <td class="right counter txt_em box">22.69</td>
# <td class="right counter txt_em box">1.69</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="000" data-branch_code="7883" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code="240"></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"><!-- <img src="/images/mibank/ko/ico_up.png" alt="up"> // 2017.06.26. J. update --></td>
# <td class="second">
# <span class="bank_name"><a class="JS_map_view" data-bank_code="000" data-branch_code="16309" data-cu_code="USD" data-data_type="cash_buy" data-gugun_code="240" data-sido_code="9" href="#none">[을지로6가] 포인트환전소</a></span> </td>
# <td class="right counter txt_em">1318</td>
# <td class="right counter txt_em">22.69</td>
# <td class="right counter txt_em">1.69</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="000" data-branch_code="16309" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code="240"></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_name"><a class="JS_map_view" data-bank_code="000" data-branch_code="16331" data-cu_code="USD" data-data_type="cash_buy" data-gugun_code="240" data-sido_code="9" href="#none">고래환전소</a></span> </td>
# <td class="right counter txt_em">1318</td>
# <td class="right counter txt_em">22.69</td>
# <td class="right counter txt_em">1.69</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="000" data-branch_code="16331" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code="240"></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"><!-- <img src="/images/mibank/ko/ico_down.png" alt="down"> // 2017.06.26. J. update --></td>
# <td class="second">
# <span class="bank_name"><a class="JS_map_view" data-bank_code="000" data-branch_code="14590" data-cu_code="USD" data-data_type="cash_buy" data-gugun_code="240" data-sido_code="9" href="#none">동대문OK환전</a></span> </td>
# <td class="right counter txt_em">1319</td>
# <td class="right counter txt_em">21.69</td>
# <td class="right counter txt_em">1.62</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="000" data-branch_code="14590" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code="240"></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"><!-- <img src="/images/mibank/ko/ico_worst.png" alt="Worst"> // 2017.06.26. J. update --></td>
# <td class="second">
# <span class="bank_name"><a class="JS_map_view" data-bank_code="000" data-branch_code="14259" data-cu_code="USD" data-data_type="cash_buy" data-gugun_code="240" data-sido_code="9" href="#none">명동스카이환전</a></span> </td>
# <td class="right counter txt_em">1319</td>
# <td class="right counter txt_em">21.69</td>
# <td class="right counter txt_em">1.62</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="000" data-branch_code="14259" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code="240"></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_name"><a class="JS_map_view" data-bank_code="000" data-branch_code="7899" data-cu_code="USD" data-data_type="cash_buy" data-gugun_code="240" data-sido_code="9" href="#none">동대문환전</a></span> </td>
# <td class="right counter txt_em">1319</td>
# <td class="right counter txt_em">21.69</td>
# <td class="right counter txt_em">1.62</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="000" data-branch_code="7899" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code="240"></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_name"><a class="JS_map_view" data-bank_code="000" data-branch_code="14625" data-cu_code="USD" data-data_type="cash_buy" data-gugun_code="239" data-sido_code="9" href="#none">[종로] 종로환전소</a></span> </td>
# <td class="right counter txt_em">1319</td>
# <td class="right counter txt_em">21.69</td>
# <td class="right counter txt_em">1.62</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="000" data-branch_code="14625" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code="239"></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_name"><a class="JS_map_view" data-bank_code="000" data-branch_code="14607" data-cu_code="USD" data-data_type="cash_buy" data-gugun_code="239" data-sido_code="9" href="#none">베스트환전</a></span> </td>
# <td class="right counter txt_em">1319</td>
# <td class="right counter txt_em">21.69</td>
# <td class="right counter txt_em">1.62</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="000" data-branch_code="14607" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code="239"></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_name"><a class="JS_map_view" data-bank_code="000" data-branch_code="7976" data-cu_code="USD" data-data_type="cash_buy" data-gugun_code="240" data-sido_code="9" href="#none">명동로사환전소</a></span> </td>
# <td class="right counter txt_em">1319</td>
# <td class="right counter txt_em">21.69</td>
# <td class="right counter txt_em">1.62</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="000" data-branch_code="7976" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code="240"></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_name"><a class="JS_map_view" data-bank_code="000" data-branch_code="14604" data-cu_code="USD" data-data_type="cash_buy" data-gugun_code="240" data-sido_code="9" href="#none">한미환전</a></span> </td>
# <td class="right counter txt_em">1320</td>
# <td class="right counter txt_em">20.69</td>
# <td class="right counter txt_em">1.54</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="000" data-branch_code="14604" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code="240"></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_name"><a class="JS_map_view" data-bank_code="000" data-branch_code="16399" data-cu_code="USD" data-data_type="cash_buy" data-gugun_code="237" data-sido_code="9" href="#none">[이태원] 월드환전소</a></span> </td>
# <td class="right counter txt_em">1320</td>
# <td class="right counter txt_em">20.69</td>
# <td class="right counter txt_em">1.54</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="000" data-branch_code="16399" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code="237"></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_name"><a class="JS_map_view" data-bank_code="000" data-branch_code="14601" data-cu_code="USD" data-data_type="cash_buy" data-gugun_code="240" data-sido_code="9" href="#none">명동제일환전센터</a></span> </td>
# <td class="right counter txt_em">1320</td>
# <td class="right counter txt_em">20.69</td>
# <td class="right counter txt_em">1.54</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="000" data-branch_code="14601" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code="240"></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_name"><a class="JS_map_view" data-bank_code="000" data-branch_code="14234" data-cu_code="USD" data-data_type="cash_buy" data-gugun_code="240" data-sido_code="9" href="#none">중앙환전</a></span> </td>
# <td class="right counter txt_em">1320</td>
# <td class="right counter txt_em">20.69</td>
# <td class="right counter txt_em">1.54</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="000" data-branch_code="14234" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code="240"></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_name"><a class="JS_map_view" data-bank_code="000" data-branch_code="16296" data-cu_code="USD" data-data_type="cash_buy" data-gugun_code="240" data-sido_code="9" href="#none">서울상역환전</a></span> </td>
# <td class="right counter txt_em">1320</td>
# <td class="right counter txt_em">20.69</td>
# <td class="right counter txt_em">1.54</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# ...
# <td class="right counter txt_em">15.69</td>
# <td class="right counter txt_em">1.17</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="000" data-branch_code="14617" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code="231"></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_name"><a class="JS_map_view" data-bank_code="000" data-branch_code="14247" data-cu_code="USD" data-data_type="cash_buy" data-gugun_code="240" data-sido_code="9" href="#none">신세계환전소</a></span> </td>
# <td class="right counter txt_em">1325</td>
# <td class="right counter txt_em">15.69</td>
# <td class="right counter txt_em">1.17</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="000" data-branch_code="14247" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code="240"></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=004"><img alt="" src="/images/mibank/ko/ico_kbbbank.png"/></a></span> </td>
# <td class="right counter txt_em">1338.82</td>
# <td class="right counter txt_em">1.87</td>
# <td class="right counter txt_em">0.14</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="004" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=031"><img alt="" src="/images/mibank/ko/ico_dgbank.png"/></a></span> </td>
# <td class="right counter txt_em">1338.82</td>
# <td class="right counter txt_em">1.87</td>
# <td class="right counter txt_em">0.14</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="031" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=005"><img alt="" src="/images/mibank/ko/ico_kbbank_2015.png"/></a></span> </td>
# <td class="right counter txt_em">1338.82</td>
# <td class="right counter txt_em">1.87</td>
# <td class="right counter txt_em">0.14</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="005" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=039"><img alt="" src="/images/mibank/ko/ico_knbank.png"/></a></span> </td>
# <td class="right counter txt_em">1338.82</td>
# <td class="right counter txt_em">1.87</td>
# <td class="right counter txt_em">0.14</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="039" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=027"><img alt="" src="/images/mibank/ko/ico_ctbank.png"/></a></span> </td>
# <td class="right counter txt_em">1338.87</td>
# <td class="right counter txt_em">1.82</td>
# <td class="right counter txt_em">0.14</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="027" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=032"><img alt="" src="/images/mibank/ko/ico_bsbank.png"/></a></span> </td>
# <td class="right counter txt_em">1338.88</td>
# <td class="right counter txt_em">1.81</td>
# <td class="right counter txt_em">0.14</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="032" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=037"><img alt="" src="/images/mibank/ko/ico_jbbank.png"/></a></span> </td>
# <td class="right counter txt_em">1338.92</td>
# <td class="right counter txt_em">1.77</td>
# <td class="right counter txt_em">0.13</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="037" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=020"><img alt="" src="/images/mibank/ko/ico_wrbank.png"/></a></span> </td>
# <td class="right counter txt_em">1338.92</td>
# <td class="right counter txt_em">1.77</td>
# <td class="right counter txt_em">0.13</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="020" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=088"><img alt="" src="/images/mibank/ko/ico_shbank.png"/></a></span> </td>
# <td class="right counter txt_em">1338.92</td>
# <td class="right counter txt_em">1.77</td>
# <td class="right counter txt_em">0.13</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="088" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=011"><img alt="" src="/images/mibank/ko/ico_nhbank.png"/></a></span> </td>
# <td class="right counter txt_em">1339.03</td>
# <td class="right counter txt_em">1.66</td>
# <td class="right counter txt_em">0.12</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="011" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=003"><img alt="" src="/images/mibank/ko/ico_ibkbank.png"/></a></span> </td>
# <td class="right counter txt_em">1339.03</td>
# <td class="right counter txt_em">1.66</td>
# <td class="right counter txt_em">0.12</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="003" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=023"><img alt="" src="/images/mibank/ko/ico_scbank.png"/></a></span> </td>
# <td class="right counter txt_em">1339.33</td>
# <td class="right counter txt_em">1.36</td>
# <td class="right counter txt_em">0.10</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="023" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=035"><img alt="" src="/images/mibank/ko/ico_jjbank.png"/></a></span> </td>
# <td class="right counter txt_em">1339.52</td>
# <td class="right counter txt_em">1.17</td>
# <td class="right counter txt_em">0.09</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="035" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=007"><img alt="" src="/images/mibank/ko/ico_shkbank.png"/></a></span> </td>
# <td class="right counter txt_em">1340.69</td>
# <td class="right counter txt_em">0</td>
# <td class="right counter txt_em">0.00</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="007" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# </tbody>
# </table>
# <h6 class="warning">
# <p class="first">- 마이뱅크에서 제공하는 데이터, 자료는 단순 정보제공을 목적으로 하며, 특정 금융회사나 환전소를 권고하지 않습니다.</p>
#                     - 마이뱅크의 제공 자료는 은행의 공시 등 신뢰할만한 판단자료로 얻어진 것이나, 그 정확성이나 완전성을 보증하지는 않습니다.
#                     <p class="last">따라서 본 정보에 의존해 행해지는 행위로 인해 발생하는 결과에 대해 당사는 책임을 지지 않습니다.</p>
# </h6>
# </div>
# </div>
# <!--// right -->
# </div>
# <!-- container -->
# <!-- 테이블 순차적 fadein -->
# <script type="text/javascript">
#         $(".tb_action tbody tr:not(:first-child)").each(function (i, v ) {
#             $(this).css('animation-delay',i *0.03 +'s');
#         });
#     </script>
# <!-- 환율 롤링 count -->
# <script type="text/javascript">
#         function startCounter(){
#             $('.counter').each(function (index) {
#                 var size = $(this).text().split(".")[1] ? $(this).text().split(".")[1].length: 0;
#
#                 if($(this).text() != '-') {
#                     var amt = $(this).text().replace(",/g", "");
#                     $(this).text(amt);
#
#                     $(this).prop('Counter', 0).animate({
#                         Counter: $(this).text()
#                     }, {
#                         duration: 2000,
#                         easing: 'swing',
#                         step: function (now) {
#                             // $(this).text(parseFloat(now).toFixed(size));
#                             if((index+1)%3 == 0) gu = "%";
#                             else gu = "원";
#
#                           $(this).text(parseFloat(now).toFixed(size).replace(/\B(?=(\d{3})+(?!\d))/g, ',')+ gu);
#                         }
#                     });
#                 }
#             });
#         }
#         startCounter();
#     </script>
# <!-- dev footer append -->
# <div id="footer-append"></div>
# <!-- dev footer append -->
# <script src="/dev-js/common.js?d=1684730059" type="text/javascript"></script>
# <div class="JS_mobile_toggle appdown_area_in_mb" style="display: none;">
# <a href="/down.php" title="앱 다운로드"><img alt="앱 다운로드" src="/images/mibank/ko/bt_app_down_in_mb.png"/></a>
# </div>
# <div class="popup_wrap" id="JS_service_layer" style="display: none;">
# <img alt="로켓이미지" class="img_rocket" src="/images/mibank/ko/img_rocket.png"/>
# <div class="popup_content_wrap">
# <div class="bg_blue">
# <div class="popup_header">
# <img alt="마이뱅크" src="/images/mibank/ko/logo_blue.png"/>
# </div>
# <div class="popup_content">
# <span>10%</span><span>대 재테크</span>
# </div>
# </div>
# <a href="https://p2p.mibank.me//invest/list.php"><input class="bt_blue" name="" type="button" value="나도 참여하기"/></a>
# <div class="popup_footer">
# <a class="bt_close_today" href="#" id="JS_service_layer_check"><img alt="오늘은 그만보기" src="/images/mibank/ko/bt_view_stop_today.png"/></a>
# </div>
# </div>
# </div>
# <!-- popup -->
# <!--
# <div class="popup_for_intro" id="JS_service_layer" style=" display:none;">
# 	<div class="intro_popup_wrap">
# 		<div class="intro_popup_top">
# 			<img src="/images/mibank/ko/context_top_for_intro_pop.png" alt="마이뱅크가 제공하는 차원이 다른 서비스를 경험 해 보세요." />
# 		</div>
# 		<div class="intro_popup_buttons">
# 			<a href="#none" onclick="setServicePopup('travel')" class="bt_for_insurance_intro_popup">
# 				<img src="/images/mibank/ko/bt_insurance_for_intro_pop.png" alt="여행보험 서비스 바로가기" />
# 			</a>
# 			<a href="#none" onclick="setServicePopup('airport')">
# 				<img src="/images/mibank/ko/bt_exchange_for_intro_pop.png" alt="외화배송 서비스 바로가기" />
# 			</a>
# 		</div>
# 		<div class="intro_popup_bottom">
# 			<img src="/images/mibank/ko/context_bottom_for_intro_pop.png" alt="이용해보시고 만족하셨다면 소중한 분들과 함께 해 주세요. 이용관련 문의 070-7758-1375" />
# 		</div>
# 		<div class="intro_popup_close">
# 			<a href="#none" id="JS_service_layer_close">
# 				<img src="/images/mibank/ko/bt_close_for_intro_pop.png" alt="팝업 닫기" />
# 			</a>
# 		</div //--
# 		<div class="intro_popup_close_today">
# 			<a href="#none" id="JS_service_layer_check">
# 				<img src="/images/mibank/ko/bt_view_stop_today.png" alt="오늘은 그만보기" />
# 			</a>
# 		</div>
# 	</div>
# </div>-->
# <script type="text/javascript">
# //레이어
# var setServiceLayerClose = function() {
# 	$('#JS_service_layer').fadeOut();
# };
# $('#JS_service_layer_check').on('click', function() {
# 	if(MKcookies) {
# 		var date = new Date();
# 		var expiretime = 23-date.getHours();
# 		var expireminutes = 60-date.getMinutes();
# 		date.setHours(date.getHours()+expiretime);
# 		date.setMinutes(date.getMinutes()+expireminutes);
#
# 		MKcookies.setItem("SERVICE_LAYER", "N", date.toGMTString(), "/");
# 		setServiceLayerClose();
# 	}
# });
# $('#JS_service_layer_close').on('click', function() {
# 	setServiceLayerClose();
# });
# </script>
# <!-- // popup -->
# </body>

# %%
print(bsObject.body.find("tr"))
# Out:
# <tr>
# <td><div id="map_view" style="width: 674px; height:509px;"></div></td>
# <td class="map_result">
# <!-- 본점 지점 리스트 정보 //-->
# <div id="JS_bank_info" style="display: none;">
# <div class="map_head">
# <div class="bank_logo">
# <!-- img src="/images/mibank/ico_wrbank.png" alt="우리은행" -->
# </div>
# <div class="bank_num">
# <!-- <span>서울 중구</span>의 '<span>우리은행</span>' 총 <span class="num">10</span>건 -->
# </div>
# </div>
# <div class="map_info">
# <ul>
# <li class="map_info_sign">
# <p>
# 										지점별 상세정보를 보시려면<br/>지도의 핀 아이콘을 클릭하세요.									</p>
# </li>
# </ul>
# </div>
# </div>
# <!-- 지점정보 //-->
# <div id="JS_branch_info" style="display: none;"></div>
# </td>
# </tr>

# %%
print(bsObject.body.find("td", {"class":"JS_map_view"}))
# Out:
# None

# %%
bsObject.get("_markup_resembles_filename")

# %%
print(bsObject.head.find("meta", {"name":"description"}).get('content')) #<meta content="The official home of the Python Programming Language" name="description"/>
# Out:
# 쉽고 편리한 금융 : 보험, 환전, 환율/금리비교, 여행자보험

# %%
print(bsObject.body.find("meta", {"name":"description"}).get('content'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [63], in <cell line: 1>()
# ----> 1 print(bsObject.body.find("meta", {"name":"description"}).get('content'))
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
for data in bsObject.find_all('td'):
    try:
        print(data.text)
    except:
        pass
# Out:
# 										지점별 상세정보를 보시려면지도의 핀 아이콘을 클릭하세요.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [을지로6가] 포인트환전소
# 1318
# 24.02
# 1.79
#
#
#                                 2023.05.22
#
#
# 고래환전소
# 1318
# 24.02
# 1.79
#
#
#                                 2023.05.22
#
#
# 나이스환전금융
# 1318
# 24.02
# 1.79
#
#
#                                 2023.05.22
#
#
# 동대문OK환전
# 1319
# 23.02
# 1.72
#
#
#                                 2023.05.22
#
#
# 명동스카이환전
# 1319
# 23.02
# 1.72
#
#
#                                 2023.05.22
#
#
# 동대문환전
# 1319
# 23.02
# 1.72
#
#
#                                 2023.05.22
#
#
# 베스트환전
# 1319
# 23.02
# 1.72
#
#
#                                 2023.05.22
#
#
# 명동로사환전소
# 1319
# 23.02
# 1.72
#
#
#                                 2023.05.22
#
#
# [종로] 종로환전소
# 1319
# 23.02
# 1.72
#
#
#                                 2023.05.22
#
#
# 환전카페
# 1319
# 23.02
# 1.72
#
#
#                                 2023.05.22
#
#
# 한미환전
# 1320
# 22.02
# 1.64
#
#
#                                 2023.05.22
#
#
# [이태원] 월드환전소
# 1320
# 22.02
# 1.64
#
#
#                                 2023.05.22
#
#
# 명동제일환전센터
# 1320
# 22.02
# 1.64
#
#
#                                 2023.05.22
#
#
# 중앙환전
# 1320
# 22.02
# 1.64
#
#
#                                 2023.05.22
#
#
# 서울상역환전
# 1320
# 22.02
# 1.64
#
#
#                                 2023.05.22
#
#
# [종로] 종로오케이환전
# 1320
# 22.02
# 1.64
#
#
#                                 2023.05.22
#
#
# 에프엑스코리아
# 1320
# 22.02
# 1.64
#
#
#                                 2023.05.22
#
#
# 플러스환전
# 1321
# 21.02
# 1.57
#
#
#                                 2023.05.22
#
#
# [코엑스] 투어시티환전센터
# 1321
# 21.02
# 1.57
#
#
#                                 2023.05.22
#
#
# 하나환전
# 1322
# 20.02
# 1.49
#
#
#                                 2023.05.22
#
#
# 한양환전소
# 1323
# 19.02
# 1.42
#
#
#                                 2023.05.22
#
#
# 대박나라넷
# 1324
# 18.02
# 1.34
#
#
#                                 2023.05.21
#
#
# [신사역] 로얄외국환환전소
# 1325
# 17.02
# 1.27
#
#
#                                 2023.05.22
#
#
# 신세계환전소
# 1325
# 17.02
# 1.27
#
#
#                                 2023.05.22
#
#
#
# 1339.52
# 2.5
# 0.19
#
#
#                                 2023.05.22
#
#
#
# 1339.64
# 2.38
# 0.18
#
#
#                                 2023.05.22
#
#
#
# 1339.74
# 2.28
# 0.17
#
#
#                                 2023.05.22
#
#
#
# 1339.84
# 2.18
# 0.16
#
#
#                                 2023.05.22
#
#
#
# 1339.84
# 2.18
# 0.16
#
#
#                                 2023.05.22
#
#
#
# 1339.84
# 2.18
# 0.16
#
#
#                                 2023.05.22
#
#
#
# 1339.84
# 2.18
# 0.16
#
#
#                                 2023.05.22
#
#
#
# 1339.89
# 2.13
# 0.16
#
#
#                                 2023.05.22
#
#
#
# 1339.94
# 2.08
# 0.15
#
#
#                                 2023.05.22
#
#
#
# 1339.94
# 2.08
# 0.15
#
#
#                                 2023.05.22
#
#
#
# 1339.94
# 2.08
# 0.15
#
#
#                                 2023.05.22
#
#
#
# 1339.99
# 2.03
# 0.15
#
#
#                                 2023.05.22
#
#
#
# 1340.04
# 1.98
# 0.15
#
#
#                                 2023.05.22
#
#
#
# 1342.02
# 0
# 0.00
#
#
#                                 2023.05.22

# %%
# Out:
# 										지점별 상세정보를 보시려면지도의 핀 아이콘을 클릭하세요.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [을지로6가] 포인트환전소
# 1318
# 24.02
# 1.79
#
#
#                                 2023.05.22
#
#
# 고래환전소
# 1318
# 24.02
# 1.79
#
#
#                                 2023.05.22
#
#
# 나이스환전금융
# 1318
# 24.02
# 1.79
#
#
#                                 2023.05.22
#
#
# 동대문OK환전
# 1319
# 23.02
# 1.72
#
#
#                                 2023.05.22
#
#
# 명동스카이환전
# 1319
# 23.02
# 1.72
#
#
#                                 2023.05.22
#
#
# 동대문환전
# 1319
# 23.02
# 1.72
#
#
#                                 2023.05.22
#
#
# 베스트환전
# 1319
# 23.02
# 1.72
#
#
#                                 2023.05.22
#
#
# 명동로사환전소
# 1319
# 23.02
# 1.72
#
#
#                                 2023.05.22
#
#
# [종로] 종로환전소
# 1319
# 23.02
# 1.72
#
#
#                                 2023.05.22
#
#
# 환전카페
# 1319
# 23.02
# 1.72
#
#
#                                 2023.05.22
#
#
# 한미환전
# 1320
# 22.02
# 1.64
#
#
#                                 2023.05.22
#
#
# [이태원] 월드환전소
# 1320
# 22.02
# 1.64
#
#
#                                 2023.05.22
#
#
# 명동제일환전센터
# 1320
# 22.02
# 1.64
#
#
#                                 2023.05.22
#
#
# 중앙환전
# 1320
# 22.02
# 1.64
#
#
#                                 2023.05.22
#
#
# 서울상역환전
# 1320
# 22.02
# 1.64
#
#
#                                 2023.05.22
#
#
# [종로] 종로오케이환전
# 1320
# 22.02
# 1.64
#
#
#                                 2023.05.22
#
#
# 에프엑스코리아
# 1320
# 22.02
# 1.64
#
#
#                                 2023.05.22
#
#
# 플러스환전
# 1321
# 21.02
# 1.57
#
#
#                                 2023.05.22
#
#
# [코엑스] 투어시티환전센터
# 1321
# 21.02
# 1.57
#
#
#                                 2023.05.22
#
#
# 하나환전
# 1322
# 20.02
# 1.49
#
#
#                                 2023.05.22
#
#
# 한양환전소
# 1323
# 19.02
# 1.42
#
#
#                                 2023.05.22
#
#
# 대박나라넷
# 1324
# 18.02
# 1.34
#
#
#                                 2023.05.21
#
#
# [신사역] 로얄외국환환전소
# 1325
# 17.02
# 1.27
#
#
#                                 2023.05.22
#
#
# 신세계환전소
# 1325
# 17.02
# 1.27
#
#
#                                 2023.05.22
#
#
#
# 1339.52
# 2.5
# 0.19
#
#
#                                 2023.05.22
#
#
#
# 1339.64
# 2.38
# 0.18
#
#
#                                 2023.05.22
#
#
#
# 1339.74
# 2.28
# 0.17
#
#
#                                 2023.05.22
#
#
#
# 1339.84
# 2.18
# 0.16
#
#
#                                 2023.05.22
#
#
#
# 1339.84
# 2.18
# 0.16
#
#
#                                 2023.05.22
#
#
#
# 1339.84
# 2.18
# 0.16
#
#
#                                 2023.05.22
#
#
#
# 1339.84
# 2.18
# 0.16
#
#
#                                 2023.05.22
#
#
#
# 1339.89
# 2.13
# 0.16
#
#
#                                 2023.05.22
#
#
#
# 1339.94
# 2.08
# 0.15
#
#
#                                 2023.05.22
#
#
#
# 1339.94
# 2.08
# 0.15
#
#
#                                 2023.05.22
#
#
#
# 1339.94
# 2.08
# 0.15
#
#
#                                 2023.05.22
#
#
#
# 1339.99
# 2.03
# 0.15
#
#
#                                 2023.05.22
#
#
#
# 1340.04
# 1.98
# 0.15
#
#
#                                 2023.05.22
#
#
#
# 1342.02
# 0
# 0.00
#
#
#                                 2023.05.22

# %%
text_data
# Out:
# ['1318',
#  '24.02',
#  '1.79',
#  '2023.05.22',
#  '고래환전소',
#  '1318',
#  '24.02',
#  '1.79',
#  '2023.05.22',
#  '나이스환전금융',
#  '1318',
#  '24.02',
#  '1.79',
#  '2023.05.22',
#  '동대문OK환전',
#  '1319',
#  '23.02',
#  '1.72',
#  '2023.05.22',
#  '명동스카이환전',
#  '1319',
#  '23.02',
#  '1.72',
#  '2023.05.22',
#  '동대문환전',
#  '1319',
#  '23.02',
#  '1.72',
#  '2023.05.22',
#  '베스트환전',
#  '1319',
#  '23.02',
#  '1.72',
#  '2023.05.22',
#  '명동로사환전소',
#  '1319',
#  '23.02',
#  '1.72',
#  '2023.05.22',
#  '1319',
#  '23.02',
#  '1.72',
#  '2023.05.22',
#  '환전카페',
#  '1319',
#  '23.02',
#  '1.72',
#  '2023.05.22',
#  '한미환전',
#  '1320',
#  '22.02',
#  '1.64',
#  '2023.05.22',
#  '1320',
#  '22.02',
#  '1.64',
#  '2023.05.22',
#  '명동제일환전센터',
#  '1320',
#  '22.02',
#  '1.64',
#  '2023.05.22',
#  '중앙환전',
#  '1320',
#  '22.02',
#  '1.64',
#  '2023.05.22',
#  '서울상역환전',
#  '1320',
#  '22.02',
#  '1.64',
#  '2023.05.22',
#  '1320',
#  '22.02',
#  '1.64',
#  '2023.05.22',
#  '에프엑스코리아',
#  '1320',
#  '22.02',
#  '1.64',
#  '2023.05.22',
#  '플러스환전',
#  '1321',
#  '21.02',
#  '1.57',
#  '2023.05.22',
#  '1321',
#  '21.02',
#  '1.57',
#  '2023.05.22',
#  '하나환전',
#  '1322',
#  '20.02',
#  '1.49',
#  '2023.05.22',
#  '한양환전소',
#  '1323',
#  '19.02',
#  '1.42',
#  '2023.05.22',
#  '대박나라넷',
#  '1324',
#  '18.02',
#  '1.34',
#  '2023.05.21',
#  '1325',
#  '17.02',
#  '1.27',
#  '2023.05.22',
#  '신세계환전소',
#  '1325',
#  '17.02',
#  '1.27',
#  '2023.05.22',
#  '1339.52',
#  '2.5',
#  '0.19',
#  '2023.05.22',
#  '1339.64',
#  '2.38',
#  '0.18',
#  '2023.05.22',
#  '1339.74',
#  '2.28',
#  '0.17',
#  '2023.05.22',
#  '1339.84',
#  '2.18',
#  '0.16',
#  '2023.05.22',
#  '1339.84',
#  '2.18',
#  '0.16',
#  '2023.05.22',
#  '1339.84',
#  '2.18',
#  '0.16',
#  '2023.05.22',
#  '1339.84',
#  '2.18',
#  '0.16',
#  '2023.05.22',
#  '1339.89',
#  '2.13',
#  '0.16',
#  '2023.05.22',
#  '1339.94',
#  '2.08',
#  '0.15',
#  '2023.05.22',
#  '1339.94',
#  '2.08',
#  '0.15',
#  '2023.05.22',
#  '1339.94',
#  '2.08',
#  '0.15',
#  '2023.05.22',
#  '1339.99',
#  '2.03',
#  '0.15',
#  '2023.05.22',
#  '1340.04',
#  '1.98',
#  '0.15',
#  '2023.05.22',
#  '1342.02',
#  '0.00',
#  '2023.05.22']

# %%
a = ""
problem_list = {}  # 시오. 추가
for i, v in enumerate(text_data):

    if len(a) == 0 and ("?" in v or "시오." in v):
        a = a + v

    if "?" in a and ("?" in v or "시오." in v):
        problem_list[len(problem_list)] = a
        a = ""

    if len(a) >= 0:
        a = a + v

# %%
problem_list
# Out:
# {}

# %%
data.get()
# Out:
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="007" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>

# %%
link
# Out:
# <a class="bt_close_today" href="#" id="JS_service_layer_check"><img alt="오늘은 그만보기" src="/images/mibank/ko/bt_view_stop_today.png"/></a>

# %%
for link in bsObject.find_all('a'):
    print(link.text.strip(), link.get('href'))
# Out:
# <!-- <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd"> -->
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=10" http-equiv="X-UA-Compatible"/><!-- J. ,chrome=1 삭제-->
# <!-- J -->
# <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no" name="viewport"/>
# <meta content="telephone=no,address=no,email=no" name="format-detection"/>
# <meta content="no-cache" http-equiv="Cache-Control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <!-- meta name='viewport' content='width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no' -->
# <title>마이뱅크 | 쉽고 편리한 금융</title>
# <meta content="마이뱅크 | 쉽고 편리한 금융" name="title"/>
# <meta content="쉽고 편리한 금융 : 보험, 환전, 환율/금리비교, 여행자보험" name="description"/>
# <link href="https://www.mibank.me/dev-img/common/mibank_og_logo.png" rel="image_src"/>
# <!-- Naver //-->
# <meta content="cacf794622f86103a98af31a559a6ee76eba27ee" name="naver-site-verification">
# <meta content="마이뱅크 | 쉽고 편리한 금융" property="og:title">
# <meta content="article" property="og:type"/>
# <meta content="https://www.mibank.me/exchange/saving/index.php?lang=ko" property="og:url"/>
# <meta content="https://www.mibank.me/dev-img/common/mibank_og_logo.png" property="og:image"/>
# <meta content="마이뱅크" property="og:site_name"/>
# <meta content="쉽고 편리한 금융 : 보험, 환전, 환율/금리비교, 여행자보험" property="og:description">
# <!-- CSS //-->
# <link href="/images/mibank_icon/favicon@2x.png" rel="shortcut icon"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/jquery-confirm/3.3.2/jquery-confirm.min.css" rel="stylesheet"/>
# <link href="/css/mibank.css?d=1684728416" rel="stylesheet"/>
# <link href="/css/MKpopup.css?d=1684728416" rel="stylesheet" type="text/css"/>
# <link href="/css/MKmsg.css?d=1684728416" rel="stylesheet" type="text/css"/>
# <link href="/css/addclass_ext.css?d=1684728416" rel="stylesheet" type="text/css"/>
# <link href="/dev-css/layout.css?d=1684728416" rel="stylesheet" type="text/css"/>
# <!--[if gteIE 8]>
# <link rel="stylesheet" type="text/css" href="ie8.css">
# <![endif]-->
# <!-- JS //-->
# <!-- script src="//code.jquery.com/jquery-1.11.0.min.js"></script -->
# <script src="/js/jquery-1.7.1.min.js" type="text/javascript"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery-confirm/3.3.2/jquery-confirm.min.js"></script>
# <script src="/js/MKcommon.js" type="text/javascript"></script>
# <script src="/js/MKvalidate.js" type="text/javascript"></script>
# <script src="/js/MKpopup.js" type="text/javascript"></script>
# <script src="/js/MKmsg.js" type="text/javascript"></script>
# <script src="/js/MKcookies.js" type="text/javascript"></script>
# <script src="/js/MKselect.js" type="text/javascript"></script>
# <script src="/js/add_javascript.js?d=1684728416" type="text/javascript"></script>
# <!-- Naver 로그분석 //-->
# <script src="//wcs.naver.net/wcslog.js" type="text/javascript"></script>
# <script type="text/javascript">
# if (!wcs_add) var wcs_add={};
# wcs_add["wa"] = "s_3fcc4d979c8d";
# if (!_nasa) var _nasa={};
# wcs.inflow();
# wcs_do(_nasa);
# </script>
# <!-- Facebook Pixel Code //-->
# <script>
# !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','https://connect.facebook.net/en_US/fbevents.js');
#
# fbq('init', '217683908576366');
# fbq('track', "PageView");
# fbq('track', 'ViewContent');
# </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=217683908576366&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script type="text/javascript">
# //구글
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# ga('create', 'UA-56021062-1', 'auto');
# ga('send', 'pageview');
#
# //모바일 체크
# if((/(android|bb\d+|meego).+mobile|avantgo|bada\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|iris|kindle|lge |maemo|midp|mmp|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\.(browser|link)|vodafone|wap|windows (ce|phone)|xda|xiino|android|ipad|playbook|silk/i.test(navigator.userAgent||navigator.vendor||window.opera)||/1207|6310|6590|3gso|4thp|50[1-6]i|770s|802s|a wa|abac|ac(er|oo|s\-)|ai(ko|rn)|al(av|ca|co)|amoi|an(ex|ny|yw)|aptu|ar(ch|go)|as(te|us)|attw|au(di|\-m|r |s )|avan|be(ck|ll|nq)|bi(lb|rd)|bl(ac|az)|br(e|v)w|bumb|bw\-(n|u)|c55\/|capi|ccwa|cdm\-|cell|chtm|cldc|cmd\-|co(mp|nd)|craw|da(it|ll|ng)|dbte|dc\-s|devi|dica|dmob|do(c|p)o|ds(12|\-d)|el(49|ai)|em(l2|ul)|er(ic|k0)|esl8|ez([4-7]0|os|wa|ze)|fetc|fly(\-|_)|g1 u|g560|gene|gf\-5|g\-mo|go(\.w|od)|gr(ad|un)|haie|hcit|hd\-(m|p|t)|hei\-|hi(pt|ta)|hp( i|ip)|hs\-c|ht(c(\-| |_|a|g|p|s|t)|tp)|hu(aw|tc)|i\-(20|go|ma)|i230|iac( |\-|\/)|ibro|idea|ig01|ikom|im1k|inno|ipaq|iris|ja(t|v)a|jbro|jemu|jigs|kddi|keji|kgt( |\/)|klon|kpt |kwc\-|kyo(c|k)|le(no|xi)|lg( g|\/(k|l|u)|50|54|\-[a-w])|libw|lynx|m1\-w|m3ga|m50\/|ma(te|ui|xo)|mc(01|21|ca)|m\-cr|me(rc|ri)|mi(o8|oa|ts)|mmef|mo(01|02|bi|de|do|t(\-| |o|v)|zz)|mt(50|p1|v )|mwbp|mywa|n10[0-2]|n20[2-3]|n30(0|2)|n50(0|2|5)|n7(0(0|1)|10)|ne((c|m)\-|on|tf|wf|wg|wt)|nok(6|i)|nzph|o2im|op(ti|wv)|oran|owg1|p800|pan(a|d|t)|pdxg|pg(13|\-([1-8]|c))|phil|pire|pl(ay|uc)|pn\-2|po(ck|rt|se)|prox|psio|pt\-g|qa\-a|qc(07|12|21|32|60|\-[2-7]|i\-)|qtek|r380|r600|raks|rim9|ro(ve|zo)|s55\/|sa(ge|ma|mm|ms|ny|va)|sc(01|h\-|oo|p\-)|sdk\/|se(c(\-|0|1)|47|mc|nd|ri)|sgh\-|shar|sie(\-|m)|sk\-0|sl(45|id)|sm(al|ar|b3|it|t5)|so(ft|ny)|sp(01|h\-|v\-|v )|sy(01|mb)|t2(18|50)|t6(00|10|18)|ta(gt|lk)|tcl\-|tdg\-|tel(i|m)|tim\-|t\-mo|to(pl|sh)|ts(70|m\-|m3|m5)|tx\-9|up(\.b|g1|si)|utst|v400|v750|veri|vi(rg|te)|vk(40|5[0-3]|\-v)|vm40|voda|vulc|vx(52|53|60|61|70|80|81|83|85|98)|w3c(\-| )|webc|whit|wi(g |nc|nw)|wmlb|wonu|x700|yas\-|your|zeto|zte\-/i.test((navigator.userAgent||navigator.vendor||window.opera).substr(0,4)))) {
# 	//toggle
# 	/*window.onload = function() {
# 		document.getElementById('mobile_toggle').style.setProperty('display', 'block');
# 	};*/
# 	$(document).ready(function() {
# 		$('.JS_mobile_toggle').show();
# 	});
# }
#
# //페이스북 공유
# var setFacebook = function() {
# 	var title = escape('절약하기');
# 	var link = escape("https://mibank.me/exchange/saving/index.php?lang=ko&date="+(Math.floor(Math.random() * 1000)+1)); // dummy data
# 	var url = 'https://www.facebook.com/sharer.php?u=' + link + '&t=' + title;
# 	window.open(url,'','width=900,height=450,scrollbar=yes,menubars=no');
# };
#
# //외화배송, 여행자보험
# var setServicePopup = function(type) {
# 	var win = {
# 		"width": Math.round(window.innerWidth || document.documentElement.clientWidth),
# 		"height": Math.round(window.innerHeight || document.documentElement.clientHeight)
# 	};
# 	var width = win.width / 4 > 480 ? win.width / 4 : 480;
# 	var height = win.height / 2 > 700 ? win.height / 2 : 700;
# 	var left = Math.round(win.width / 2) - Math.round(width / 2);
# 	var top = Math.round(win.height / 2) - Math.round(height / 2);
# 	if(left < 0) left = 0;
# 	if(top < 0) top = 0;
#
# 	var open;
# 	switch(type) {
# 		case 'travel': //여행자보험
# 			open = window.open('https://travel.mibank.me', 'travel', 'width=' + width + ',height=' + height + ',left=' + left + ',top=' + top + ',menubar=no,status=no,location=no,scrollbars=yes,resizable=no');
# 			open.focus();
# 			break;
# 		case 'airport': //외화배송
# 			open = window.open('https://airport.mibank.me/', 'airport', 'width=' + width + ',height=' + height + ',left=' + left + ',top=' + top + ',menubar=no,status=no,location=no,scrollbars=yes,resizable=no');
# 			open.focus();
# 			break;
# 	}
# };
#
# $(document).ready(function() {
# 	//숫자 키보드 확인
# 	var isNumberKey = function(event) {
# 		if( /*
# 			(event.keyCode >= 48 && event.keyCode <= 57) ||		// 숫자열 0 ~ 9 : 48 ~ 57
# 			(event.keyCode >= 96 && event.keyCode <= 105) ||	// 키패드 0 ~ 9 : 96 ~ 105
# 			event.keyCode == 8 ||								// BackSpace
# 			event.keyCode == 110 || event.keyCode == 190		// 소수점(.)
# 			*/
#                     (event.keyCode >= 48 && event.keyCode <= 57) || (event.keyCode >= 96 && event.keyCode <= 105) //숫자열 0 ~ 9 : 48 ~ 57, 키패드 0 ~ 9 : 96 ~ 105
#                 ) {
#                     return true;
#                 } else {
#                     return false;
#                 }
#             };
#             /*
#             //document ready 후 첫 키보드 입력이 숫자의 경우
#             $(document).one('keydown', function(e) {
#             	var event = window.event || e;
#             	if(isNumberKey(event)) {
#             		$('input:text').filter(':enabled').eq(0).focus();
#             	}
#             });
#             //$('input:text').filter(':enabled').one('focus', function() {
#             $('input:text').one('focus, blur', function() {
#             	$(document).off('keydown');
#             });
#             */
#             //언어변경
#             /*
#             $('#JS_lang_select').on('change', function() {
#             	var current = 'ko';
#             	var lang = $(this).val();
#             	if(current != lang) {
#             		var search = /\/ko\/|\/zh\/|\/ja\/|\/en\//ig;
#             		var url = 'https://mibank.me/exchange/saving/index.php';
#             		url = url.replace(search, '/' + lang + '/');
#             		url = url + '?lang=' + lang;
#             		window.location.replace(url);
#             	}
#             });
#             */
#             MKselect('JS_select_text', function(value) {
#                 var current = 'ko';
#                 var lang = value;
#                 if (lang != '' && current != lang) {
#                     var search = /\/ko\/|\/zh\/|\/ja\/|\/en\//ig;
#                     var url = 'https://mibank.me/exchange/saving/index.php';
#                     url = url.replace(search, '/' + lang + '/');
#                     url = url + '?lang=' + lang;
#                     window.location.replace(url);
#                 }
#             }).on();
#
#             //input 천단위 표기
#             //$('.JS_number_input').filter(':enabled').on('keyup', function() {
#             $('.JS_number_input').on('keyup', function() {
#                 if (!$(this).is(':enabled')) return;
#                 var min = $(this).data('min') || 0; //최소
#                 var max = $(this).data('max') || 0; //최대
#                 var min_msg = $(this).data('min-msg') || ''; //alert 메시지
#                 var max_msg = $(this).data('max-msg') || ''; //alert 메시지
#                 var num = $(this).val();
#                 min_msg = String(min_msg);
#                 max_msg = String(max_msg);
#                 num = String(num); //숫자를 문자열로 변환
#                 num = num.replace(/,/gi, ""); //기존 콤마 제거
#                 var setNumber = function(val) {
#                     var val = String(val);
#                     var reg = /(^[+-]?\d+)(\d{3})/; //정규식
#                     while (reg.test(val)) {
#                         val = val.replace(reg, '$1' + ',' + '$2');
#                     }
#                     return val;
#                 };
#                 if (min > 0 && min > num) {
#                     num = setNumber(min);
#                     if (min_msg != '') {
#                         min_msg = min_msg.replace(/{num}/ig, num);
#                         alert(min_msg);
#                     } else {
#                         alert(num + ' 이상 입력해 주세요.');
#                     }
#                 } else if (max > 0 && max < num) {
#                     num = setNumber(max);
#                     if (max_msg != '') {
#                         max_msg = max_msg.replace(/{num}/ig, num);
#                         alert(max_msg);
#                     } else {
#                         alert(num + ' 이하로 입력해 주세요.');
#                     }
#                 } else {
#                     num = setNumber(num);
#                 }
#                 $(this).val(num);
#             });
#
#             //thead 상단고정
#             var JS_fixed_table_head = $('#JS_fixed_table_head');
#             if (JS_fixed_table_head.size() > 0) {
#                 var fixed_table_head_top = JS_fixed_table_head.offset().top; //테이블 위치
#                 var bank_header_height = Number($('#JS_bank_header').height()) + 46; //header 높이
#                 var standard_top = Number(fixed_table_head_top) - Number(bank_header_height);
#
#                 //테이블 width 설정
#                 JS_fixed_table_head.find('tr').eq(0).find('th').each(function() {
#                     var that = $(this);
#                     that.width(that.width());
#                 });
#
#                 //thead 생성
#                 var thead_fixed = $('<table style="z-index: 55;"><thead>' + JS_fixed_table_head.html() + '</thead></table>').hide();
#                 $('#JS_data_content').prepend(thead_fixed);
#
#                 //말풍선 레이어 모두 숨기기
#                 thead_fixed.find('.JS_layer_toggle').each(function() {
#                     $(this).hide();
#                     thead_fixed.find('.' + $(this).data('layer-target')).remove();
#                 });
#
#                 //스크롤에 따른 작업
#                 $(window).scroll(function() {
#                     var scroll_top = $(window).scrollTop();
#                     if (standard_top < scroll_top) {
#                         if (thead_fixed.is(':hidden')) {
#                             //thead_fixed.css('position', 'fixed').fadeIn('fast');
#                             thead_fixed.css('position', 'fixed').animate({
#                                 opacity: 'show'
#                             }, 'fast');
#                         }
#                         thead_fixed.css('top', bank_header_height + 'px');
#                     } else {
#                         if (thead_fixed.is(':visible')) {
#                             thead_fixed.fadeOut('fast');
#                         }
#                     }
#                 });
#             }
#
#             //레이어(말풍선) 보이기/숨기기
#             var JS_layer_toggle = $('.JS_layer_toggle');
#             JS_layer_toggle.mouseover(function() {
#                 var layer = $('.' + $(this).data('layer-target'));
#                 layer.stop(true, true);
#                 layer.animate({
#                     opacity: 'show'
#                 }, 'fast', function() {
#                     $(this).css('display', 'block');
#                 });
#                 //$('#' + $(this).data('layer-target')).fadeIn('fast');
#             });
#             JS_layer_toggle.mouseout(function() {
#                 var layer = $('.' + $(this).data('layer-target'));
#                 layer.stop(true, true);
#                 layer.animate({
#                     opacity: 'hide'
#                 }, 'fast');
#                 //$('#' + $(this).data('layer-target')).fadeOut('fast');
#             });
#
#             //공지사항
#             var JS_notice_marquee = $('#JS_notice_marquee');
#             if (JS_notice_marquee.length > 0) {
#                 $.ajax({
#                     url: '/ajax/select_notice.php',
#                     type: 'post',
#                     data: {
#                         "category": "exchange"
#                     },
#                     beforeSend: function() {
#                         //요청전
#                     },
#                     complete: function() {
#                         //요청완료
#                     },
#                     error: function() {
#                         //요청실패
#                     },
#                     success: function(json) {
#                         if (!json) return;
#                         if (json['msg'] == 'success') {
#                             var i;
#                             var max = json['data'].length;
#                             var html = [];
#                             if (max > 0) {
#                                 for (i = 0; i < max; i++) {
#                                     html.push('&nbsp;<a href="http://www.mibank.me/exchange/notice.php?code=' + json['data'][i]['code'] + '">▶ ' + decodeURIComponent(json['data'][i]['title']) + '</a>&nbsp;');
#                                 }
#                                 JS_notice_marquee.html(html.join(''));
#                                 /*
#                                 window.setTimeout(function() {
#                                 	JS_notice_marquee.fadeIn();
#                                 }, 500);
#                                 */
#                                 //JS_notice_marquee.fadeIn();
#                             }
#                         } else {
#                             //alert('데이터 전송 중 오류가 발생했습니다.');
#                         }
#                     }
#                 });
#             }
#
#         });
#     </script>
# <script type="text/javascript">
# //현재 접속위치
# var setUserLocation = function() {
# 	//주소 -> 좌표변환
# 	var getAddr2coord = function(address, callback) {
# 		$.ajax({
# 			url : '//apis.daum.net/local/geo/addr2coord',
# 			async: false, //비동기 여부
# 			type : 'get',
# 			data : {"apikey": "0a141d8dd522330f6d33f95bcde476c4677ef750", "q": address, "output": "json"},
# 			beforeSend: function() {
# 				//요청전
# 			},
# 			complete: function() {
# 				//요청완료
# 			},
# 			error: function() {
# 				//요청실패
# 				if(typeof callback == 'function') {
# 					callback();
# 				}
# 			},
# 			dataType: "jsonp",
# 			jsonp : "callback",
# 			success: function(json) {
# 				if(!json) return;
# 				//console.dir(json);
# 				if(typeof callback == 'function') {
# 					callback(json);
# 				}
# 			}
# 		});
# 	};
# 	//시도명, 구군명으로 정보 조회
# 	var getSidoGugun = function(sido, gugun) {
# 		if(!sido || !gugun) return;
# 		var data = {};
# 		$.ajax({
# 			url : '/ajax/select_address_code.php',
# 			async: false, //비동기 여부
# 			type : 'post',
# 			data : {"sido": sido, "gugun": gugun},
# 			beforeSend: function() {
# 				//요청전
# 			},
# 			complete: function() {
# 				//요청완료
# 			},
# 			error: function() {
# 				//요청실패
# 			},
# 			//dataType: "jsonp",
# 			//jsonp : "callback",
# 			success: function(json) {
# 				if(!json) return;
# 				//console.dir(json);
# 				if(json['msg'] == 'success' && json.sido_code && json.gugun_code) {
# 					data = {"sido_code": json.sido_code, "gugun_code": json.gugun_code}
# 				}
# 			}
# 		});
#
# 		return data;
# 	};
# 	// $.ajax({
# 	// 	url : '/ajax/whois.php',
# 	// 	async: true, //비동기 여부
# 	// 	//type : 'get',
# 	// 	//data : {},
# 	// 	beforeSend: function() {
# 	// 		//요청전
# 	// 	},
# 	// 	complete: function() {
# 	// 		//요청완료
# 	// 	},
# 	// 	error: function() {
# 	// 		//요청실패
# 	// 	},
# 	// 	//dataType: "jsonp",
# 	// 	//jsonp : "callback",
# 	// 	success: function(json) {
# 	// 		try {
# 	// 			if(json.whois.korean.ISP.netinfo.addr) {
# 	// 				//var address = json.whois.korean.ISP.netinfo.addr;
# 	// 				var address = json.whois.korean.user.netinfo.addr;
# 	// 				if(address) {
# 	// 					//주소 -> 좌표변환
# 	// 					getAddr2coord(address, function(json) {
# 	// 						//console.dir(json);
# 	// 						var sido = '';
# 	// 						var gugun = '';
# 	// 						if(json && json.channel && json.channel.result > 0) {
# 	// 							sido = json.channel.item[0].localName_1; //시도
# 	// 							gugun = json.channel.item[0].localName_2; //구군
# 	// 							//시도 구군 -> 코드변환
# 	// 							if(sido && gugun) {
# 	// 								var data = getSidoGugun(sido, gugun);
# 	// 								if(data && data.sido_code && data.gugun_code) {
# 	// 									//쿠키저장
# 	// 									MKcookies.setItem("mibank_location", '{"sido_code": ' + data.sido_code + ', "gugun_code": ' + data.gugun_code + '}', null, '/');
# 	// 								}
# 	// 							}
# 	// 						}
# 	// 					});
# 	// 				}
# 	// 			}
# 	// 		}catch(e) {}
# 	// 	}
# 	// });
# };
# setUserLocation();</script></meta></meta></meta></head>
# <body>
# <!-- header -->
# <div class="sub_header header-dev" id="JS_bank_header">
# <div id="header-dev-top"></div>
# <div class="sub_menu JS_popup_scroll_fix">
# <div class="s_menu">
# <div class="s_menu_l">
# <ul>
# <li><a class="on" href="/exchange/saving/index.php">절약하기</a></li>
# <li><a class="first" href="/exchange/bank/index.php">은행별 환율</a></li>
# <li><a class="" href="/exchange/map/index.php">가까운 환전소</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <script src="/dev-js/header.js?d=1684728416" type="text/javascript"></script>
# <!--// header --><div class="saving_map_pop" id="map_popup" style="display: none;">
# <table>
# <caption>saving 지도레이어</caption>
# <colgroup>
# <col width="674px"/>
# <col width="249px"/>
# </colgroup>
# <tbody>
# <tr>
# <td><div id="map_view" style="width: 674px; height:509px;"></div></td>
# <td class="map_result">
# <!-- 본점 지점 리스트 정보 //-->
# <div id="JS_bank_info" style="display: none;">
# <div class="map_head">
# <div class="bank_logo">
# <!-- img src="/images/mibank/ico_wrbank.png" alt="우리은행" -->
# </div>
# <div class="bank_num">
# <!-- <span>서울 중구</span>의 '<span>우리은행</span>' 총 <span class="num">10</span>건 -->
# </div>
# </div>
# <div class="map_info">
# <ul>
# <li class="map_info_sign">
# <p>
# 										지점별 상세정보를 보시려면<br/>지도의 핀 아이콘을 클릭하세요.									</p>
# </li>
# </ul>
# </div>
# </div>
# <!-- 지점정보 //-->
# <div id="JS_branch_info" style="display: none;"></div>
# </td>
# </tr>
# </tbody>
# </table>
# <p class="pop_close">
# <a class="close" href="#none"><img alt="창닫기" src="/images/mibank/ic_close_but.gif"/></a>
# </p>
# </div>
# <!--<script type="text/javascript" src="//apis.daum.net/maps/maps3.js?apikey=2a439b072176fd863f0f96ddfcf60405f340118b" charset="utf-8"></script>-->
# <script src="//dapi.kakao.com/v2/maps/sdk.js?appkey=a3876d95ecb22374950c424abde4e1c4" type="text/javascript"></script>
# <script type="text/javascript">
# //전역변수
# var search = { //검색조건
# 	"cu_code": "",
# 	"data_type": "",
# 	"bank_code": ""
# };
# var obj = { //object
# 	"map": null,
# 	"points": [],
# 	"bounds": null,
# 	"marker": [],
# 	"infowindow": []
# };
# var data = { //데이터
# 	"list": []
# };
#
# //팝업
# var daum_map_popup = MKpopup({"selector": "map_popup", "header": "N"});
#
# //주소값 -> 좌표 변환
# var getLngLat = function(options) {
# 	if(typeof options.address == 'undefined') return;
# 	var address = options.address;
# 	var lng = '';
# 	var lat = '';
# 	$.ajax({
# 		url : '//apis.daum.net/local/geo/addr2coord',
# 		async: false, //비동기 여부
# 		type : 'get',
# 		data : {"apikey": "0a141d8dd522330f6d33f95bcde476c4677ef750", "q": address, "output": "json"},
# 		beforeSend: function() {
# 			//요청전
# 		},
# 		complete: function() {
# 			//요청완료
# 		},
# 		error: function() {
# 			//요청실패
# 		},
# 		dataType: "jsonp",
# 		jsonp : "callback",
# 		success: function(json) {
# 			//console.log(json);
# 			if(json.channel && json.channel.result > 0) {
# 				lng = json.channel.item[0].lng; //경도
# 				lat = json.channel.item[0].lat; //위도
# 			}
# 		}
# 	});
#
# 	return {"lng": lng, "lat": lat};
# };
#
# //지도로딩
# var setMap = function(options) {
# 	if(typeof options.lng == 'undefined' || typeof options.lat == 'undefined') return;
# 	var lng = options.lng; //경도
# 	var lat = options.lat; //위도
#
# 	//지도 출력 div
# 	var map_view = $('#map_view')[0];
#
# 	//기본 지도 설정
# 	obj.map = new daum.maps.Map(map_view, {
# 		center: new daum.maps.LatLng(lat, lng), //중심 좌표
# 		level: 4, //확대 수준
# 		draggable: true //마우스로 드래그하여 시점을 변경 가능한지의 여부
# 	});
#
# 	//컨트롤
# 	var zoomControl = new daum.maps.ZoomControl();
# 	obj.map.addControl(zoomControl, daum.maps.ControlPosition.RIGHT);
# 	var mapTypeControl = new daum.maps.MapTypeControl();
# 	obj.map.addControl(mapTypeControl, daum.maps.ControlPosition.TOPRIGHT);
# };
#
# //지점 정보 보기
# var setBranchView = function(index) {
# 	var JS_bank_info = $('#JS_bank_info');
# 	var JS_branch_info = $('#JS_branch_info');
# 	var div = JS_branch_info.find('> div');
#
# 	JS_bank_info.hide();
# 	JS_branch_info.show();
# 	div.hide();
# 	div.filter('#JS_branch_' + index).fadeIn('fast');
# };
#
# //지점 리스트 생성
# var setCreateBranchList = function() {
# 	var index = 0;
# 	var max = data.list.length;
# 	var JS_bank_info = $('#JS_bank_info'); //지점정보
# 	var JS_branch_info = $('#JS_branch_info'); //지점리스트
#
# 	//초기화
# 	//console.log('obj.marker.length: ' + obj.marker.length);
# 	if(obj.marker.length > 0) {
# 		//지도 부분
# 		for(var loop in obj.marker) {
# 			if(typeof obj.marker[loop] != 'undefined') obj.marker[loop].setMap(null);
# 		}
# 		obj.points = [];
# 		obj.bounds = [];
# 		obj.marker = [];
# 	}
#
# 	//리스트 표시
# 	if(max <= 0) {
# 		//기존 초기화
# 		JS_bank_info.hide();
# 		JS_branch_info.hide();
# 		alert('해당 지역에는 선택하신 은행의 지점이 없습니다.');
# 		daum_map_popup.close();
# 		return;
# 	}else {
# 		//지도생성
# 		if(obj.map == null || typeof obj.map != 'object') {
# 			setMap({"lng": data.list[0].longitude, "lat": data.list[0].latitude});
# 		}
# 		//지도를 재설정할 범위정보를 가지고 있을 LatLngBounds 객체를 생성
# 		obj.bounds = new daum.maps.LatLngBounds();
# 		//지점표시
# 		var html = '';
# 		for( ; index<max; index++) {
#
# 			// ---------- Map ---------- //
#
# 			//좌표설정
# 			obj.points[index] = new daum.maps.LatLng(data.list[index].latitude, data.list[index].longitude);
#
# 			//LatLngBounds 객체에 좌표를 추가
# 			obj.bounds.extend(obj.points[index]);
#
# 			//마커설정
# 			obj.marker[index] = new daum.maps.Marker({
# 				position: obj.points[index]
# 			});
# 			obj.marker[index].setMap(obj.map);
#
# 			//인포윈도우 설정
# 			obj.infowindow[index] = new daum.maps.InfoWindow({
# 				position : obj.points[index],
# 				content : data.list[index].branch_name
# 			});
#
# 			//이벤트
# 			(function(num) {
# 				//var points = obj.points[num];
# 				var marker = obj.marker[num];
# 				//var custom_overlay = obj.custom_overlay[num];
# 				var infowindow = obj.infowindow[num];
# 				daum.maps.event.addListener(marker, 'click', function() { //클릭
# 					setBranchView(num);
# 				});
#
# 				daum.maps.event.addListener(marker, 'mouseover', function() { //마커에 마우스오버 이벤트
# 					infowindow.open(obj.map, marker);
# 				});
# 				daum.maps.event.addListener(marker, 'mouseout', function() { //마커에 마우스아웃 이벤트
# 					infowindow.close();
# 				});
#
# 			})(index);
#
# 			// ---------- ul ---------- //
#
# 			//지점
# 			html += decodeURIComponent(data.list[index].html);
# 		}
# 		obj.map.setBounds(obj.bounds);
# 		JS_branch_info.html(html);
#
# 		//지점이 하나의 경우
# 		if(max == 1) {
# 			setBranchView(0);
# 		}else {
# 			var bank_logo = JS_bank_info.find('.bank_logo');
# 			bank_logo.empty();
# 			if(data.list[0].branch_image) {
# 				bank_logo.html('<img src="' + data.list[0].branch_image + '" alt="">');
# 			}
# 			var bank_name = data.list[0].bank_name || data.list[0].branch_name || '';
# 			var bank_num = JS_bank_info.find('.bank_num');
# 			var sido = $('#sido_code').find('option').filter(':selected').text();
# 			var gugun = $('#gugun_code').find('option').filter(':selected').text();
# 			var tmp = [];
# 			var address = '';
# 			if(sido != '') tmp.push(sido);
# 			if(gugun != '') tmp.push(gugun);
#
# 			if(tmp.length > 0) address = '<span>' + tmp.join(' ') + '</span>의 ';
# 			bank_num.empty();
# 			bank_num.html(address + '\'<span>' + bank_name + '</span>\' 총 <span class="num">' + max + '</span>건');
#
# 			JS_branch_info.hide();
# 			JS_bank_info.fadeIn('fast');
# 		}
# 	}
# };
#
# //환전소 정보
# var getExchangeBranch = function(options) {
# 	var options = options || {};
#
# 	daum_map_popup.open({"callback": function() {
# 		$.ajax({
# 			url : '/ajax/select_branch_list_exchange.php',
# 			//async: false, //비동기 여부
# 			type : 'post',
# 			data : options,
# 			beforeSend: function() {
# 				//요청전
# 			},
# 			complete: function() {
# 				//요청완료
# 			},
# 			error: function() {
# 				//요청실패
# 			},
# 			//dataType: "jsonp",
# 			//jsonp : "callback",
# 			success: function(json) {
# 				//console.dir(json);
# 				if(json.msg == 'success') {
# 					//지도에 좌표표시
# 					data.list = json.data;
# 					setCreateBranchList(); //지점 리스트
# 				}
# 			}
# 		});
# 	}});
# };
#
# //지점 정보
# var getBranchMap = function(options, type) {
# 	var options = options || {};
# 	var type = type || '';
#
# 	if(type == 'loan') {
# 		daum_map_popup.open({"callback": function() {
# 			$.ajax({
# 				url : '/ajax/select_branch_list_loan.php',
# 				//async: false, //비동기 여부
# 				type : 'post',
# 				data : options,
# 				beforeSend: function() {
# 					//요청전
# 				},
# 				complete: function() {
# 					//요청완료
# 				},
# 				error: function() {
# 					//요청실패
# 				},
# 				//dataType: "jsonp",
# 				//jsonp : "callback",
# 				success: function(json) {
# 					//console.dir(json);
# 					if(json.msg == 'success') {
# 						//지도에 좌표표시
# 						data.list = json.data;
# 						setCreateBranchList(); //지점 리스트
# 					}
# 				}
# 			});
# 		}});
# 	}else if(type == 'deposit') {
# 		daum_map_popup.open({"callback": function() {
# 			$.ajax({
# 				url : '/ajax/select_branch_list_deposit.php',
# 				//async: false, //비동기 여부
# 				type : 'post',
# 				data : options,
# 				beforeSend: function() {
# 					//요청전
# 				},
# 				complete: function() {
# 					//요청완료
# 				},
# 				error: function() {
# 					//요청실패
# 				},
# 				//dataType: "jsonp",
# 				//jsonp : "callback",
# 				success: function(json) {
# 					//console.dir(json);
# 					if(json.msg == 'success') {
# 						//지도에 좌표표시
# 						data.list = json.data;
# 						setCreateBranchList(); //지점 리스트
# 					}
# 				}
# 			});
# 		}});
# 	}
# };
# </script> <script type="text/javascript">
#         //구글
#         ga('send', 'event', 'ko.Saving', 'currency', 'USD'); //통화별 클릭수
#
#         var setSearch = function(){
#             $('#search_form')[0].submit();
#         };
#         var setDiscountView = function() {
#             var popup_discount_all = $('#JS_discount_all');
#             var popup_discount_list = $('.JS_discount_list');
#             var search_form = $('#search_form');
#             var form_discount_all = search_form.find('[name="discount_all"]');
#             var form_discount_list = search_form.find('[name="discount_list"]');
#
#             //초기화
#             form_discount_all.val('');
#             form_discount_list.val('');
#             //값 검사
#             var arr = [];
#             if(MKvalidate.isNumber(popup_discount_all)) {
#                 var value = popup_discount_all.val();
#                 form_discount_all.val(value);
#             }else {
#                 popup_discount_list.each(function() {
#                     var that = $(this);
#                     var value = that.val();
#                     var code = that.data('code').replace('CODE', ''); //자바스크립트의 자동 Number 타입 변환을 방지하기 위해 CODE라는 문자열 값을 넣어주었음.
#                     if(MKvalidate.isNumber(that) && value > 0) {
#                         arr.push(code + '|' + value);
#                     }
#                 });
#                 form_discount_list.val(arr.join(','));
#             }
#             setSearch();
#         };
#
#         $(document).ready(function() {
#             //주소
#             var sido_code = $('#sido_code');
#             var gugun_code = $('#gugun_code');
#             var getGugun = function(code) {
#                 if(!code) return;
#                 $.ajax({
#                     url : '/ajax/select_gugun.php',
#                     type : 'post',
#                     data : {"code": code},
#                     beforeSend: function() {
#                         //요청전
#                     },
#                     complete: function() {
#                         //요청완료
#                     },
#                     error: function() {
#                         //요청실패
#                     },
#                     success: function(json) {
#                         if(!json) return;
#                         if(json['msg'] == 'success') {
#                             var select = '';
#                             var arr = [];
#                             for(var i=0, max=json.data.length; i<max; i++) {
#                                 arr.push('<option value="' + json.data[i]['gugun_code'] + '" ' + (select == json.data[i]['gugun_code'] ? 'selected="selected"' : '') + '>' + decodeURIComponent(json.data[i]['name_ko']) + '</option>');
#                             }
#                             gugun_code.append(arr.join(''));
#                         }else {
#                             alert('데이터 전송 중 오류가 발생했습니다.');
#                         }
#                     }
#                 });
#             };
#             sido_code.on('change', function() {
#                 var val = $(this).find('option:selected').val();
#                 //select 초기화
#                 gugun_code.find('option:not(:eq(0))').remove();
#                 if(val) {
#                     getGugun(val);
#                 }
#             });
#             getGugun(9);
#             //지도
#             $('.JS_map_view').on('click', function() {
#                 var that = $(this);
#                 var option = {
#                     "bank_code": that.attr('data-bank_code'), //은행 고유값은 숫자로 시작
#                     "branch_code": that.data('branch_code'),
#                     "cu_code": that.data('cu_code'),
#                     "data_type": that.data('data_type'),
#                     "sido_code": that.data('sido_code'),
#                     "gugun_code": that.data('gugun_code')
#                 };
#
#                 getExchangeBranch(option);
#
#                 //구글
#                 ga('send', 'event', 'ko.Saving', 'map_view', option.cu_code);
#                 ga('send', 'event', 'ko.ExchangeStation', option.cu_code, option.branch_code);
#             });
#
#             //할인율 팝업
#             var discount_popup = MKpopup({'selector': 'discount_popup', 'header': 'N', 'mask': 'Y'});
#             $('.JS_discount_open_btn').on('click', function() {
#                 discount_popup.open();
#             });
#
#             //할인율 입력
#             var JS_discount_all = $('#JS_discount_all');
#             var JS_discount_list = $('.JS_discount_list');
#             $(JS_discount_all).on('keyup', function() {
#                 var val = $(this).val();
#                 if(val != '' && !MKvalidate.isNumber(val)) {
#                     alert('숫자만 입력 가능합니다.');
#                     return;
#                 }else if(Number(val) > 100) {
#                     val = val.slice(0, -1);
#                     JS_discount_all.val(val);
#                 }
#                 JS_discount_list.val(val);
#             });
#             JS_discount_list.on('keyup', function() {
#                 var val = $.trim($(this).val());
#                 if(val != '' && !MKvalidate.isNumber(val)) {
#                     alert('숫자만 입력 가능합니다.');
#                     return;
#                 }else if(Number(val) > 100) {
#                     val = val.slice(0, -1);
#                     $(this).val(val);
#                 }
#                 if(val !== '') {
#                     JS_discount_all.val('');
#                     //JS_discount_list.not(this).val('');
#                 }
#             });
#
#             //enter event
#             setEnterEvent(JS_discount_all, setDiscountView);
#             setEnterEvent(JS_discount_list, setDiscountView);
#
#             //우대쿠폰 팝업
#             var coupon_popup = MKpopup({'selector': 'coupon_popup', 'header': 'N', 'mask': 'Y'});
#             $('.JS_coupon_open_btn').on('click', function() {
#                 coupon_popup.open();
#             });
#
#             //서브메뉴 보이기/숨기기
#             var JS_toggleList = $('.JS_toggleList');
#             $('.JS_toggle_btn').on('click', function() {
#                 var index = $(this).data('index');
#                 JS_toggleList.filter('[data-index="' + index + '"]').slideToggle();
#             });
#
#             //입력값 초기화
#             $('#money_input').on('focus', function() {
#                 $(this).val('');
#             });
#
#             //입력값 콤마
#             var setMoneyInputFormat = function() {
#                 var regNumber = /^[0-9]*$/;
#                 if(!regNumber.test($("#money_input_check").val())) {
#                     alert('숫자를 입력해주세요.');
#                     $("#money_input").val('');
#                     $("#money_input_check").val('');
#                     return;
#                 }
#                 var money_input = $('#money_input');
#                 var val1 = remove_comma($.trim(money_input.val()));
#                 //var val2 = number_format(val1);
#                 var val2 = float_format(val1);
#                 $('input[name="money"]').val(val1);
#                 money_input.val(val2);
#             };
#             $('#money_input').on('keyup', function() {
#                 $("#money_input_check").val(remove_comma($("#money_input").val()));
#                 setMoneyInputFormat();
#             });
#             setMoneyInputFormat(); //초기화
#         });
#     </script>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <!-- 할인율 입력 //-->
# <div class="popup_layer" id="discount_popup" style="display: none;background-color: #FFF;">
# <div class="pop1">
# <form>
# <table border="0" cellspacing="0" class="table_style02" summary="할인율 입력을 위한 은행 리스트입니다.">
# <caption class="pop_title02">
# <img alt="할인율 입력" src="/images/mibank/ko/t_input_discount.png">
# </img></caption>
# <tr>
# <th class="left" scope="row" style="width: 53.5%"><label for="all"><img alt="일괄적용" src="/images/mibank/ko/all_apply.png"/> </label></th>
# <td>
# <input class="input_style3" id="JS_discount_all" name="discount[]" title="일괄적용" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank0"><img alt="KEB하나은행" src="/images/mibank/ko/ico_kbbank_2015.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE005" id="bank0" name="discount[]" title="KEB하나은행 우대쿠폰 할인율 입력" type="text" value="">
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </input></td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank1"><img alt="우리은행" src="/images/mibank/ko/ico_wrbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE020" id="bank1" name="discount[]" title="우리은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank2"><img alt="KB국민은행" src="/images/mibank/ko/ico_kbbbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE004" id="bank2" name="discount[]" title="KB국민은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank3"><img alt="신한은행" src="/images/mibank/ko/ico_shbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE088" id="bank3" name="discount[]" title="신한은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank4"><img alt="NH농협은행" src="/images/mibank/ko/ico_nhbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE011" id="bank4" name="discount[]" title="NH농협은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank5"><img alt="기업은행" src="/images/mibank/ko/ico_ibkbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE003" id="bank5" name="discount[]" title="기업은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank6"><img alt="한국스탠다드차타드은행" src="/images/mibank/ko/ico_scbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE023" id="bank6" name="discount[]" title="한국스탠다드차타드은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank7"><img alt="한국씨티은행" src="/images/mibank/ko/ico_ctbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE027" id="bank7" name="discount[]" title="한국씨티은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank8"><img alt="수협은행" src="/images/mibank/ko/ico_shkbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE007" id="bank8" name="discount[]" title="수협은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank9"><img alt="부산은행" src="/images/mibank/ko/ico_bsbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE032" id="bank9" name="discount[]" title="부산은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank10"><img alt="대구은행" src="/images/mibank/ko/ico_dgbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE031" id="bank10" name="discount[]" title="대구은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank11"><img alt="전북은행" src="/images/mibank/ko/ico_jbbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE037" id="bank11" name="discount[]" title="전북은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank12"><img alt="경남은행" src="/images/mibank/ko/ico_knbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE039" id="bank12" name="discount[]" title="경남은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# <tr>
# <th class="left" scope="row"><label for="bank13"><img alt="제주은행" src="/images/mibank/ko/ico_jjbank.png"/></label></th>
# <td>
# <input class="input_style3 JS_discount_list" data-code="CODE035" id="bank13" name="discount[]" title="제주은행 우대쿠폰 할인율 입력" type="text" value=""/>
# <span class="percent"><img alt="%" src="/images/mibank/ko/percentage.png"/></span>
# </td>
# </tr>
# </table>
# </form>
# <div class="pop_close_saving">
# <a class="close" href="#none"><img alt="닫기" src="/images/mibank/ko/bt_layer_close.png"/></a>
# </div>
# <!-- 2014.11.03-->
# <p class="bt_center_pop">
# <a class="close" href="#none"><img alt="취소" src="/images/mibank/ko/canceled.png"/></a>
# <a href="#none" onclick="setDiscountView()"><img alt="확인" src="/images/mibank/ko/finished.png"/></a>
# </p>
# <!--// 2014.11.03-->
# <br/>
# </div>
# </div>
# <!-- 우대쿠폰 //-->
# <div class="popup_layer" id="coupon_popup" style="display: none; background-color: #FFF;">
# <div class="pop2">
# <ul>
# <li class="pop_title02"><span class="pop_title02"><img alt="우대쿠폰" src="/images/mibank/ko/t_good_coupon.png"/></span></li>
# <li class="good_coupon">
# <a href="http://www.keb.co.kr/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '005');" target="_blank"><img alt="KEB하나은행" src="/images/mibank/ko/ico_kbbank_2015.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="https://www.wooribank.com/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '020');" target="_blank"><img alt="우리은행" src="/images/mibank/ko/ico_wrbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="https://www.kbstar.com/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '004');" target="_blank"><img alt="KB국민은행" src="/images/mibank/ko/ico_kbbbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="http://www.shinhan.com/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '088');" target="_blank"><img alt="신한은행" src="/images/mibank/ko/ico_shbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="https://banking.nonghyup.com/nhbank.html" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '011');" target="_blank"><img alt="NH농협은행" src="/images/mibank/ko/ico_nhbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="http://www.ibk.co.kr/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '003');" target="_blank"><img alt="기업은행" src="/images/mibank/ko/ico_ibkbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="http://www.standardchartered.co.kr/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '023');" target="_blank"><img alt="한국스탠다드차타드은행" src="/images/mibank/ko/ico_scbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="http://www.citibank.co.kr/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '027');" target="_blank"><img alt="한국씨티은행" src="/images/mibank/ko/ico_ctbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="https://www.suhyup-bank.com/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '007');" target="_blank"><img alt="수협은행" src="/images/mibank/ko/ico_shkbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="http://www.busanbank.co.kr/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '032');" target="_blank"><img alt="부산은행" src="/images/mibank/ko/ico_bsbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="https://www.dgb.co.kr/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '031');" target="_blank"><img alt="대구은행" src="/images/mibank/ko/ico_dgbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="https://www.jbbank.co.kr/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '037');" target="_blank"><img alt="전북은행" src="/images/mibank/ko/ico_jbbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="http://www.knbank.co.kr/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '039');" target="_blank"><img alt="경남은행" src="/images/mibank/ko/ico_knbank.png"/></a>
# </li>
# <li class="good_coupon">
# <a href="https://www.e-jejubank.com/" onclick="ga('send', 'event', 'ko.Saving', 'good_coupon', '035');" target="_blank"><img alt="제주은행" src="/images/mibank/ko/ico_jjbank.png"/></a>
# </li>
# </ul>
# <div class="pop_close_saving">
# <a class="close" href="#none"><img alt="닫기" src="/images/mibank/ko/bt_layer_close.png"/></a>
# </div>
# </div>
# </div>
# <!-- container -->
# <div class="container_sub_banks_saving">
# <!-- left -->
# <div class="left_menu">
# <div class="world_first JS_toggle_btn" data-index="1" style="display:none;">
# 			주요국<a href="#none"><img alt="카테고리 접기" class="saving_cat_arrow" src="/images/mibank/ko/bt_close.png"/></a>
# </div>
# <ul class="menulist1 JS_toggleList" data-index="1">
# <li class=""><a href="/exchange/saving/index.php?currency=CNY"><img alt="중국" src="/images/mibank/ko/CNY.png"/>중국</a></li><li class=""><a href="/exchange/saving/index.php?currency=JPY"><img alt="일본" src="/images/mibank/ko/JPY.png"/>일본</a></li><li class="on"><a href="/exchange/saving/index.php?currency=USD"><img alt="미국" src="/images/mibank/ko/USD.png"/>미국</a></li><li class=""><a href="/exchange/saving/index.php?currency=EUR"><img alt="유럽연합" src="/images/mibank/ko/EUR.png"/>유럽연합</a></li><li class=""><a href="/exchange/saving/index.php?currency=HKD"><img alt="홍콩" src="/images/mibank/ko/HKD.png"/>홍콩</a></li><li class=""><a href="/exchange/saving/index.php?currency=TWD"><img alt="대만" src="/images/mibank/ko/TWD.png"/>대만</a></li><li class=""><a href="/exchange/saving/index.php?currency=SGD"><img alt="싱가폴" src="/images/mibank/ko/SGD.png"/>싱가폴</a></li><li class=""><a href="/exchange/saving/index.php?currency=THB"><img alt="태국" src="/images/mibank/ko/THB.png"/>태국</a></li><li class=""><a href="/exchange/saving/index.php?currency=PHP"><img alt="필리핀" src="/images/mibank/ko/PHP.png"/>필리핀</a></li><li class=""><a href="/exchange/saving/index.php?currency=VND"><img alt="베트남" src="/images/mibank/ko/VND.png"/>베트남</a></li><li class=""><a href="/exchange/saving/index.php?currency=GBP"><img alt="영국" src="/images/mibank/ko/GBP.png"/>영국</a></li><li class=""><a href="/exchange/saving/index.php?currency=AUD"><img alt="호주" src="/images/mibank/ko/AUD.png"/>호주</a></li>
# </ul>
# <div class="world JS_toggle_btn" data-index="2" style="display:none;">
# 			미주<a href="#none"><img alt="카테고리 접기" class="saving_cat_arrow" src="/images/mibank/ko/bt_close.png"/></a>
# </div>
# <ul class="menulist1 JS_toggleList" data-index="2">
# <li class=""><a href="/exchange/saving/index.php?currency=CAD"><img alt="캐나다" src="/images/mibank/ko/CAD.png"/>캐나다</a></li><li class=""><a href="/exchange/saving/index.php?currency=BRL"><img alt="브라질" src="/images/mibank/ko/BRL.png"/>브라질</a></li><li class=""><a href="/exchange/saving/index.php?currency=CLP"><img alt="칠레" src="/images/mibank/ko/CLP.png"/>칠레</a></li><li class=""><a href="/exchange/saving/index.php?currency=MXN"><img alt="멕시코" src="/images/mibank/ko/MXN.png"/>멕시코</a></li>
# </ul>
# <div class="world JS_toggle_btn" data-index="3" style="display:none;">
# 			오세아니아<a href="#none"><img alt="카테고리 접기" class="saving_cat_arrow" src="/images/mibank/ko/bt_close.png"/></a>
# </div>
# <ul class="menulist1 JS_toggleList" data-index="3">
# ...
# <td class="right counter txt_em">17.22</td>
# <td class="right counter txt_em">1.28</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="000" data-branch_code="14617" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code="231"></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_name"><a class="JS_map_view" data-bank_code="000" data-branch_code="14247" data-cu_code="USD" data-data_type="cash_buy" data-gugun_code="240" data-sido_code="9" href="#none">신세계환전소</a></span> </td>
# <td class="right counter txt_em">1325</td>
# <td class="right counter txt_em">17.22</td>
# <td class="right counter txt_em">1.28</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="000" data-branch_code="14247" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code="240"></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=031"><img alt="" src="/images/mibank/ko/ico_dgbank.png"/></a></span> </td>
# <td class="right counter txt_em">1339.03</td>
# <td class="right counter txt_em">3.19</td>
# <td class="right counter txt_em">0.24</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="031" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=037"><img alt="" src="/images/mibank/ko/ico_jbbank.png"/></a></span> </td>
# <td class="right counter txt_em">1339.03</td>
# <td class="right counter txt_em">3.19</td>
# <td class="right counter txt_em">0.24</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="037" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=027"><img alt="" src="/images/mibank/ko/ico_ctbank.png"/></a></span> </td>
# <td class="right counter txt_em">1339.08</td>
# <td class="right counter txt_em">3.14</td>
# <td class="right counter txt_em">0.23</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="027" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=088"><img alt="" src="/images/mibank/ko/ico_shbank.png"/></a></span> </td>
# <td class="right counter txt_em">1339.13</td>
# <td class="right counter txt_em">3.09</td>
# <td class="right counter txt_em">0.23</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="088" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=003"><img alt="" src="/images/mibank/ko/ico_ibkbank.png"/></a></span> </td>
# <td class="right counter txt_em">1339.13</td>
# <td class="right counter txt_em">3.09</td>
# <td class="right counter txt_em">0.23</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="003" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=011"><img alt="" src="/images/mibank/ko/ico_nhbank.png"/></a></span> </td>
# <td class="right counter txt_em">1339.33</td>
# <td class="right counter txt_em">2.89</td>
# <td class="right counter txt_em">0.22</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="011" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=005"><img alt="" src="/images/mibank/ko/ico_kbbank_2015.png"/></a></span> </td>
# <td class="right counter txt_em">1339.33</td>
# <td class="right counter txt_em">2.89</td>
# <td class="right counter txt_em">0.22</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="005" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=035"><img alt="" src="/images/mibank/ko/ico_jjbank.png"/></a></span> </td>
# <td class="right counter txt_em">1339.52</td>
# <td class="right counter txt_em">2.7</td>
# <td class="right counter txt_em">0.20</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="035" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=020"><img alt="" src="/images/mibank/ko/ico_wrbank.png"/></a></span> </td>
# <td class="right counter txt_em">1339.53</td>
# <td class="right counter txt_em">2.69</td>
# <td class="right counter txt_em">0.20</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="020" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=039"><img alt="" src="/images/mibank/ko/ico_knbank.png"/></a></span> </td>
# <td class="right counter txt_em">1339.53</td>
# <td class="right counter txt_em">2.69</td>
# <td class="right counter txt_em">0.20</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="039" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=032"><img alt="" src="/images/mibank/ko/ico_bsbank.png"/></a></span> </td>
# <td class="right counter txt_em">1339.79</td>
# <td class="right counter txt_em">2.43</td>
# <td class="right counter txt_em">0.18</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="032" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=004"><img alt="" src="/images/mibank/ko/ico_kbbbank.png"/></a></span> </td>
# <td class="right counter txt_em">1339.84</td>
# <td class="right counter txt_em">2.38</td>
# <td class="right counter txt_em">0.18</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="004" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=023"><img alt="" src="/images/mibank/ko/ico_scbank.png"/></a></span> </td>
# <td class="right counter txt_em">1340.3</td>
# <td class="right counter txt_em">1.92</td>
# <td class="right counter txt_em">0.14</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="023" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# <tr>
# <td class="first"></td>
# <td class="second">
# <span class="bank_logo"><a href="/exchange/bank/index.php?search_code=007"><img alt="" src="/images/mibank/ko/ico_shkbank.png"/></a></span> </td>
# <td class="right counter txt_em">1342.22</td>
# <td class="right counter txt_em">0</td>
# <td class="right counter txt_em">0.00</td>
# <!--//($i == 0 ? 'box box_right' : '')-->
# <td class="last box box_right">
# <!-- 2017.06.27. J. update. 날짜데이터 불러와야 함.
# 												<a href="#none" class="JS_map_view ico_spot" data-bank_code="007" data-branch_code="" data-cu_code="USD" data-data_type="cash_buy" data-sido_code="9" data-gugun_code=""></a>
# 												 -->
#                                 2023.05.22                            </td>
# </tr>
# </tbody>
# </table>
# <h6 class="warning">
# <p class="first">- 마이뱅크에서 제공하는 데이터, 자료는 단순 정보제공을 목적으로 하며, 특정 금융회사나 환전소를 권고하지 않습니다.</p>
#                     - 마이뱅크의 제공 자료는 은행의 공시 등 신뢰할만한 판단자료로 얻어진 것이나, 그 정확성이나 완전성을 보증하지는 않습니다.
#                     <p class="last">따라서 본 정보에 의존해 행해지는 행위로 인해 발생하는 결과에 대해 당사는 책임을 지지 않습니다.</p>
# </h6>
# </div>
# </div>
# <!--// right -->
# </div>
# <!-- container -->
# <!-- 테이블 순차적 fadein -->
# <script type="text/javascript">
#         $(".tb_action tbody tr:not(:first-child)").each(function (i, v ) {
#             $(this).css('animation-delay',i *0.03 +'s');
#         });
#     </script>
# <!-- 환율 롤링 count -->
# <script type="text/javascript">
#         function startCounter(){
#             $('.counter').each(function (index) {
#                 var size = $(this).text().split(".")[1] ? $(this).text().split(".")[1].length: 0;
#
#                 if($(this).text() != '-') {
#                     var amt = $(this).text().replace(",/g", "");
#                     $(this).text(amt);
#
#                     $(this).prop('Counter', 0).animate({
#                         Counter: $(this).text()
#                     }, {
#                         duration: 2000,
#                         easing: 'swing',
#                         step: function (now) {
#                             // $(this).text(parseFloat(now).toFixed(size));
#                             if((index+1)%3 == 0) gu = "%";
#                             else gu = "원";
#
#                           $(this).text(parseFloat(now).toFixed(size).replace(/\B(?=(\d{3})+(?!\d))/g, ',')+ gu);
#                         }
#                     });
#                 }
#             });
#         }
#         startCounter();
#     </script>
# <!-- dev footer append -->
# <div id="footer-append"></div>
# <!-- dev footer append -->
# <script src="/dev-js/common.js?d=1684728416" type="text/javascript"></script>
# <div class="JS_mobile_toggle appdown_area_in_mb" style="display: none;">
# <a href="/down.php" title="앱 다운로드"><img alt="앱 다운로드" src="/images/mibank/ko/bt_app_down_in_mb.png"/></a>
# </div>
# <div class="popup_wrap" id="JS_service_layer" style="display: none;">
# <img alt="로켓이미지" class="img_rocket" src="/images/mibank/ko/img_rocket.png"/>
# <div class="popup_content_wrap">
# <div class="bg_blue">
# <div class="popup_header">
# <img alt="마이뱅크" src="/images/mibank/ko/logo_blue.png"/>
# </div>
# <div class="popup_content">
# <span>10%</span><span>대 재테크</span>
# </div>
# </div>
# <a href="https://p2p.mibank.me//invest/list.php"><input class="bt_blue" name="" type="button" value="나도 참여하기"/></a>
# <div class="popup_footer">
# <a class="bt_close_today" href="#" id="JS_service_layer_check"><img alt="오늘은 그만보기" src="/images/mibank/ko/bt_view_stop_today.png"/></a>
# </div>
# </div>
# </div>
# <!-- popup -->
# <!--
# <div class="popup_for_intro" id="JS_service_layer" style=" display:none;">
# 	<div class="intro_popup_wrap">
# 		<div class="intro_popup_top">
# 			<img src="/images/mibank/ko/context_top_for_intro_pop.png" alt="마이뱅크가 제공하는 차원이 다른 서비스를 경험 해 보세요." />
# 		</div>
# 		<div class="intro_popup_buttons">
# 			<a href="#none" onclick="setServicePopup('travel')" class="bt_for_insurance_intro_popup">
# 				<img src="/images/mibank/ko/bt_insurance_for_intro_pop.png" alt="여행보험 서비스 바로가기" />
# 			</a>
# 			<a href="#none" onclick="setServicePopup('airport')">
# 				<img src="/images/mibank/ko/bt_exchange_for_intro_pop.png" alt="외화배송 서비스 바로가기" />
# 			</a>
# 		</div>
# 		<div class="intro_popup_bottom">
# 			<img src="/images/mibank/ko/context_bottom_for_intro_pop.png" alt="이용해보시고 만족하셨다면 소중한 분들과 함께 해 주세요. 이용관련 문의 070-7758-1375" />
# 		</div>
# 		<div class="intro_popup_close">
# 			<a href="#none" id="JS_service_layer_close">
# 				<img src="/images/mibank/ko/bt_close_for_intro_pop.png" alt="팝업 닫기" />
# 			</a>
# 		</div //--
# 		<div class="intro_popup_close_today">
# 			<a href="#none" id="JS_service_layer_check">
# 				<img src="/images/mibank/ko/bt_view_stop_today.png" alt="오늘은 그만보기" />
# 			</a>
# 		</div>
# 	</div>
# </div>-->
# <script type="text/javascript">
# //레이어
# var setServiceLayerClose = function() {
# 	$('#JS_service_layer').fadeOut();
# };
# $('#JS_service_layer_check').on('click', function() {
# 	if(MKcookies) {
# 		var date = new Date();
# 		var expiretime = 23-date.getHours();
# 		var expireminutes = 60-date.getMinutes();
# 		date.setHours(date.getHours()+expiretime);
# 		date.setMinutes(date.getMinutes()+expireminutes);
#
# 		MKcookies.setItem("SERVICE_LAYER", "N", date.toGMTString(), "/");
# 		setServiceLayerClose();
# 	}
# });
# $('#JS_service_layer_close').on('click', function() {
# 	setServiceLayerClose();
# });
# </script>
# <!-- // popup -->
# </body>
# </html>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://www.mibank.me/exchange/saving/index.php?currency=USD")
bsObject = BeautifulSoup(html, "html.parser")

for link in bsObject.find_all('a'):
    print(link.text.strip(), link.get('href'))
# Out:
# 절약하기 /exchange/saving/index.php
# 은행별 환율 /exchange/bank/index.php
# 가까운 환전소 /exchange/map/index.php
#  #none
#  #none
#  #none
#  #none
#  http://www.keb.co.kr/
#  https://www.wooribank.com/
#  https://www.kbstar.com/
#  http://www.shinhan.com/
#  https://banking.nonghyup.com/nhbank.html
#  http://www.ibk.co.kr/
#  http://www.standardchartered.co.kr/
#  http://www.citibank.co.kr/
#  https://www.suhyup-bank.com/
#  http://www.busanbank.co.kr/
#  https://www.dgb.co.kr/
#  https://www.jbbank.co.kr/
#  http://www.knbank.co.kr/
#  https://www.e-jejubank.com/
#  #none
#  #none
# 중국 /exchange/saving/index.php?currency=CNY
# 일본 /exchange/saving/index.php?currency=JPY
# 미국 /exchange/saving/index.php?currency=USD
# 유럽연합 /exchange/saving/index.php?currency=EUR
# 홍콩 /exchange/saving/index.php?currency=HKD
# 대만 /exchange/saving/index.php?currency=TWD
# 싱가폴 /exchange/saving/index.php?currency=SGD
# 태국 /exchange/saving/index.php?currency=THB
# 필리핀 /exchange/saving/index.php?currency=PHP
# 베트남 /exchange/saving/index.php?currency=VND
# 영국 /exchange/saving/index.php?currency=GBP
# 호주 /exchange/saving/index.php?currency=AUD
#  #none
# 캐나다 /exchange/saving/index.php?currency=CAD
# 브라질 /exchange/saving/index.php?currency=BRL
# 칠레 /exchange/saving/index.php?currency=CLP
# 멕시코 /exchange/saving/index.php?currency=MXN
#  #none
# 뉴질랜드 /exchange/saving/index.php?currency=NZD
#  #none
# 인도네시아 /exchange/saving/index.php?currency=IDR
# 말레이시아 /exchange/saving/index.php?currency=MYR
# 터키 /exchange/saving/index.php?currency=TRY
# 인도 /exchange/saving/index.php?currency=INR
# 몽골 /exchange/saving/index.php?currency=MNT
# 이스라엘 /exchange/saving/index.php?currency=ILS
# 사우디 /exchange/saving/index.php?currency=SAR
# 쿠웨이트 /exchange/saving/index.php?currency=KWD
# 바레인 /exchange/saving/index.php?currency=BHD
# U.A.E /exchange/saving/index.php?currency=AED
# 카자흐스탄 /exchange/saving/index.php?currency=KZT
# 카타르 /exchange/saving/index.php?currency=QAR
# 파키스탄 /exchange/saving/index.php?currency=PKR
# 방글라데시 /exchange/saving/index.php?currency=BDT
# 브루나이 /exchange/saving/index.php?currency=BND
# 오만 /exchange/saving/index.php?currency=OMR
# 요르단 /exchange/saving/index.php?currency=JOD
#  #none
# 스위스 /exchange/saving/index.php?currency=CHF
# 러시아 /exchange/saving/index.php?currency=RUB
# 스웨덴 /exchange/saving/index.php?currency=SEK
# 덴마크 /exchange/saving/index.php?currency=DKK
# 노르웨이 /exchange/saving/index.php?currency=NOK
# 헝가리 /exchange/saving/index.php?currency=HUF
# 체코 /exchange/saving/index.php?currency=CZK
# 폴란드 /exchange/saving/index.php?currency=PLN
#  #none
# 남아공 /exchange/saving/index.php?currency=ZAR
# 이집트 /exchange/saving/index.php?currency=EGP
# 확인 #none
# 우대쿠폰으로 다시 계산 #none
#  #none
# 나이스환전금융 #none
# 동대문OK환전 #none
# [을지로6가] 포인트환전소 #none
# 명동스카이환전 #none
# 동대문환전 #none
# 명동로사환전소 #none
# [종로] 종로환전소 #none
# 베스트환전 #none
# 한미환전 #none
# [이태원] 월드환전소 #none
# 명동제일환전센터 #none
# 중앙환전 #none
# 서울상역환전 #none
# [종로] 종로오케이환전 #none
# 플러스환전 #none
# [코엑스] 투어시티환전센터 #none
# 에프엑스코리아 #none
# 하나환전 #none
# 한양환전소 #none
# 대박나라넷 #none
# [신사역] 로얄외국환환전소 #none
# 신세계환전소 #none
#  /exchange/bank/index.php?search_code=037
#  /exchange/bank/index.php?search_code=039
#  /exchange/bank/index.php?search_code=088
#  /exchange/bank/index.php?search_code=031
#  /exchange/bank/index.php?search_code=023
#  /exchange/bank/index.php?search_code=032
#  /exchange/bank/index.php?search_code=003
#  /exchange/bank/index.php?search_code=027
#  /exchange/bank/index.php?search_code=011
#  /exchange/bank/index.php?search_code=005
#  /exchange/bank/index.php?search_code=020
#  /exchange/bank/index.php?search_code=035
#  /exchange/bank/index.php?search_code=004
#  /exchange/bank/index.php?search_code=007
#  /down.php
#  https://p2p.mibank.me//invest/list.php
#  #

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://www.mibank.me/exchange/saving/index.php?currency=USD")
bsObject = BeautifulSoup(html, "html.parser")


for meta in bsObject.head.find_all('meta'):
    print(meta.get('content'))
# Out:
# text/html; charset=utf-8
# IE=10
# width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no
# telephone=no,address=no,email=no
# no-cache
# no-cache
# 마이뱅크 | 쉽고 편리한 금융
# 쉽고 편리한 금융 : 보험, 환전, 환율/금리비교, 여행자보험
# cacf794622f86103a98af31a559a6ee76eba27ee
# 마이뱅크 | 쉽고 편리한 금융
# article
# https://www.mibank.me/exchange/saving/index.php?lang=ko
# https://www.mibank.me/dev-img/common/mibank_og_logo.png
# 마이뱅크
# 쉽고 편리한 금융 : 보험, 환전, 환율/금리비교, 여행자보험

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://www.mibank.me/exchange/saving/index.php?currency=USD")
bsObject = BeautifulSoup(html, "html.parser")

for link in bsObject.find_all('a'):
    print(link.text.strip(), link.get('href'))
# Out:
# 절약하기 /exchange/saving/index.php
# 은행별 환율 /exchange/bank/index.php
# 가까운 환전소 /exchange/map/index.php
#  #none
#  #none
#  #none
#  #none
#  http://www.keb.co.kr/
#  https://www.wooribank.com/
#  https://www.kbstar.com/
#  http://www.shinhan.com/
#  https://banking.nonghyup.com/nhbank.html
#  http://www.ibk.co.kr/
#  http://www.standardchartered.co.kr/
#  http://www.citibank.co.kr/
#  https://www.suhyup-bank.com/
#  http://www.busanbank.co.kr/
#  https://www.dgb.co.kr/
#  https://www.jbbank.co.kr/
#  http://www.knbank.co.kr/
#  https://www.e-jejubank.com/
#  #none
#  #none
# 중국 /exchange/saving/index.php?currency=CNY
# 일본 /exchange/saving/index.php?currency=JPY
# 미국 /exchange/saving/index.php?currency=USD
# 유럽연합 /exchange/saving/index.php?currency=EUR
# 홍콩 /exchange/saving/index.php?currency=HKD
# 대만 /exchange/saving/index.php?currency=TWD
# 싱가폴 /exchange/saving/index.php?currency=SGD
# 태국 /exchange/saving/index.php?currency=THB
# 필리핀 /exchange/saving/index.php?currency=PHP
# 베트남 /exchange/saving/index.php?currency=VND
# 영국 /exchange/saving/index.php?currency=GBP
# 호주 /exchange/saving/index.php?currency=AUD
#  #none
# 캐나다 /exchange/saving/index.php?currency=CAD
# 브라질 /exchange/saving/index.php?currency=BRL
# 칠레 /exchange/saving/index.php?currency=CLP
# 멕시코 /exchange/saving/index.php?currency=MXN
#  #none
# 뉴질랜드 /exchange/saving/index.php?currency=NZD
#  #none
# 인도네시아 /exchange/saving/index.php?currency=IDR
# 말레이시아 /exchange/saving/index.php?currency=MYR
# 터키 /exchange/saving/index.php?currency=TRY
# 인도 /exchange/saving/index.php?currency=INR
# 몽골 /exchange/saving/index.php?currency=MNT
# 이스라엘 /exchange/saving/index.php?currency=ILS
# 사우디 /exchange/saving/index.php?currency=SAR
# 쿠웨이트 /exchange/saving/index.php?currency=KWD
# 바레인 /exchange/saving/index.php?currency=BHD
# U.A.E /exchange/saving/index.php?currency=AED
# 카자흐스탄 /exchange/saving/index.php?currency=KZT
# 카타르 /exchange/saving/index.php?currency=QAR
# 파키스탄 /exchange/saving/index.php?currency=PKR
# 방글라데시 /exchange/saving/index.php?currency=BDT
# 브루나이 /exchange/saving/index.php?currency=BND
# 오만 /exchange/saving/index.php?currency=OMR
# 요르단 /exchange/saving/index.php?currency=JOD
#  #none
# 스위스 /exchange/saving/index.php?currency=CHF
# 러시아 /exchange/saving/index.php?currency=RUB
# 스웨덴 /exchange/saving/index.php?currency=SEK
# 덴마크 /exchange/saving/index.php?currency=DKK
# 노르웨이 /exchange/saving/index.php?currency=NOK
# 헝가리 /exchange/saving/index.php?currency=HUF
# 체코 /exchange/saving/index.php?currency=CZK
# 폴란드 /exchange/saving/index.php?currency=PLN
#  #none
# 남아공 /exchange/saving/index.php?currency=ZAR
# 이집트 /exchange/saving/index.php?currency=EGP
# 확인 #none
# 우대쿠폰으로 다시 계산 #none
#  #none
# 동대문OK환전 #none
# [을지로6가] 포인트환전소 #none
# 명동스카이환전 #none
# 나이스환전금융 #none
# 동대문환전 #none
# [종로] 종로환전소 #none
# 한미환전 #none
# [이태원] 월드환전소 #none
# 명동로사환전소 #none
# 명동제일환전센터 #none
# 중앙환전 #none
# 서울상역환전 #none
# 플러스환전 #none
# 베스트환전 #none
# [종로] 종로오케이환전 #none
# 에프엑스코리아 #none
# 하나환전 #none
# [코엑스] 투어시티환전센터 #none
# 한양환전소 #none
# 대박나라넷 #none
# [신사역] 로얄외국환환전소 #none
# 신세계환전소 #none
#  /exchange/bank/index.php?search_code=035
#  /exchange/bank/index.php?search_code=004
#  /exchange/bank/index.php?search_code=032
#  /exchange/bank/index.php?search_code=039
#  /exchange/bank/index.php?search_code=003
#  /exchange/bank/index.php?search_code=031
#  /exchange/bank/index.php?search_code=088
#  /exchange/bank/index.php?search_code=037
#  /exchange/bank/index.php?search_code=005
#  /exchange/bank/index.php?search_code=011
#  /exchange/bank/index.php?search_code=027
#  /exchange/bank/index.php?search_code=020
#  /exchange/bank/index.php?search_code=023
#  /exchange/bank/index.php?search_code=007
#  /down.php
#  https://p2p.mibank.me//invest/list.php
#  #

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://www.python.org/about")
bsObject = BeautifulSoup(html, "html.parser")


print (bsObject.head.find("meta", {"name":"description"}).get('content'))
# Out:
# The official home of the Python Programming Language

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://www.naver.com")
bsObject = BeautifulSoup(html, "html.parser")

print(bsObject) # 웹 문서 전체가 출력됩니다.
# Out:
#  <!DOCTYPE html>
#  <html class="fzoom" data-dark="false" lang="ko"> <head> <meta charset="utf-8"/> <meta content="IE=edge" http-equiv="X-UA-Compatible"/> <meta content="width=1190" name="viewport"/> <title>NAVER</title> <meta content="NAVER" name="apple-mobile-web-app-title"> <meta content="index,nofollow" name="robots"> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description"> <meta content="네이버" property="og:title"/> <meta content="https://www.naver.com/" property="og:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description"> <meta content="summary" name="twitter:card"/> <meta content="" name="twitter:title"/> <meta content="https://www.naver.com/" name="twitter:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description"> <link href="/favicon.ico?1" rel="shortcut icon" type="image/x-icon"/> <link href="https://s.pstatic.net/static/www/nFavicon96.png" rel="apple-touch-icon-precomposed"> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png" rel="apple-touch-icon" sizes="114x114"/> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png" rel="apple-touch-icon"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css" rel="stylesheet"/> <script>window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc</script> <script>try{var NNB_REGEX=/^(.*[;\s])?NNB=([^;\s]+).*$/,getNNB=function(){try{return NNB_REGEX.test(document.cookie)?document.cookie.match(NNB_REGEX)[2]:"-"}catch(e){return"-"}};window.__sendNelo=function(e){var t=new XMLHttpRequest;t.open("POST","https://nelo2-col.navercorp.com/_store",!0),t.timeout=5e3,t.send(JSON.stringify({projectName:"0043a63d2570472a8b700b985db64498",projectVersion:"1.0.0",ua:navigator.userAgent||"-",url:window.location.href||"-",logLevel:"INFO",nnb:getNNB(),body:e}))},Math.random()<.01&&window.__sendNelo("[LCS] 1/100 - check")}catch(e){}</script> <script>function getGladsdkSize(){try{return JSON.stringify(window.gladsdk).length}catch(n){return-1}}window.__script_onload=function(){setTimeout((function(){var n=getGladsdkSize();n>200||window.__sendNelo("[AD] invalid gladsdk size. "+n)}),2e3)},window.__script_onerror=function(){window.__sendNelo("[AD] fail to load gladsdk")}</script> <script async="" onerror="window.__script_onerror()" onload="window.__script_onload()" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script>
#   window["EAGER-DATA"] = window["EAGER-DATA"] || {};
#
#     window["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"_id":null,"@type":"BLOCK","@code":"PC-FEED-LIVINGHOME-CAS-EDIT","@template":"PC-FEED-CAS-EDIT","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"BLOCK","blocks":null,"materials":[{"@type":"MATERIAL-PC-FEED","title":"TV 없는 거실 만들기","url":"https://blog.naver.com/seul_0326/223102522624","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshop.phinf%2F20230515_76%2F1684145741598QDjCd_JPEG%2Fdr.jpg%22&type=ff364_236&service=navermain"},"source":{"name":"dewylight","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshop.phinf%2F20230515_230%2F1684145738418QMSKA_PNG%2FprofileImage_%25285%2529.png%22&type=nf40_40&service=navermain"}},"_id":"6441ca92c499cc07f334c49b"},{"@type":"MATERIAL-PC-FEED","title":"수납력 최대화! 실용적으로 꾸민 주방, 드레스룸, 베란다","url":"https://blog.naver.com/moodawni/223101577081","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshop.phinf%2F20230519_117%2F1684489448131IirnG_PNG%2Fcapture-20230519-184322.png%22&type=ff364_236&service=navermain"},"source":{"name":"무더니","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshop.phinf%2F20230515_116%2F1684145976902xT3oe_PNG%2FprofileImage_%25287%2529.png%22&type=nf40_40&service=navermain"}},"_id":"6441ca92c499cc07f334c49c"},{"@type":"MATERIAL-PC-FEED","title":"신혼집 랜선집들이 : 의왕 래미안에버하임 24평아파트인테리어","url":"http://blog.naver.com/1004najjang/223053409692","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogfiles.naver.net%2FMjAyMzAzMjNfNzYg%2FMDAxNjc5NTM1MzQ5MDE3.hvw2KTaWcSGGTQKy38ltQTL6r9PDWdkZJvb1RLRez6Ig.Vu5a8mUYjh_crZQgpatLutQcmW43-fVp65skz00gO8Ig.JPEG.1004najjang%2F%EC%9D%98%EC%99%95_%EB%9E%98%EB%AF%B8%EC%95%88%EC%97%90%EB%B2%84%ED%95%98%EC%9E%84_24%ED%8F%8908.jpg%22&type=ff364_236&service=navermain"},"source":{"name":"리썸 디자인","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogpfthumb.phinf.naver.net%2FMjAyMDExMThfMTkx%2FMDAxNjA1NzA1ODg2ODc2.T3oIKGE8-1zxHR-CxzL6jGIEtKkQGhgcc7p6WSWr-Uwg.MhFU818JdQMvjZx3uMI4J9-0_O8bYDPWXMe0PMxXnOcg.JPEG.1004najjang%2F1_8-1.jpg%22&type=nf40_40&service=navermain"}},"_id":"6441ca92c499cc07f334c49d"},{"@type":"MATERIAL-PC-FEED","title":"개방감까지 좋다","url":"https://post.naver.com/viewer/postView.naver?volumeNo=35899689&memberNo=1606529","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshop.phinf%2F20230519_242%2F1684489167179bPWz2_PNG%2Fcapture-20230519-183732.png%22&type=ff364_236&service=navermain"},"source":{"name":"월간 더리빙","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshop.phinf%2F20230517_147%2F1684284822866IJztL_JPEG%2FBB.jpg%22&type=nf40_40&service=navermain"}},"_id":"6441ca92c499cc07f334c49e"},{"@type":"MATERIAL-PC-FEED","title":"매일 열리는 우리 집 홈카페","url":"https://blog.naver.com/jelintea/223081768610","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshop.phinf%2F20230510_106%2F1683712000976YsJIz_PNG%2Fp.PNG%22&type=ff364_236&service=navermain"},"source":{"name":"비자림","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshop.phinf%2F20230510_297%2F1683711994583Jjej8_JPEG%2F%25BA%25F1%25C0%25DA%25B8%25B2%252B%25C7%25C1%25B7%25CE%25C7%25CA%25BB%25E7%25C1%25F8.jpg%22&type=nf40_40&service=navermain"}},"_id":"6441ca92c499cc07f334c49f"},{"@type":"MATERIAL-PC-FEED","title":"로망이 실현된 오픈 주방","url":"https://blog.naver.com/amy8277/223084667026","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshop.phinf%2F20230515_239%2F1684145489287ldXbE_JPEG%2Feg.jpg%22&type=ff364_236&service=navermain"},"source":{"name":"1982home","image":{"url ...
#
#     window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6433d8e3a10d3006850274e8","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SPECIAL-LOGO","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"7e249ade-f855-11ed-afb0-6355d78fca9d","@provider":"lambda","@lastModifiedAt":[2023,5,22,4,2,39,199000000]}
#
#     window["EAGER-DATA"]["PC-MEDIA-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-NEWSSTAND-BLOCK","blocks":[{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":[{"@type":"MATERIAL-PC-NEWSSTAND-HEADLINE","gdid":null,"title":"만개한 장미꽃 사이 상춘객 북적","url":"http://www.kbmaeil.com/news/articleView.html?idxno=958975","aid":"b322b88e4b781dce","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fnewsstand%2F2023%2F0522%2Farticle_img%2Fnew_main%2F9123%2F125535_001.jpg%22&type=nf312_208&service=navermain"},"_id":"643e68a2530d8014e0e206d4"},{"@type":"MATERIAL-PC-NEWSSTAND-HEADLINE","gdid":null,"title":"\"포항시민 고교평준화 인식 긍정·부정 팽팽\"","url":"http://www.kbmaeil.com/news/articleView.html?idxno=959004","aid":"b3230a4ac214b30a","image":null,"_id":"64649e497dd28a7aefb64f39"},{"@type":"MATERIAL-PC-NEWSSTAND-HEADLINE","gdid":null,"title":"전세 사기 부동산 중개보조원 구속…3천여만원 가로채","url":"http://www.kbmaeil.com/news/articleView.html?idxno=959007","aid":"b3230a4d9cc33fcd","image":null,"_id":"64649e497dd28a7aefb64f3a"},{"@type":"MATERIAL-PC-NEWSSTAND-HEADLINE","gdid":null,"title":"경북 산업단지 지붕 태양광 확대…영천·구미·경산서 첫 사업","url":"http://www.kbmaeil.com/news/articleView.html?idxno=959005","aid":"b3230a4bb5a4374b","image":null,"_id":"64649e497dd28a7aefb64f3b"},{"@type":"MATERIAL-PC-NEWSSTAND-HEADLINE","gdid":null,"title":"“신규사업지 부동산 취득 상시 전수조사 ”","url":"http://www.kbmaeil.com/news/articleView.html?idxno=958998","aid":"b322b8cf4ea389cf","image":null,"_id":"64668a797a6b147b6beb2ad5"},{"@type":"MATERIAL-PC-NEWSSTAND-HEADLINE","gdid":null,"title":"‘지역역량강화사업 부정수급 의혹’ 일파만파","url":"http://www.kbmaeil.com/news/articleView.html?idxno=958989","aid":"b322b8b1adf49e71","image":null,"_id":"64668a797a6b147b6beb2ad6"},{"@type":"MATERIAL-PC-NEWSSTAND-HEADLINE","gdid":null,"title":"불빛축제 기간 포항사랑상품권 10% 할인","url":"http://www.kbmaeil.com/news/articleView.html?idxno=958977","aid":"b322b89032972650","image":null,"_id":"64668a797a6b147b6beb2ad7"}],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"907","name":"경북매일신문","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/907.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/907.png"},"showThumbnailView":true,"showListView":true,"regDate":"20230522 12:50:20","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":[{"@type":"MATERIAL-PC-NEWSSTAND-HEADLINE","gdid":null,"title":"‘한·미·일 공조’ 새로운 수준으로 발전 합의","url":"https://kookbang.dema.mil.kr/newsWeb/20230522/4/ATCE_CTGR_0030020000/view.do","aid":"fb2e1d31767eddef","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fnewsstand%2F2023%2F0521%2Farticle_img%2Fnew_main%2F9140%2F173208_001.jpg%22&type=nf312_208&service=navermain"},"_id":"643e68a2530d8014e0e206db"},{"@type":"MATERIAL-PC-NEWSSTAND-HEADLINE","gdid":null,"title":"이종섭 국방부 장관 “과학기술 강군 위한 긴밀한 국방AI 협업체계 구축”","url":"https://kookbang.dema.mil.kr/newsWeb/20230522/4/ATCE_CTGR_0010010000/view.do","aid":"49875af2861b85ce","image":null,"_id":"643e68a2530d8014e0e206dc"},{"@type":"MATERIAL-PC-NEWSSTAND-HEADLINE","gdid":null,"title":"부활한 ‘천안함’ 다시 조국 해양수호 앞장선다","url":"https://kookbang.dema.mil.kr/newsWeb/20230522/4/ATCE_CTGR_0010040000/view.do","aid":"15106e7530bca7ab","image":null,"_id":"643e68a2530d8014e0e206dd"},{"@type":"MATERIAL-PC-NEWSSTAND-HEADLINE","gdid":null,"title":"[국방일보 기자가 간다] 신임 장교 지휘참모과정 유격훈련","url":"https://kookbang.dema.mil.kr/newsWeb/20230522/1/ATCE_CTGR_0010030000/view.do","aid":"24876517502c3289","image":null,"_id":"643e68a2530d8014e0e206de"},{"@type":"MATERIAL-PC-NEWSSTAND-HEADLINE","gdid":null,"title":"육군1보병사단 수색대대, 수색종합훈련 현장을 가다","url":"https://kookbang.dema.mil.kr/newsWeb/20230522/8/ATCE_CTGR_0010030000/view.do","aid":"294016702cc70d10","image":null,"_id":"643e68a2530d801 ...
#
#     window["EAGER-DATA"]["PC-NEWSSTAND-YONHAP"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":null,"materials":[],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"_id":null,"@type":"BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}],"materials":[{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"정부 후쿠시마 오염수 시찰단, 일본서 공식일정 시작","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013955537","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"643543b2caf3d87b7e0a0da6"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"'등록 재산에 가상자산 포함' 법안 통과…21대 의원도 등록해야","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013956300","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"6467ee3ef04b5ed2c5368317"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"전세사기 특별법, 소위통과…최우선변제금 최장 10년 무이자대출","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013956285","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"6467ee3ef04b5ed2c5368318"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"검찰, '김남국 코인' 예치서비스 운영사 압수수색","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013956278","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"6467ee3ef04b5ed2c5368319"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"한미일 워싱턴 3자회담 7월 가능성…한미일판 셔틀정상외교 거론","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013956167","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"6467ee3ef04b5ed2c536831a"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"박진 \"尹, 한일정상회담서 오염수 문제 입장 확실히 말해\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013956276","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"6467ee3ef04b5ed2c536831b"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"개인정보 건당 1천원 판매·불법대출 광고…대부업체 대거 적발","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013956206","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"6467ee3ef04b5ed2c536831c"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"검찰, 윤관석 소환…'현역의원에 돈봉투' 조사","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013955962","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"6467ee3ef04b5ed2c536831d"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"우크라이나에 지원 가능한 '비살상 무기'는…정부, 선별 착수","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013955954","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"6467ee3ef04b5ed2c536831e"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"1분기 전기·가스 물가지수 30.5% 상승…외환위기 이후 최고","url":"ht ...
#
#     window["EAGER-DATA"]["CAS-MINICONTENT-PC-SEARCH-RIGHT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"imageDark":"https://s.pstatic.net/static/www/mobile/edit/20230517_1095/upload_1684316175644FMYI4.png","image":"https://s.pstatic.net/static/www/mobile/edit/20230517_1095/upload_1684316169642tHsLu.png","url":"https://campaign.naver.com/collect_v2/?pcode=naver_pcanniversary&event_id=2023newPC&target=https%3A%2F%2Fcampaign.naver.com%2Fnaverdetails%2Fnewpc","alt":"새로워진 네이버 PC 메인"},"exposure":true,"@miniContentId":"6464a2ce80c83668a7005861","@miniContentCode":"PC-SEARCH-RIGHT","@startAt":"2023-05-17 00:00","@endAt":"2023-05-31 23:59","@createdAt":"2023-05-17T18:47:58.764","@updatedAt":"2023-05-18T12:00:07.777"},{"content":{"imageDark":"https://s.pstatic.net/static/www/mobile/edit/20230517_1095/upload_1684316106870X9zbK.png","image":"https://s.pstatic.net/static/www/mobile/edit/20230517_1095/upload_1684316098099YAFpj.png","url":"https://campaign.naver.com/collect_v2/?pcode=naver_pcanniversary&event_id=2023newPC&target=https%3A%2F%2Fcampaign.naver.com%2Fnaverdetails%2Fnewpc","alt":"새로워진 네이버 PC 메인"},"exposure":true,"@miniContentId":"6464a2d37b0fdd62fac158e4","@miniContentCode":"PC-SEARCH-RIGHT","@startAt":"2023-05-17 00:00","@endAt":"2023-05-31 23:59","@createdAt":"2023-05-17T18:48:03.132","@updatedAt":"2023-05-18T11:59:59.642"}],"_id":"6433d8a5a10d300685012682","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SEARCH-RIGHT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"7cf0126e-f855-11ed-afb0-7be3787e9e50","@provider":"lambda","@lastModifiedAt":[2023,5,22,4,2,37,76000000]}
#
#     window["EAGER-DATA"]["CAS-MINICONTENT-PC-MEDIA-TAB-EVENT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"643687e1a10d300685630556","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MEDIA-TAB-EVENT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"842f89ec-f855-11ed-abac-894fb876555f","@provider":"lambda","@lastModifiedAt":[2023,5,22,4,2,49,231000000]}
#
# </script>
# <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/polyfill.f47ccc9a.js?o=www"></script><script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/preload.06cdf21d.js?o=www"></script><script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/search.27c2ad9d.js?o=www"></script><script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/main.05c2c9b5.js?o=www"></script><link href="https://pm.pstatic.net/resources/css/main.d7aa8e78.css" rel="stylesheet"/></link></meta></meta></meta></meta></meta></head> <body> <div id="u_skip"> <a href="#"><span>바로가기</span></a> </div> <script data-gfp-banner-size="830x130" data-gfp-banner-type="full" id="ad-timeboard-response" type="text/plain">{"requestId":"a31b4cdeaa1a40eda8536d0c57c0c1c2","head":{"version":"0.0.1","description":"Naver SSP Waterfall List"},"eventTracking":{"ackImpressions":[{"url":"https://tivan.naver.com/sc2/1/"}],"activeViewImpressions":[{"url":"https://tivan.naver.com/sc2/2/"}],"clicks":[{"url":"https://tivan.naver.com/sc2/3/"}],"completions":[{"url":"https://tivan.naver.com/sc2/4/"}],"attached":[{"url":"https://tivan.naver.com/sc2/10/"}],"renderedImpressions":[{"url":"https://tivan.naver.com/sc2/11/"}],"viewableImpressions":[{"url":"https://tivan.naver.com/sc2/12/"}],"loadErrors":[{"url":"https://tivan.naver.com/sc2/91/"}],"startErrors":[{"url":"https://tivan.naver.com/sc2/92/"}],"mute":[{"url":"https://tivan.naver.com/sc2/5/"}]},"adUnit":"p_main_timeboard_v1","randomNumber":75,"adDivId":"ad_timeboard","ads":[{"encrypted":"pOb57hAgl5gE_QWoGM6QsSrjsUnjGS4p4fvK8jahWGHX_ato4iwtVyPNUF8l4v1FbYC2c9pJ66Gwiuy1VfNR-t0lQdHXQYj8rPdZqbChIm8xpbuI2q73yUIIMXjIhJtFLC4HNdeaQGq2t2V8tOjoNsqRaS0IiuI2ZpkABtmVYkK1FOfsZ0kYLIzHuv9llQighu4x9yejJZEipSpUjayDAp2-fMU283S05wBfqn43liB5SyfOwAh3hy4uHfK9bMRmzBGySo5awyAoLhHXBKrFUnp6VSSsw9MvwxvExrvs9C8Z5cK2VOIzXFglN4UjLLCPgfTUcXqsc9np_xrCOD5ryeI6kuHzXJpylDbQ8wxYLvBNjSnr8RUQuj6R93hKcyK5Zo62jrqoOd2a5XGJxMRvID4jy2ZtWYX1AOH2RYd1nkXU2IlCYV0jxSPnffHIz53IaqQKiyTRLiVCZtO8lmoVFYgxupJKVYAz2NsiIDRiJr_Z_kKaMXv8apvlooEqtHg0uJIdWpH_MLQ2CZhcGduE3OChgoW8TaJmqcv4Wuvy4Ezg33X-RiWf0JSH4MSXVEa3RlIXRJkOnzWc2oWM-seSczCo8uoWaG-FTWlEXVTVJeyWnSlxo7yLDVgexnOEye4RvB6WRN0Rj76hNkbfquo-yEU4ipro0ZZS-RpwEhugPLEma0W3DYRjb3zhyfq1kFOLuBq7NZhWbn-BdBqXzURrNQ==","connectionType":"S2S","adProviderType":"IN_NAVER","adProviderName":"NDP_SF","layoutType":"FLUID","creativeType":"BANNER","renderType":"SF","eventTracking":{"ackImpressions":[{"url":"https://siape.veta.naver.com/openrtb/nurl?eu=EU10043565\u0026calp=-\u0026oj=cQgn6aire5PVt0%2BV1srWKzDPNWU1pH8EqDrb%2BTalo7nbMIGV2PBYdIkMR78spZPHJL1qM2Pf%2FanY4vxme6ckuZp%2BRbuAiarlFLxTGzkOQsDO9PohFosHG0plqdgUSG%2BUXrQSw%2B%2FX1bbNCF9%2F110BZDp0hCNKO%2BcHo2M9jEOAPSLbaIdXv9YIFqKzdZWOwZvb0I2S64hazz4\u0026ac=8777526\u0026src=6508746\u0026evtcd=BID_WIN\u0026x_ti=1487\u0026rk=0qU1gFGPY7D0CsPf8-aKjA\u0026eltts=1ykUO9Xv9SDFQ1NSPRC2hQ%3D%3D\u0026brs=Y\u0026"}],"attached":[],"activeViewImpressions":[],"renderedImpressions":[],"viewableImpressions":[],"clicks":[],"vimp1px":[],"vimp100":[],"vimp100p":[],"admute":[],"advmute":[],"like":[],"unlike":[],"close":[],"bounce":[]},"adInfo":{"placeId":"6436232db28a76002ea3f30c","exp":3258,"adm":"%3Cscript%20src%3D%22https%3A%2F%2Fssl.pstatic.net%2Fmelona%2Flibs%2Fglad%2Fbridge%2Fgfp-bridge.js%22%3E%3C%2Fscript%3E%0D%0A%0D%0A%3Ca%20href%3D%22https%3A%2F%2Fsiape.veta.naver.com%2Ffxclick%3Feu%3DEU10043565%26calp%3D-%26oj%3DcQgn6aire5PVt0%252BV1srWKzDPNWU1pH8EqDrb%252BTalo7nbMIGV2PBYdIkMR78spZPHJL1qM2Pf%252FanY4vxme6ckuZp%252BRbuAiarlFLxTGzkOQsDO9PohFosHG0plqdgUSG%252BUXrQSw%252B%252FX1bbNCF9%252F110BZDp0hCNKO%252BcHo2M9jEOAPSLbaIdXv9YIFqKzdZWOwZvb0I2S64hazz4%26ac%3D8777526%26src%3D6508746%26br%3D4250382%26evtcd%3DP901%26x_ti%3D1487%26tb%3D%26oid%3D%26sid1%3D%26sid2%3D%26rk%3D0qU1gFGPY7D0CsPf8-aKjA%26eltts%3D1ykUO9Xv9SDFQ1NSPRC2hQ%253D%253D%26lu%3D%26brs%3DY%26%22%20id%3D%22ac_banner_a%22%20target%3D%22_blank%22%20sty ...
# </script> <div id="wrap"> <div id="header" role="banner"> <div class="header_inner" id="topSearchWrap"> <div class="search_special_bg" id="special-logo"></div> <div class="ad_area" id="timeboard-ex" style="min-width:1480px"> </div> <div class="search_area" id="search_area" style="border-color:#fff"> <a class="link_search_special" href="/" id="special-input-logo-ex" onclick='window.nclk_v2(this,"top.spinputlogo")' style="display:none"></a> <div class="search_group"> <div class="search_group_inner" id="search"> <h1 class="search_logo" id="special-input-logo"></h1> <form action="https://search.naver.com/search.naver" id="sform" method="get" name="search" role="search"> <fieldset> <legend class="blind">검색</legend> <input name="where" type="hidden" value="nexearch"/> <input id="sm" name="sm" type="hidden" value="top_hty"/> <input id="fbm" name="fbm" type="hidden" value="0"/> <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/> <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/> <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/> <input id="ie" name="ie" type="hidden" value="utf8"/> <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/> <input disabled="disabled" id="os" name="os" type="hidden" value=""/> <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/> <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/> <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/> <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/> <div class="search_input_box"> <input autocomplete="off" class="search_input" data-atcmp-element="" id="query" maxlength="255" name="query" placeholder="검색어를 입력해 주세요." title="검색어를 입력해 주세요." type="search"/> </div> <button class="btn_search" onclick='window.nclk_v2(this,"sch.action")' type="submit"> <span class="ico_btn_search" id="search-btn"></span> <span class="blind">검색</span> </button> </fieldset> </form> <div class="search_box"> <button class="btn_keyboard" id="ke_kbd_btn" type="button"> <span class="keybord_text"> <span class="blind">입력도구</span> </span> </button> <div id="_nx_kbd" style="display:none"></div> <button class="btn_arrow" data-atcmp-element="" id="nautocomplete" type="button"> <span class="blind">자동완성/최근검색어펼치기</span> </button> </div> <div class="layer_atcmp" id="autoFrame" style="display:none"> <div class="ly_atcmp" data-atcmp-element=""> <div class="api_atcmp_wrap"> <div class="atcmp_fixer _recent_layer" style="display:none"> <div class="atcmp_header _recent_header"> <strong class="tit">최근검색어</strong> <div class="option"> <a aria-pressed="false" class="item _delAll" href="#" role="button">전체삭제</a> </div> </div> <div class="atcmp_container"> <ul class="kwd_lst _recent"> <li class="item _item" data-keyword="@in_txt@" data-rank="@rank@" data-template-type="history"> <a class="kwd" href="#"> <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span><span>@txt@</span></span> </a> <span class="etc"> <em class="date">@date@.</em> <a aria-pressed="false" class="bt_item _del" href="#" role="button"><i class="imsc ico_del">삭제</i></a> </span> </li> </ul> <div class="kwd_info kwd_off _offMsg" style="display:none">검색어 저장 기능이 꺼져 있습니다.<br/><span class="kwd_dsc">설정이 초기화 된다면 <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/support/alias/search/word/word_29.naver" target="_blank">도움말</a>을 확인해주세요.</span></div> <div class="kwd_info kwd_none _recentNone" style="display:none">최근 검색어 내역이 없습니다.<br/><span class="kwd_dsc">설정이 초기화 된다면 <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/support/alias/search/word/word_29.naver" target="_blank">도움말</a>을 확인해주세요.</span></div> </div> <div class="atcmp_footer"> <span class="side_opt_area"> <span class="opt_item"><a data-clk="sly.help" href="https://help.naver.com/support/service/main.help?serviceNo=605&amp;categoryNo=1991" target="_blank">도움말</a></span> </span> <span class= ...
#         window['EAGER-DATA']['GV'] = {
#             svt: '20230522130540',  }; </script> <script>(()=>{function t(t){var e=document.getElementById("search_area"),n=document.getElementById("search-btn");t?(e&&e.setAttribute("style","border-color: "+t),n&&n.setAttribute("class","ico_btn_search type_color"),n&&n.setAttribute("style","background-color: "+t)):e&&e.removeAttribute("style")}var e=window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"];if(e&&e.items&&e.items.length>0!=!1){var n=Math.floor(Math.random()*e.items.length),o=e.items[n];e.items=[o],t(o&&o.content&&o.content.input&&o.content.input.color);var r=o&&o.content&&o.content.input&&o.content.input.placeholder;if(r){var c=document.getElementById("query");c&&r&&c.setAttribute("title",r),c&&r&&c.setAttribute("placeholder",r)}}else t()})()</script> <script>window.__timeboard_rendered=!1,window.__timeboard_called=!1,window.__timeboard_called2=!1,window.__timeboard_gladsdksize=0</script> </body> </html>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://www.naver.com")
bsObject = BeautifulSoup(html, "html.parser")

for link in bsObject.find_all('a'):
    print(link.text.strip(), link.get('href'))
# Out:
# 바로가기 #
#  /
# 전체삭제 #
# @txt@ #
# 삭제 #
# 도움말 https://help.naver.com/support/alias/search/word/word_29.naver
# 도움말 https://help.naver.com/support/alias/search/word/word_29.naver
# 도움말 https://help.naver.com/support/service/main.help?serviceNo=605&categoryNo=1991
# 자동저장 끄기 #
# @5@회 당첨번호  동행복권 제공     @6@@7@@8@@9@@10@@11@@12@ #
# @14@  @txt@@currency@  @8@(@9@%)    @6@원 #
# @txt@  @7@, @message@     @7@ @8@° #
# @txt@  @5@    바로가기 @5@
# @txt@ #
# 추가 #
# @txt@ #
# 추가 #
# @query@ @intend@ #
# 추가 #
# 자세히보기 #
# 관심사를 반영한 컨텍스트 자동완성도움말 https://help.naver.com/support/alias/search/word/word_16.naver
# 컨텍스트 자동완성 #
# 자세히 https://help.naver.com/support/alias/search/word/word_16.naver
# 로그인 https://nid.naver.com/nidlogin.login
# 자세히 https://help.naver.com/support/alias/search/word/word_16.naver
# 컨텍스트 자동완성 레이어 닫기 #
# 도움말 https://help.naver.com/support/service/main.help?serviceNo=605&categoryNo=1987
# 신고 https://help.naver.com/support/contents/contents.help?serviceNo=605&categoryNo=18215
# 자동완성 끄기 #

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://www.python.org/about")     
bsObject = BeautifulSoup(html, "html.parser")

# %%
bsObject
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->
# <!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->
# <!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->
# <!--[if gt IE 8]><!--><html class="no-js" dir="ltr" lang="en"> <!--<![endif]-->
# <head>
# <!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-TF35YF9CVH"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#       gtag('config', 'G-TF35YF9CVH');
#     </script>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="//ajax.googleapis.com/ajax/libs/jquery/1.8.2/jquery.min.js" rel="prefetch"/>
# <link href="//ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.js" rel="prefetch"/>
# <meta content="Python.org" name="application-name"/>
# <meta content="The official home of the Python Programming Language" name="msapplication-tooltip"/>
# <meta content="Python.org" name="apple-mobile-web-app-title"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="True" name="HandheldFriendly"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="on" http-equiv="cleartype"/>
# <meta content="false" http-equiv="imagetoolbar"/>
# <script async="" crossorigin="anonymous" integrity="sha256-U3hKDidudIaxBDEzwGJApJgPEf2mWk6cfMWghrAa6i0= sha384-UcmsCqcNRSLW/dV3Lo1oCi2/VaurXbib6p4HyUEOeIa/4OpsrnucrugAefzVZJfI sha512-q4t1L4xEjGV2R4hzqCa41P8jrgFUS8xTb8rdNv4FGvw7FpydVj/kkxBJHOiaoxHa8olCcx1Slk9K+3sNbsM4ug==" src="https://media.ethicalads.io/media/client/v1.4.0/ethicalads.min.js"></script>
# <script src="/static/js/libs/modernizr.js"></script>
# <link href="/static/stylesheets/style.2135bffe4dde.css" media="all" rel="stylesheet" title="default" type="text/css">
# <link href="/static/stylesheets/mq.f9187444a4a1.css" media="not print, braille, embossed, speech, tty" rel="stylesheet" type="text/css">
# <!--[if (lte IE 8)&(!IEMobile)]>
#     <link href="/static/stylesheets/no-mq.bf0c425cdb73.css" rel="stylesheet" type="text/css" media="screen" />
#
#
#     <![endif]-->
# <link href="//ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/themes/smoothness/jquery-ui.css" rel="stylesheet"/>
# <link href="/static/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="/static/apple-touch-icon-144x144-precomposed.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <link href="/static/apple-touch-icon-114x114-precomposed.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <link href="/static/apple-touch-icon-72x72-precomposed.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# <link href="/static/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed"/>
# <link href="/static/apple-touch-icon-precomposed.png" rel="apple-touch-icon"/>
# <meta content="/static/metro-icon-144x144-precomposed.png" name="msapplication-TileImage"/><!-- white shape -->
# <meta content="#3673a5" name="msapplication-TileColor"/><!-- python blue -->
# <meta content="#3673a5" name="msapplication-navbutton-color"/>
# <title>About Python™ | Python.org</title>
# <meta content="The official home of the Python Programming Language" name="description"/>
# <meta content="Python programming language object oriented web free open source software license documentation download community" name="keywords"/>
# <meta content="website" property="og:type"/>
# <meta content="Python.org" property="og:site_name"/>
# <meta content="Welcome to Python.org" property="og:title"/>
# <meta content="The official home of the Python Programming Language" property="og:description"/>
# <meta content="https://www.python.org/static/opengraph-icon-200x200.png" property="og:image"/>
# <meta content="https://www.python.org/static/opengraph-icon-200x200.png" property="og:image:secure_url"/>
# <meta content="https://www.python.org/about/" property="og:url"/>
# <link href="/humans.txt" rel="author"/>
# <link href="https://www.python.org/dev/peps/peps.rss/" rel="alternate" title="Python Enhancement Proposals" type="application/rss+xml"/>
# <link href="https://www.python.org/jobs/feed/rss/" rel="alternate" title="Python Job Opportunities" type="application/rss+xml"/>
# <link href="https://feeds.feedburner.com/PythonSoftwareFoundationNews" rel="alternate" title="Python Software Foundation News" type="application/rss+xml"/>
# <link href="https://feeds.feedburner.com/PythonInsider" rel="alternate" title="Python Insider" type="application/rss+xml"/>
# <script type="application/ld+json">
#      {
#        "@context": "https://schema.org",
#        "@type": "WebSite",
#        "url": "https://www.python.org/",
#        "potentialAction": {
#          "@type": "SearchAction",
#          "target": "https://www.python.org/search/?q={search_term_string}",
#          "query-input": "required name=search_term_string"
#        }
#      }
#     </script>
# <script type="text/javascript">
#     var _gaq = _gaq || [];
#     _gaq.push(['_setAccount', 'UA-39055973-1']);
#     _gaq.push(['_trackPageview']);
#
#     (function() {
#         var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#         ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#         var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#     })();
#     </script>
# </link></link></head>
# <body class="python about">
# <div id="touchnav-wrapper">
# <div class="do-not-print" id="nojs">
# <p><strong>Notice:</strong> While JavaScript is not essential for this website, your interaction with the content will be limited. Please turn JavaScript on for the full experience. </p>
# </div>
# <!--[if lte IE 8]>
#         <div id="oldie-warning" class="do-not-print">
#             <p>
#                 <strong>Notice:</strong> Your browser is <em>ancient</em>. Please
#                 <a href="http://browsehappy.com/">upgrade to a different browser</a> to experience a better web.
#             </p>
#         </div>
#         <![endif]-->
# <!-- Sister Site Links -->
# <div class="top-bar do-not-print" id="top">
# <nav class="meta-navigation container" role="navigation">
# <div class="skip-link screen-reader-text">
# <a href="#content" title="Skip to content">Skip to content</a>
# </div>
# <a aria-hidden="true" class="jump-link" href="#python-network" id="close-python-network">
# <span aria-hidden="true" class="icon-arrow-down"><span>▼</span></span> Close
#                 </a>
# <ul class="menu" role="tree">
# <li class="python-meta current_branch selected">
# <a class="current_branch selected" href="/" title="The Python Programming Language">Python</a>
# </li>
# <li class="psf-meta">
# <a href="https://www.python.org/psf/" title="The Python Software Foundation">PSF</a>
# </li>
# <li class="docs-meta">
# <a href="https://docs.python.org" title="Python Documentation">Docs</a>
# </li>
# <li class="pypi-meta">
# <a href="https://pypi.org/" title="Python Package Index">PyPI</a>
# </li>
# <li class="jobs-meta">
# <a href="/jobs/" title="Python Job Board">Jobs</a>
# </li>
# <li class="shop-meta">
# <a href="/community-landing/">Community</a>
# </li>
# </ul>
# <a aria-hidden="true" class="jump-link" href="#top" id="python-network">
# <span aria-hidden="true" class="icon-arrow-up"><span>▲</span></span> The Python Network
#                 </a>
# </nav>
# </div>
# <!-- Header elements -->
# <header class="main-header" role="banner">
# <div class="container">
# <h1 class="site-headline">
# <a href="/"><img alt="python™" class="python-logo" src="/static/img/python-logo.png"/></a>
# </h1>
# <div class="options-bar-container do-not-print">
# <a class="donate-button" href="https://psfmember.org/civicrm/contribute/transact?reset=1&amp;id=2">Donate</a>
# <div class="options-bar">
# <a class="jump-to-menu" href="#site-map" id="site-map-link"><span class="menu-icon">≡</span> Menu</a><form action="/search/" class="search-the-site" method="get">
# <fieldset title="Search Python.org">
# <span aria-hidden="true" class="icon-search"></span>
# <label class="screen-reader-text" for="id-search-field">Search This Site</label>
# <input class="search-field" id="id-search-field" name="q" placeholder="Search" role="textbox" tabindex="1" type="search" value=""/>
# <button class="search-button" id="submit" name="submit" tabindex="3" title="Submit this Search" type="submit">
#                                     GO
#                                 </button>
# <!--[if IE]><input type="text" style="display: none;" disabled="disabled" size="1" tabindex="4"><![endif]-->
# </fieldset>
# </form><span class="breaker"></span><div aria-hidden="true" class="adjust-font-size">
# <ul aria-label="Adjust Text Size on Page" class="navigation menu">
# <li aria-haspopup="true" class="tier-1 last">
# <a class="action-trigger" href="#"><strong><small>A</small> A</strong></a>
# <ul class="subnav menu">
# <li class="tier-2 element-1" role="treeitem"><a class="text-shrink" href="javascript:;" title="Make Text Smaller">Smaller</a></li>
# <li class="tier-2 element-2" role="treeitem"><a class="text-grow" href="javascript:;" title="Make Text Larger">Larger</a></li>
# <li class="tier-2 element-3" role="treeitem"><a class="text-reset" href="javascript:;" title="Reset any font size changes I have made">Reset</a></li>
# </ul>
# </li>
# </ul>
# </div><div class="winkwink-nudgenudge">
# <ul aria-label="Social Media Navigation" class="navigation menu">
# <li aria-haspopup="true" class="tier-1 last">
# <a class="action-trigger" href="#">Socialize</a>
# <ul class="subnav menu">
# <li class="tier-2 element-1" role="treeitem"><a href="https://www.facebook.com/pythonlang?fref=ts"><span aria-hidden="true" class="icon-facebook"></span>Facebook</a></li>
# <li class="tier-2 element-2" role="treeitem"><a href="https://twitter.com/ThePSF"><span aria-hidden="true" class="icon-twitter"></span>Twitter</a></li>
# <li class="tier-2 element-3" role="treeitem"><a href="/community/irc/"><span aria-hidden="true" class="icon-freenode"></span>Chat on IRC</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <span data-html-include="/authenticated"></span>
# </div><!-- end options-bar -->
# </div>
# <nav class="python-navigation main-navigation do-not-print" id="mainnav" role="navigation">
# <ul aria-label="Main Navigation" class="navigation menu" role="menubar">
# <li aria-haspopup="true" class="tier-1 element-1" id="about">
# <a class="current_item selected selected" href="/about/" title="">About</a>
# <ul aria-hidden="true" class="subnav menu" role="menu">
# <li class="tier-2 element-1" role="treeitem"><a href="/about/apps/" title="">Applications</a></li>
# <li class="tier-2 element-2" role="treeitem"><a href="/about/quotes/" title="">Quotes</a></li>
# <li class="tier-2 element-3" role="treeitem"><a href="/about/gettingstarted/" title="">Getting Started</a></li>
# <li class="tier-2 element-4" role="treeitem"><a href="/about/help/" title="">Help</a></li>
# <li class="tier-2 element-5" role="treeitem"><a href="http://brochure.getpython.info/" title="">Python Brochure</a></li>
# </ul>
# </li>
# <li aria-haspopup="true" class="tier-1 element-2" id="downloads">
# <a class="" href="/downloads/" title="">Downloads</a>
# <ul aria-hidden="true" class="subnav menu" role="menu">
# <li class="tier-2 element-1" role="treeitem"><a href="/downloads/" title="">All releases</a></li>
# <li class="tier-2 element-2" role="treeitem"><a href="/downloads/source/" title="">Source code</a></li>
# <li class="tier-2 element-3" role="treeitem"><a href="/downloads/windows/" title="">Windows</a></li>
# <li class="tier-2 element-4" role="treeitem"><a href="/downloads/macos/" title="">macOS</a></li>
# <li class="tier-2 element-5" role="treeitem"><a href="/download/other/" title="">Other Platforms</a></li>
# <li class="tier-2 element-6" role="treeitem"><a href="https://docs.python.org/3/license.html" title="">License</a></li>
# <li class="tier-2 element-7" role="treeitem"><a href="/download/alternatives" title="">Alternative Implementations</a></li>
# </ul>
# </li>
# <li aria-haspopup="true" class="tier-1 element-3" id="documentation">
# <a class="" href="/doc/" title="">Documentation</a>
# <ul aria-hidden="true" class="subnav menu" role="menu">
# <li class="tier-2 element-1" role="treeitem"><a href="/doc/" title="">Docs</a></li>
# <li class="tier-2 element-2" role="treeitem"><a href="/doc/av" title="">Audio/Visual Talks</a></li>
# <li class="tier-2 element-3" role="treeitem"><a href="https://wiki.python.org/moin/BeginnersGuide" title="">Beginner's Guide</a></li>
# <li class="tier-2 element-4" role="treeitem"><a href="https://devguide.python.org/" title="">Developer's Guide</a></li>
# <li class="tier-2 element-5" role="treeitem"><a href="https://docs.python.org/faq/" title="">FAQ</a></li>
# <li class="tier-2 element-6" role="treeitem"><a href="http://wiki.python.org/moin/Languages" title="">Non-English Docs</a></li>
# <li class="tier-2 element-7" role="treeitem"><a href="http://python.org/dev/peps/" title="">PEP Index</a></li>
# <li class="tier-2 element-8" role="treeitem"><a href="https://wiki.python.org/moin/PythonBooks" title="">Python Books</a></li>
# <li class="tier-2 element-9" role="treeitem"><a href="/doc/essays/" title="">Python Essays</a></li>
# </ul>
# </li>
# <li aria-haspopup="true" class="tier-1 element-4" id="community">
# <a class="" href="/community/" title="">Community</a>
# <ul aria-hidden="true" class="subnav menu" role="menu">
# <li class="tier-2 element-1" role="treeitem"><a href="/community/diversity/" title="">Diversity</a></li>
# <li class="tier-2 element-2" role="treeitem"><a href="/community/lists/" title="">Mailing Lists</a></li>
# <li class="tier-2 element-3" role="treeitem"><a href="/community/irc/" title="">IRC</a></li>
# <li class="tier-2 element-4" role="treeitem"><a href="/community/forums/" title="">Forums</a></li>
# <li class="tier-2 element-5" role="treeitem"><a href="/psf/annual-report/2021/" title="">PSF Annual Impact Report</a></li>
# <li class="tier-2 element-6" role="treeitem"><a href="/community/workshops/" title="">Python Conferences</a></li>
# <li class="tier-2 element-7" role="treeitem"><a href="/community/sigs/" title="">Special Interest Groups</a></li>
# <li class="tier-2 element-8" role="treeitem"><a href="/community/logos/" title="">Python Logo</a></li>
# <li class="tier-2 element-9" role="treeitem"><a href="https://wiki.python.org/moin/" title="">Python Wiki</a></li>
# <li class="tier-2 element-10" role="treeitem"><a href="/psf/conduct/" title="">Code of Conduct</a></li>
# <li class="tier-2 element-11" role="treeitem"><a href="/community/awards" title="">Community Awards</a></li>
# <li class="tier-2 element-12" role="treeitem"><a href="/psf/get-involved/" title="">Get Involved</a></li>
# <li class="tier-2 element-13" role="treeitem"><a href="/psf/community-stories/" title="">Shared Stories</a></li>
# </ul>
# </li>
# <li aria-haspopup="true" class="tier-1 element-5" id="success-stories">
# <a class="" href="/success-stories/" title="success-stories">Success Stories</a>
# <ul aria-hidden="true" class="subnav menu" role="menu">
# <li class="tier-2 element-1" role="treeitem"><a href="/success-stories/category/arts/" title="">Arts</a></li>
# <li class="tier-2 element-2" role="treeitem"><a href="/success-stories/category/business/" title="">Business</a></li>
# <li class="tier-2 element-3" role="treeitem"><a href="/success-stories/category/education/" title="">Education</a></li>
# <li class="tier-2 element-4" role="treeitem"><a href="/success-stories/category/engineering/" title="">Engineering</a></li>
# <li class="tier-2 element-5" role="treeitem"><a href="/success-stories/category/government/" title="">Government</a></li>
# <li class="tier-2 element-6" role="treeitem"><a href="/success-stories/category/scientific/" title="">Scientific</a></li>
# <li class="tier-2 element-7" role="treeitem"><a href="/success-stories/category/software-development/" title="">Software Development</a></li>
# </ul>
# </li>
# <li aria-haspopup="true" class="tier-1 element-6" id="news">
# <a class="" href="/blogs/" title="News from around the Python world">News</a>
# <ul aria-hidden="true" class="subnav menu" role="menu">
# <li class="tier-2 element-1" role="treeitem"><a href="/blogs/" title="Python Insider Blog Posts">Python News</a></li>
# <li class="tier-2 element-2" role="treeitem"><a href="/psf/newsletter/" title="Python Software Foundation Newsletter">PSF Newsletter</a></li>
# <li class="tier-2 element-3" role="treeitem"><a href="http://pyfound.blogspot.com/" title="PSF Blog">PSF News</a></li>
# <li class="tier-2 element-4" role="treeitem"><a href="http://pycon.blogspot.com/" title="PyCon Blog">PyCon US News</a></li>
# <li class="tier-2 element-5" role="treeitem"><a href="http://planetpython.org/" title="Planet Python">News from the Community</a></li>
# </ul>
# </li>
# <li aria-haspopup="true" class="tier-1 element-7" id="events">
# <a class="" href="/events/" title="">Events</a>
# <ul aria-hidden="true" class="subnav menu" role="menu">
# <li class="tier-2 element-1" role="treeitem"><a href="/events/python-events/" title="">Python Events</a></li>
# <li class="tier-2 element-2" role="treeitem"><a href="/events/python-user-group/" title="">User Group Events</a></li>
# <li class="tier-2 element-3" role="treeitem"><a href="/events/python-events/past/" title="">Python Events Archive</a></li>
# <li class="tier-2 element-4" role="treeitem"><a href="/events/python-user-group/past/" title="">User Group Events Archive</a></li>
# <li class="tier-2 element-5" role="treeitem"><a href="https://wiki.python.org/moin/PythonEventsCalendar#Submitting_an_Event" title="">Submit an Event</a></li>
# </ul>
# </li>
# </ul>
# </nav>
# <div class="header-banner"> <!-- for optional "do-not-print" class -->
# <div class="about-banner">
# <h1 class="call-to-action">
#     Python is powerful... and fast; <br/>
#     plays well with others; <br/>
#     runs everywhere; <br/>
#     is friendly &amp; easy to learn; <br/>
#     is Open.
# </h1>
# <p>These are some of the reasons people who use Python would rather not use anything else.</p>
# </div>
# </div>
# </div><!-- end .container -->
# </header>
# <div class="content-wrapper" id="content">
# <!-- Main Content Column -->
# <div class="container">
# <section class="main-content" role="main">
# <div class="row">
# <div class="medium-widget success-story-category">
# <h2 class="widget-title"><span aria-hidden="true" class="icon-get-started"></span>Getting Started</h2>
# <p>Python can be easy to pick up whether you're a first time programmer or you're experienced with other languages. The following pages are a useful first step to get on your way writing programs with Python!</p>
# <ul>
# <li><a href="https://wiki.python.org/moin/BeginnersGuide/Programmers">Beginner's Guide, Programmers</a></li>
# <li><a href="https://wiki.python.org/moin/BeginnersGuide/NonProgrammers">Beginner's Guide, Non-Programmers</a></li>
# <li><a href="https://wiki.python.org/moin/BeginnersGuide/Download">Beginner's Guide, Download &amp; Installation</a></li>
# <li><a href="https://wiki.python.org/moin/BeginnersGuide/Examples">Code sample and snippets for Beginners</a></li>
# </ul>
# </div>
# <div class="medium-widget success-story-category last">
# <h2 class="widget-title"><span aria-hidden="true" class="icon-success-stories"></span>Friendly &amp; Easy to Learn</h2>
# <p>The community hosts conferences and meetups, collaborates on code, and much more. Python's documentation will help you along the way, and the mailing lists will keep you in touch.</p>
# <ul>
# <li><a href="/community/workshops/">Conferences and Workshops</a></li>
# <li><a href="http://docs.python.org">Python Documentation</a></li>
# <li><a href="/community/lists"></a>Mailing Lists and <a href="/community/irc/">IRC channels</a></li>
# </ul>
# </div>
# </div>
# <div class="row">
# <div class="medium-widget success-story-category">
# <h2 class="widget-title"><span aria-hidden="true" class="icon-pypi"></span>Applications</h2>
# <p>The <a href="https://pypi.python.org">Python Package Index (PyPI)</a> hosts thousands of third-party modules for Python. Both Python's standard library and the community-contributed modules allow for endless possibilities.</p>
# <ul>
# <li><a href="/about/apps/#web-and-internet-development">Web and Internet Development</a></li>
# <li><a href="/about/apps/#database-access">Database Access</a></li>
# <li><a href="/about/apps/#desktop-guis">Desktop GUIs</a></li>
# <li><a href="/about/apps/#scientific-and-numeric">Scientific &amp; Numeric</a></li>
# <li><a href="/about/apps/#education">Education</a></li>
# <li><a href="/about/apps/#network-programming">Network Programming</a></li>
# <li><a href="/about/apps/#software-development">Software &amp; Game Development</a></li>
# </ul>
# </div>
# <div class="medium-widget success-story-category last">
# <h2 class="widget-title"><span aria-hidden="true" class="icon-code"></span>Open-source</h2>
# <p>Python is developed under an OSI-approved open source license, making it freely usable and distributable, even for commercial use. Python's license is administered by the <a href="/psf">Python Software Foundation</a>.</p>
# <ul>
# <li><a href="https://docs.python.org/license.html">Learn more about the license</a></li>
# <li><a href="https://opensource.org/license/pythonsoftfoundation-php/">Python license on OSI</a></li>
# <li><a href="/psf-landing/">Learn more about the Foundation</a></li>
# </ul>
# </div>
# </div>
# <div class="user-feedback level-general">
# <p>Can’t find what you’re looking for? <a href="/about/help/">Try our comprehensive Help section</a></p>
# </div>
# <div class="list-widgets row">
# <div class="medium-widget blog-widget">
# <div class="shrubbery">
# <h2 class="widget-title"><span aria-hidden="true" class="icon-news"></span>Latest News</h2>
# <p class="give-me-more"><a href="https://blog.python.org" title="More News">More</a></p>
# <ul class="menu">
# <li>
# <time datetime="2023-05-11T21:21:00.000003+00:00"><span class="say-no-more">2023-</span>05-11</time>
# <a href="https://pyfound.blogspot.com/2023/05/psf-board-election-dates-for-2023.html">PSF Board Election Dates for 2023</a></li>
# <li>
# <time datetime="2023-05-05T18:31:00.000004+00:00"><span class="say-no-more">2023-</span>05-05</time>
# <a href="https://pyfound.blogspot.com/2023/05/python-humble-bundle.html">All-Python Humble Bundle out now from No Starch Press!</a></li>
# <li>
# <time datetime="2023-04-13T14:28:00.000003+00:00"><span class="say-no-more">2023-</span>04-13</time>
# <a href="https://pyfound.blogspot.com/2023/04/thank-you-for-many-years-of-service-van.html">Thank You for Many Years of Service, Van!</a></li>
# <li>
# <time datetime="2023-04-11T13:59:00.000001+00:00"><span class="say-no-more">2023-</span>04-11</time>
# <a href="https://pyfound.blogspot.com/2023/04/the-eus-proposed-cra-law-may-have.html">The EU's Proposed CRA Law May Have Unintended Consequences for the Python Ecosystem</a></li>
# <li>
# <time datetime="2023-04-05T12:25:00.000002+00:00"><span class="say-no-more">2023-</span>04-05</time>
# <a href="https://pythoninsider.blogspot.com/2023/04/its-time-for-another-set-of-python.html">Python 3.11.3, Python 3.10.11 and 3.12.0 alpha 7 are available</a></li>
# </ul>
# </div><!-- end .shrubbery -->
# </div>
# <div class="medium-widget event-widget last">
# <div class="shrubbery">
# <h2 class="widget-title"><span aria-hidden="true" class="icon-calendar"></span>Upcoming Events</h2>
# <p class="give-me-more"><a href="/events/calendars/" title="More Events">More</a></p>
# <ul class="menu">
# <li>
# <time datetime="2023-05-25T00:00:00+00:00"><span class="say-no-more">2023-</span>05-25</time>
# <a href="/events/python-events/1382/">PyCon Italia 2023</a></li>
# <li>
# <time datetime="2023-05-27T00:00:00+00:00"><span class="say-no-more">2023-</span>05-27</time>
# <a href="/events/python-user-group/1499/">Django Girls Groningen</a></li>
# <li>
# <time datetime="2023-05-29T00:00:00+00:00"><span class="say-no-more">2023-</span>05-29</time>
# <a href="/events/python-events/1433/"> DjangoCon Europe 2023</a></li>
# <li>
# <time datetime="2023-05-30T16:00:00+00:00"><span class="say-no-more">2023-</span>05-30</time>
# <a href="/events/python-user-group/1511/">An Introduction to Pyro</a></li>
# <li>
# <time datetime="2023-06-02T00:00:00+00:00"><span class="say-no-more">2023-</span>06-02</time>
# <a href="/events/python-events/1453/">PyData London 2023</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="psf-widget">
# <div class="python-logo"></div>
# <h2 class="widget-title">
# <span class="prompt">&gt;&gt;&gt;</span> <a href="/psf/">Python Software Foundation</a>
# </h2>
# <p>The mission of the Python Software Foundation is to promote, protect, and advance the Python programming language, and to support and facilitate the growth of a diverse and international community of Python programmers. <a class="readmore" href="/psf/">Learn more</a> </p>
# <p class="click-these">
# <a class="button" href="/users/membership/">Become a Member</a>
# <a class="button" href="/psf/donations/">Donate to the PSF</a>
# </p>
# </div>
# </section>
# </div><!-- end .container -->
# </div><!-- end #content .content-wrapper -->
# <!-- Footer and social media list -->
# <footer class="main-footer" id="site-map" role="contentinfo">
# <div class="main-footer-links">
# <div class="container">
# <a class="jump-link" href="#python-network" id="back-to-top-1"><span aria-hidden="true" class="icon-arrow-up"><span>▲</span></span> Back to Top</a>
# <ul class="sitemap navigation menu do-not-print" id="container" role="tree">
# <li class="tier-1 element-1">
# <a href="/about/">About</a>
# <ul class="subnav menu">
# <li class="tier-2 element-1" role="treeitem"><a href="/about/apps/" title="">Applications</a></li>
# <li class="tier-2 element-2" role="treeitem"><a href="/about/quotes/" title="">Quotes</a></li>
# <li class="tier-2 element-3" role="treeitem"><a href="/about/gettingstarted/" title="">Getting Started</a></li>
# <li class="tier-2 element-4" role="treeitem"><a href="/about/help/" title="">Help</a></li>
# <li class="tier-2 element-5" role="treeitem"><a href="http://brochure.getpython.info/" title="">Python Brochure</a></li>
# </ul>
# </li>
# <li class="tier-1 element-2">
# <a href="/downloads/">Downloads</a>
# <ul class="subnav menu">
# <li class="tier-2 element-1" role="treeitem"><a href="/downloads/" title="">All releases</a></li>
# <li class="tier-2 element-2" role="treeitem"><a href="/downloads/source/" title="">Source code</a></li>
# <li class="tier-2 element-3" role="treeitem"><a href="/downloads/windows/" title="">Windows</a></li>
# <li class="tier-2 element-4" role="treeitem"><a href="/downloads/macos/" title="">macOS</a></li>
# <li class="tier-2 element-5" role="treeitem"><a href="/download/other/" title="">Other Platforms</a></li>
# <li class="tier-2 element-6" role="treeitem"><a href="https://docs.python.org/3/license.html" title="">License</a></li>
# <li class="tier-2 element-7" role="treeitem"><a href="/download/alternatives" title="">Alternative Implementations</a></li>
# </ul>
# </li>
# <li class="tier-1 element-3">
# <a href="/doc/">Documentation</a>
# <ul class="subnav menu">
# <li class="tier-2 element-1" role="treeitem"><a href="/doc/" title="">Docs</a></li>
# <li class="tier-2 element-2" role="treeitem"><a href="/doc/av" title="">Audio/Visual Talks</a></li>
# <li class="tier-2 element-3" role="treeitem"><a href="https://wiki.python.org/moin/BeginnersGuide" title="">Beginner's Guide</a></li>
# <li class="tier-2 element-4" role="treeitem"><a href="https://devguide.python.org/" title="">Developer's Guide</a></li>
# <li class="tier-2 element-5" role="treeitem"><a href="https://docs.python.org/faq/" title="">FAQ</a></li>
# <li class="tier-2 element-6" role="treeitem"><a href="http://wiki.python.org/moin/Languages" title="">Non-English Docs</a></li>
# <li class="tier-2 element-7" role="treeitem"><a href="http://python.org/dev/peps/" title="">PEP Index</a></li>
# <li class="tier-2 element-8" role="treeitem"><a href="https://wiki.python.org/moin/PythonBooks" title="">Python Books</a></li>
# <li class="tier-2 element-9" role="treeitem"><a href="/doc/essays/" title="">Python Essays</a></li>
# </ul>
# </li>
# <li class="tier-1 element-4">
# <a href="/community/">Community</a>
# <ul class="subnav menu">
# <li class="tier-2 element-1" role="treeitem"><a href="/community/diversity/" title="">Diversity</a></li>
# <li class="tier-2 element-2" role="treeitem"><a href="/community/lists/" title="">Mailing Lists</a></li>
# <li class="tier-2 element-3" role="treeitem"><a href="/community/irc/" title="">IRC</a></li>
# <li class="tier-2 element-4" role="treeitem"><a href="/community/forums/" title="">Forums</a></li>
# <li class="tier-2 element-5" role="treeitem"><a href="/psf/annual-report/2021/" title="">PSF Annual Impact Report</a></li>
# <li class="tier-2 element-6" role="treeitem"><a href="/community/workshops/" title="">Python Conferences</a></li>
# <li class="tier-2 element-7" role="treeitem"><a href="/community/sigs/" title="">Special Interest Groups</a></li>
# <li class="tier-2 element-8" role="treeitem"><a href="/community/logos/" title="">Python Logo</a></li>
# <li class="tier-2 element-9" role="treeitem"><a href="https://wiki.python.org/moin/" title="">Python Wiki</a></li>
# <li class="tier-2 element-10" role="treeitem"><a href="/psf/conduct/" title="">Code of Conduct</a></li>
# <li class="tier-2 element-11" role="treeitem"><a href="/community/awards" title="">Community Awards</a></li>
# <li class="tier-2 element-12" role="treeitem"><a href="/psf/get-involved/" title="">Get Involved</a></li>
# <li class="tier-2 element-13" role="treeitem"><a href="/psf/community-stories/" title="">Shared Stories</a></li>
# </ul>
# </li>
# <li class="tier-1 element-5">
# <a href="/success-stories/" title="success-stories">Success Stories</a>
# <ul class="subnav menu">
# <li class="tier-2 element-1" role="treeitem"><a href="/success-stories/category/arts/" title="">Arts</a></li>
# <li class="tier-2 element-2" role="treeitem"><a href="/success-stories/category/business/" title="">Business</a></li>
# <li class="tier-2 element-3" role="treeitem"><a href="/success-stories/category/education/" title="">Education</a></li>
# <li class="tier-2 element-4" role="treeitem"><a href="/success-stories/category/engineering/" title="">Engineering</a></li>
# <li class="tier-2 element-5" role="treeitem"><a href="/success-stories/category/government/" title="">Government</a></li>
# <li class="tier-2 element-6" role="treeitem"><a href="/success-stories/category/scientific/" title="">Scientific</a></li>
# <li class="tier-2 element-7" role="treeitem"><a href="/success-stories/category/software-development/" title="">Software Development</a></li>
# </ul>
# </li>
# <li class="tier-1 element-6">
# <a href="/blogs/" title="News from around the Python world">News</a>
# <ul class="subnav menu">
# <li class="tier-2 element-1" role="treeitem"><a href="/blogs/" title="Python Insider Blog Posts">Python News</a></li>
# <li class="tier-2 element-2" role="treeitem"><a href="/psf/newsletter/" title="Python Software Foundation Newsletter">PSF Newsletter</a></li>
# <li class="tier-2 element-3" role="treeitem"><a href="http://pyfound.blogspot.com/" title="PSF Blog">PSF News</a></li>
# <li class="tier-2 element-4" role="treeitem"><a href="http://pycon.blogspot.com/" title="PyCon Blog">PyCon US News</a></li>
# <li class="tier-2 element-5" role="treeitem"><a href="http://planetpython.org/" title="Planet Python">News from the Community</a></li>
# </ul>
# </li>
# <li class="tier-1 element-7">
# <a href="/events/">Events</a>
# <ul class="subnav menu">
# <li class="tier-2 element-1" role="treeitem"><a href="/events/python-events/" title="">Python Events</a></li>
# <li class="tier-2 element-2" role="treeitem"><a href="/events/python-user-group/" title="">User Group Events</a></li>
# <li class="tier-2 element-3" role="treeitem"><a href="/events/python-events/past/" title="">Python Events Archive</a></li>
# <li class="tier-2 element-4" role="treeitem"><a href="/events/python-user-group/past/" title="">User Group Events Archive</a></li>
# <li class="tier-2 element-5" role="treeitem"><a href="https://wiki.python.org/moin/PythonEventsCalendar#Submitting_an_Event" title="">Submit an Event</a></li>
# </ul>
# </li>
# <li class="tier-1 element-8">
# <a href="/dev/">Contributing</a>
# <ul class="subnav menu">
# <li class="tier-2 element-1" role="treeitem"><a href="https://devguide.python.org/" title="">Developer's Guide</a></li>
# <li class="tier-2 element-2" role="treeitem"><a href="https://bugs.python.org/" title="">Issue Tracker</a></li>
# <li class="tier-2 element-3" role="treeitem"><a href="https://mail.python.org/mailman/listinfo/python-dev" title="">python-dev list</a></li>
# <li class="tier-2 element-4" role="treeitem"><a href="/dev/core-mentorship/" title="">Core Mentorship</a></li>
# <li class="tier-2 element-5" role="treeitem"><a href="/dev/security/" title="">Report a Security Issue</a></li>
# </ul>
# </li>
# </ul>
# <a class="jump-link" href="#python-network" id="back-to-top-2"><span aria-hidden="true" class="icon-arrow-up"><span>▲</span></span> Back to Top</a>
# </div><!-- end .container -->
# </div> <!-- end .main-footer-links -->
# <div class="site-base">
# <div class="container">
# <ul class="footer-links navigation menu do-not-print" role="tree">
# <li class="tier-1 element-1"><a href="/about/help/">Help &amp; <span class="say-no-more">General</span> Contact</a></li>
# <li class="tier-1 element-2"><a href="/community/diversity/">Diversity <span class="say-no-more">Initiatives</span></a></li>
# <li class="tier-1 element-3"><a href="https://github.com/python/pythondotorg/issues">Submit Website Bug</a></li>
# <li class="tier-1 element-4">
# <a href="https://status.python.org/">Status <span class="python-status-indicator-default" id="python-status-indicator"></span></a>
# </li>
# </ul>
# <div class="copyright">
# <p><small>
# <span class="pre">Copyright ©2001-2023.</span>
#                              <span class="pre"><a href="/psf-landing/">Python Software Foundation</a></span>
#                              <span class="pre"><a href="/about/legal/">Legal Statements</a></span>
#                              <span class="pre"><a href="/privacy/">Privacy Policy</a></span>
#                              <span class="pre"><a href="/psf/sponsorship/sponsors/#heroku">Powered by Heroku</a></span>
# </small></p>
# </div>
# </div><!-- end .container -->
# </div><!-- end .site-base -->
# </footer>
# </div><!-- end #touchnav-wrapper -->
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.8.2/jquery.min.js"></script>
# <script>window.jQuery || document.write('<script src="/static/js/libs/jquery-1.8.2.min.js"><\/script>')</script>
# <script src="//ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.js"></script>
# <script>window.jQuery || document.write('<script src="/static/js/libs/jquery-ui-1.12.1.min.js"><\/script>')</script>
# <script src="/static/js/libs/masonry.pkgd.min.js"></script>
# <script src="/static/js/libs/html-includes.js"></script>
# <script charset="utf-8" src="/static/js/main-min.f5487accf7ed.js" type="text/javascript"></script>
# <!--[if lte IE 7]>
#     <script type="text/javascript" src="/static/js/plugins/IE8-min.8af6e26c7a3b.js" charset="utf-8"></script>
#
#
#     <![endif]-->
# <!--[if lte IE 8]>
#     <script type="text/javascript" src="/static/js/plugins/getComputedStyle-min.d41d8cd98f00.js" charset="utf-8"></script>
#
#
#     <![endif]-->
# </body>
# </html>
